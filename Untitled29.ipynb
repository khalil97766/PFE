# %%
# ==============================================================================
# SCRIPT: prepare_dataset.py
# ==============================================================================
# PURPOSE: To process a video and create a structured dataset. For each
#          processed frame, it saves the image, obstacle data (JSON), and
#          depth map (NPY). This is the foundation for all future algorithms.
# ==============================================================================

import cv2
import os
import numpy as np
import torch
import json
import time

def main():
    """Main function to run the dataset preparation script."""
    
    # ==========================================================================
    # 1. SETTINGS
    # ==========================================================================
    
    # --- Input Paths ---
    YOLO_FOLDER = "C:/Users/acer/Desktop/sqh/yolo"
    # *** UPDATED aS REQUESTED ***
    VIDEO_FILE_FULL_PATH = "C:/Users/acer/Desktop/sqh/vedio/bejaia.mp4"
    
    # --- Output Dataset Folder ---
    # We will create one main folder for our new dataset
    DATASET_OUTPUT_FOLDER = "street_dataset"
    
    # --- Subfolders for different data types ---
    IMAGE_FOLDER = os.path.join(DATASET_OUTPUT_FOLDER, "images")
    OBSTACLE_FOLDER = os.path.join(DATASET_OUTPUT_FOLDER, "obstacles_json")
    DEPTH_FOLDER = os.path.join(DATASET_OUTPUT_FOLDER, "depth_maps_npy")
    
    # Create the folders if they don't exist
    os.makedirs(IMAGE_FOLDER, exist_ok=True)
    os.makedirs(OBSTACLE_FOLDER, exist_ok=True)
    os.makedirs(DEPTH_FOLDER, exist_ok=True)
    
    # --- Processing Settings ---
    PROCESSING_WIDTH = 480      # Resize frames to this width for consistency
    PROCESS_EVERY_N_FRAMES = 15 # Process a frame every half-second (assuming 30fps video)
    CONFIDENCE_THRESHOLD = 0.5
    NMS_THRESHOLD = 0.4
    
    # ==========================================================================
    # 2. LOAD AI MODELS
    # ==========================================================================
    
    print("--- Loading AI Models ---")
    
    # --- Load YOLO ---
    try:
        weights_path = os.path.join(YOLO_FOLDER, "yolov3.weights")
        config_path = os.path.join(YOLO_FOLDER, "yolov3.cfg")
        yolo_net = cv2.dnn.readNet(weights_path, config_path)
        names_path = os.path.join(YOLO_FOLDER, "coco.names")
        with open(names_path, "r") as f:
            yolo_classes = [line.strip() for line in f.readlines()]
        layer_names = yolo_net.getLayerNames()
        output_layers = [layer_names[i - 1] for i in yolo_net.getUnconnectedOutLayers()]
        print("YOLO model loaded successfully.")
    except cv2.error as e:
        print(f"!!! FATAL ERROR: Could not load YOLO model. Check file paths in '{YOLO_FOLDER}'. Error: {e}")
        return

    # --- Load MiDaS ---
    try:
        model_type = "MiDaS_small"
        midas = torch.hub.load("intel-isl/MiDaS", model_type)
        device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
        midas.to(device)
        midas.eval()
        midas_transforms = torch.hub.load("intel-isl/MiDaS", "transforms")
        transform = midas_transforms.small_transform
        print(f"MiDaS model loaded successfully on device: {device}")
    except Exception as e:
        print(f"!!! FATAL ERROR: Could not load MiDaS model. An internet connection may be required. Error: {e}")
        return

    # ==========================================================================
    # 3. HELPER FUNCTIONS (detect_obstacles, estimate_depth)
    # ==========================================================================
    
    def detect_obstacles(frame, net, output_layers, classes):
        height, width, _ = frame.shape
        blob = cv2.dnn.blobFromImage(frame, 1/255.0, (416, 416), swapRB=True, crop=False)
        net.setInput(blob)
        layer_outputs = net.forward(output_layers)
        boxes, confidences, class_ids = [], [], []
        for output in layer_outputs:
            for detection in output:
                scores = detection[5:]
                class_id = np.argmax(scores)
                confidence = scores[class_id]
                if confidence > CONFIDENCE_THRESHOLD:
                    center_x = int(detection[0] * width)
                    center_y = int(detection[1] * height)
                    w = int(detection[2] * width)
                    h = int(detection[3] * height)
                    x = int(center_x - w / 2)
                    y = int(center_y - h / 2)
                    boxes.append([x, y, w, h])
                    confidences.append(float(confidence))
                    class_ids.append(class_id)
        final_indices = cv2.dnn.NMSBoxes(boxes, confidences, CONFIDENCE_THRESHOLD, NMS_THRESHOLD)
        detected_obstacles = []
        if len(final_indices) > 0:
            for i in final_indices.flatten():
                obstacle_data = {"box": boxes[i], "label": classes[class_ids[i]], "confidence": confidences[i]}
                detected_obstacles.append(obstacle_data)
        return detected_obstacles

    def estimate_depth(frame, model, transform, device):
        if model is None: return None
        img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        input_batch = transform(img).to(device)
        with torch.no_grad():
            prediction = model(input_batch)
            prediction = torch.nn.functional.interpolate(
                prediction.unsqueeze(1), size=img.shape[:2], mode="bicubic", align_corners=False
            ).squeeze()
        depth_map = prediction.cpu().numpy()
        return depth_map
        
    # ==========================================================================
    # 4. MAIN PROCESSING LOOP
    # ==========================================================================
    
    print("\n--- Starting Video Processing to Create Dataset ---")
    vid_capture = cv2.VideoCapture(VIDEO_FILE_FULL_PATH)
    if not vid_capture.isOpened():
        print(f"!!! FATAL ERROR: Could not open the video file at: {VIDEO_FILE_FULL_PATH}")
        return

    frame_count = 0
    start_time = time.time()
    
    while True:
        ret, original_frame = vid_capture.read()
        if not ret:
            print("\nReached end of video.")
            break

        if frame_count % PROCESS_EVERY_N_FRAMES == 0:
            
            # --- Resize Frame ---
            h, w, _ = original_frame.shape
            scale = PROCESSING_WIDTH / w
            frame = cv2.resize(original_frame, (int(w * scale), int(h * scale)))

            # --- Run AI Models ---
            obstacles = detect_obstacles(frame, yolo_net, output_layers, yolo_classes)
            depth_map = estimate_depth(frame, midas, transform, device)

            # --- Save all data to disk ---
            # Create a base filename for this frame
            base_filename = f"frame_{frame_count:05d}" # e.g., frame_00000, frame_00015
            
            # 1. Save the processed image
            cv2.imwrite(os.path.join(IMAGE_FOLDER, f"{base_filename}.jpg"), frame)
            
            # 2. Save the obstacle data
            with open(os.path.join(OBSTACLE_FOLDER, f"{base_filename}.json"), 'w') as f:
                json.dump(obstacles, f)
            
            # 3. Save the depth map
            if depth_map is not None:
                np.save(os.path.join(DEPTH_FOLDER, f"{base_filename}.npy"), depth_map)

            print(f"  - Processed and saved data for frame {frame_count}")

        frame_count += 1
        
    end_time = time.time()
    total_time = end_time - start_time
    print(f"\n--- Dataset Creation Finished! ---")
    print(f"Total time taken: {total_time:.2f} seconds.")
    print(f"Dataset saved in folder: '{DATASET_OUTPUT_FOLDER}'")

# This is standard practice in Python scripts
if __name__ == '__main__':
    main()
# Out:
# --- Loading AI Models ---
# YOLO model loaded successfully.
# Using cache found in C:\Users\acer/.cache\torch\hub\intel-isl_MiDaS_master
# D:\anaconda\Lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Loading weights:  None
# Using cache found in C:\Users\acer/.cache\torch\hub\rwightman_gen-efficientnet-pytorch_master
# Using cache found in C:\Users\acer/.cache\torch\hub\intel-isl_MiDaS_master
# MiDaS model loaded successfully on device: cpu
#
# --- Starting Video Processing to Create Dataset ---
#   - Processed and saved data for frame 0
#   - Processed and saved data for frame 15
#   - Processed and saved data for frame 30
#   - Processed and saved data for frame 45
#   - Processed and saved data for frame 60
#   - Processed and saved data for frame 75
#   - Processed and saved data for frame 90
#   - Processed and saved data for frame 105
#   - Processed and saved data for frame 120
#   - Processed and saved data for frame 135
#   - Processed and saved data for frame 150
#   - Processed and saved data for frame 165
#   - Processed and saved data for frame 180
#   - Processed and saved data for frame 195
#   - Processed and saved data for frame 210
#   - Processed and saved data for frame 225
#   - Processed and saved data for frame 240
#   - Processed and saved data for frame 255
#   - Processed and saved data for frame 270
#   - Processed and saved data for frame 285
#   - Processed and saved data for frame 300
#   - Processed and saved data for frame 315
#   - Processed and saved data for frame 330
#   - Processed and saved data for frame 345
#   - Processed and saved data for frame 360
#   - Processed and saved data for frame 375
#   - Processed and saved data for frame 390
#   - Processed and saved data for frame 405
#   - Processed and saved data for frame 420
#   - Processed and saved data for frame 435
#   - Processed and saved data for frame 450
#   - Processed and saved data for frame 465
#   - Processed and saved data for frame 480
#   - Processed and saved data for frame 495
#   - Processed and saved data for frame 510
#   - Processed and saved data for frame 525
#   - Processed and saved data for frame 540
#   - Processed and saved data for frame 555
#   - Processed and saved data for frame 570
#   - Processed and saved data for frame 585
#   - Processed and saved data for frame 600
#   - Processed and saved data for frame 615
#   - Processed and saved data for frame 630
#   - Processed and saved data for frame 645
#   - Processed and saved data for frame 660
#   - Processed and saved data for frame 675
#   - Processed and saved data for frame 690
#   - Processed and saved data for frame 705
#   - Processed and saved data for frame 720
#   - Processed and saved data for frame 735
#   - Processed and saved data for frame 750
#   - Processed and saved data for frame 765
#   - Processed and saved data for frame 780
#   - Processed and saved data for frame 795
#   - Processed and saved data for frame 810
#   - Processed and saved data for frame 825
#   - Processed and saved data for frame 840
#   - Processed and saved data for frame 855
#   - Processed and saved data for frame 870
#   - Processed and saved data for frame 885
#   - Processed and saved data for frame 900
#   - Processed and saved data for frame 915
#   - Processed and saved data for frame 930
#   - Processed and saved data for frame 945
#   - Processed and saved data for frame 960
#   - Processed and saved data for frame 975
#   - Processed and saved data for frame 990
#   - Processed and saved data for frame 1005
#   - Processed and saved data for frame 1020
#   - Processed and saved data for frame 1035
#   - Processed and saved data for frame 1050
#   - Processed and saved data for frame 1065
#   - Processed and saved data for frame 1080
#   - Processed and saved data for frame 1095
#   - Processed and saved data for frame 1110
#   - Processed and saved data for frame 1125
#   - Processed and saved data for frame 1140
#   - Processed and saved data for frame 1155
#   - Processed and saved data for frame 1170
#   - Processed and saved data for frame 1185
#   - Processed and saved data for frame 1200
#   - Processed and saved data for frame 1215
#   - Processed and saved data for frame 1230
#   - Processed and saved data for frame 1245
#   - Processed and saved data for frame 1260
#   - Processed and saved data for frame 1275
#   - Processed and saved data for frame 1290
#   - Processed and saved data for frame 1305
#   - Processed and saved data for frame 1320
#   - Processed and saved data for frame 1335
#   - Processed and saved data for frame 1350
#   - Processed and saved data for frame 1365
#   - Processed and saved data for frame 1380
#   - Processed and saved data for frame 1395
#   - Processed and saved data for frame 1410
#   - Processed and saved data for frame 1425
#   - Processed and saved data for frame 1440
#   - Processed and saved data for frame 1455
#   - Processed and saved data for frame 1470
#   - Processed and saved data for frame 1485
#   - Processed and saved data for frame 1500
#   - Processed and saved data for frame 1515
#   - Processed and saved data for frame 1530
#   - Processed and saved data for frame 1545
#   - Processed and saved data for frame 1560
#   - Processed and saved data for frame 1575
#   - Processed and saved data for frame 1590
#   - Processed and saved data for frame 1605
#   - Processed and saved data for frame 1620
#   - Processed and saved data for frame 1635
#   - Processed and saved data for frame 1650
#   - Processed and saved data for frame 1665
#   - Processed and saved data for frame 1680
#   - Processed and saved data for frame 1695
#   - Processed and saved data for frame 1710
#   - Processed and saved data for frame 1725
#   - Processed and saved data for frame 1740
#   - Processed and saved data for frame 1755
#   - Processed and saved data for frame 1770
#   - Processed and saved data for frame 1785
#   - Processed and saved data for frame 1800
#   - Processed and saved data for frame 1815
#   - Processed and saved data for frame 1830
#   - Processed and saved data for frame 1845
#   - Processed and saved data for frame 1860
#   - Processed and saved data for frame 1875
#   - Processed and saved data for frame 1890
#   - Processed and saved data for frame 1905
#   - Processed and saved data for frame 1920
#   - Processed and saved data for frame 1935
#   - Processed and saved data for frame 1950
#   - Processed and saved data for frame 1965
#   - Processed and saved data for frame 1980
#   - Processed and saved data for frame 1995
#   - Processed and saved data for frame 2010
#   - Processed and saved data for frame 2025
#   - Processed and saved data for frame 2040
#   - Processed and saved data for frame 2055
#   - Processed and saved data for frame 2070
#   - Processed and saved data for frame 2085
#   - Processed and saved data for frame 2100
#   - Processed and saved data for frame 2115
#   - Processed and saved data for frame 2130
#   - Processed and saved data for frame 2145
#   - Processed and saved data for frame 2160
#   - Processed and saved data for frame 2175
#   - Processed and saved data for frame 2190
#   - Processed and saved data for frame 2205
#   - Processed and saved data for frame 2220
#   - Processed and saved data for frame 2235
#   - Processed and saved data for frame 2250
#   - Processed and saved data for frame 2265
#   - Processed and saved data for frame 2280
#   - Processed and saved data for frame 2295
#   - Processed and saved data for frame 2310
#   - Processed and saved data for frame 2325
#   - Processed and saved data for frame 2340
#   - Processed and saved data for frame 2355
#   - Processed and saved data for frame 2370
#   - Processed and saved data for frame 2385
#   - Processed and saved data for frame 2400
#   - Processed and saved data for frame 2415
#   - Processed and saved data for frame 2430
#   - Processed and saved data for frame 2445
#   - Processed and saved data for frame 2460
#   - Processed and saved data for frame 2475
#   - Processed and saved data for frame 2490
#   - Processed and saved data for frame 2505
#   - Processed and saved data for frame 2520
#   - Processed and saved data for frame 2535
#   - Processed and saved data for frame 2550
#   - Processed and saved data for frame 2565
#   - Processed and saved data for frame 2580
#   - Processed and saved data for frame 2595
#   - Processed and saved data for frame 2610
#   - Processed and saved data for frame 2625
#   - Processed and saved data for frame 2640
#   - Processed and saved data for frame 2655
#   - Processed and saved data for frame 2670
#   - Processed and saved data for frame 2685
#   - Processed and saved data for frame 2700
#   - Processed and saved data for frame 2715
#   - Processed and saved data for frame 2730
#   - Processed and saved data for frame 2745
#   - Processed and saved data for frame 2760
#   - Processed and saved data for frame 2775
#   - Processed and saved data for frame 2790
#   - Processed and saved data for frame 2805
#   - Processed and saved data for frame 2820
#   - Processed and saved data for frame 2835
#   - Processed and saved data for frame 2850
#   - Processed and saved data for frame 2865
#   - Processed and saved data for frame 2880
#   - Processed and saved data for frame 2895
#   - Processed and saved data for frame 2910
#   - Processed and saved data for frame 2925
#   - Processed and saved data for frame 2940
#   - Processed and saved data for frame 2955
#   - Processed and saved data for frame 2970
#   - Processed and saved data for frame 2985
#   - Processed and saved data for frame 3000
#   - Processed and saved data for frame 3015
#   - Processed and saved data for frame 3030
#   - Processed and saved data for frame 3045
#   - Processed and saved data for frame 3060
#   - Processed and saved data for frame 3075
#   - Processed and saved data for frame 3090
#   - Processed and saved data for frame 3105
#   - Processed and saved data for frame 3120
#   - Processed and saved data for frame 3135
#   - Processed and saved data for frame 3150
#   - Processed and saved data for frame 3165
#   - Processed and saved data for frame 3180
#   - Processed and saved data for frame 3195
#   - Processed and saved data for frame 3210
#   - Processed and saved data for frame 3225
#   - Processed and saved data for frame 3240
#   - Processed and saved data for frame 3255
#   - Processed and saved data for frame 3270
#   - Processed and saved data for frame 3285
#   - Processed and saved data for frame 3300
#   - Processed and saved data for frame 3315
#   - Processed and saved data for frame 3330
#   - Processed and saved data for frame 3345
#   - Processed and saved data for frame 3360
#   - Processed and saved data for frame 3375
#   - Processed and saved data for frame 3390
#   - Processed and saved data for frame 3405
#   - Processed and saved data for frame 3420
#   - Processed and saved data for frame 3435
#   - Processed and saved data for frame 3450
#   - Processed and saved data for frame 3465
#   - Processed and saved data for frame 3480
#   - Processed and saved data for frame 3495
#   - Processed and saved data for frame 3510
#   - Processed and saved data for frame 3525
#   - Processed and saved data for frame 3540
#   - Processed and saved data for frame 3555
#   - Processed and saved data for frame 3570
#   - Processed and saved data for frame 3585
#   - Processed and saved data for frame 3600
#   - Processed and saved data for frame 3615
#   - Processed and saved data for frame 3630
#   - Processed and saved data for frame 3645
#   - Processed and saved data for frame 3660
#   - Processed and saved data for frame 3675
#   - Processed and saved data for frame 3690
#   - Processed and saved data for frame 3705
#   - Processed and saved data for frame 3720
#   - Processed and saved data for frame 3735
#   - Processed and saved data for frame 3750
#   - Processed and saved data for frame 3765
#   - Processed and saved data for frame 3780
#   - Processed and saved data for frame 3795
#   - Processed and saved data for frame 3810
#   - Processed and saved data for frame 3825
#   - Processed and saved data for frame 3840
#   - Processed and saved data for frame 3855
#   - Processed and saved data for frame 3870
#   - Processed and saved data for frame 3885
#   - Processed and saved data for frame 3900
#   - Processed and saved data for frame 3915
#   - Processed and saved data for frame 3930
#   - Processed and saved data for frame 3945
#   - Processed and saved data for frame 3960
#   - Processed and saved data for frame 3975
#   - Processed and saved data for frame 3990
#   - Processed and saved data for frame 4005
#   - Processed and saved data for frame 4020
#   - Processed and saved data for frame 4035
#   - Processed and saved data for frame 4050
#   - Processed and saved data for frame 4065
#   - Processed and saved data for frame 4080
#   - Processed and saved data for frame 4095
#   - Processed and saved data for frame 4110
#   - Processed and saved data for frame 4125
#   - Processed and saved data for frame 4140
#   - Processed and saved data for frame 4155
#   - Processed and saved data for frame 4170
#   - Processed and saved data for frame 4185
#   - Processed and saved data for frame 4200
#   - Processed and saved data for frame 4215
#   - Processed and saved data for frame 4230
#   - Processed and saved data for frame 4245
#   - Processed and saved data for frame 4260
#   - Processed and saved data for frame 4275
#   - Processed and saved data for frame 4290
#   - Processed and saved data for frame 4305
#   - Processed and saved data for frame 4320
#   - Processed and saved data for frame 4335
#   - Processed and saved data for frame 4350
#   - Processed and saved data for frame 4365
#   - Processed and saved data for frame 4380
#   - Processed and saved data for frame 4395
#   - Processed and saved data for frame 4410
#   - Processed and saved data for frame 4425
#   - Processed and saved data for frame 4440
#   - Processed and saved data for frame 4455
#   - Processed and saved data for frame 4470
#   - Processed and saved data for frame 4485
#   - Processed and saved data for frame 4500
#   - Processed and saved data for frame 4515
#   - Processed and saved data for frame 4530
#   - Processed and saved data for frame 4545
#   - Processed and saved data for frame 4560
#   - Processed and saved data for frame 4575
#   - Processed and saved data for frame 4590
#   - Processed and saved data for frame 4605
#   - Processed and saved data for frame 4620
#   - Processed and saved data for frame 4635
#   - Processed and saved data for frame 4650
#   - Processed and saved data for frame 4665
#   - Processed and saved data for frame 4680
#   - Processed and saved data for frame 4695
#   - Processed and saved data for frame 4710
#   - Processed and saved data for frame 4725
#   - Processed and saved data for frame 4740
#   - Processed and saved data for frame 4755
#   - Processed and saved data for frame 4770
#   - Processed and saved data for frame 4785
#   - Processed and saved data for frame 4800
#   - Processed and saved data for frame 4815
#   - Processed and saved data for frame 4830
#   - Processed and saved data for frame 4845
#   - Processed and saved data for frame 4860
#   - Processed and saved data for frame 4875
#   - Processed and saved data for frame 4890
#   - Processed and saved data for frame 4905
#   - Processed and saved data for frame 4920
#   - Processed and saved data for frame 4935
#   - Processed and saved data for frame 4950
#   - Processed and saved data for frame 4965
#   - Processed and saved data for frame 4980
#   - Processed and saved data for frame 4995
#   - Processed and saved data for frame 5010
#   - Processed and saved data for frame 5025
#   - Processed and saved data for frame 5040
#   - Processed and saved data for frame 5055
#   - Processed and saved data for frame 5070
#   - Processed and saved data for frame 5085
#   - Processed and saved data for frame 5100
#   - Processed and saved data for frame 5115
#   - Processed and saved data for frame 5130
#   - Processed and saved data for frame 5145
#   - Processed and saved data for frame 5160
#   - Processed and saved data for frame 5175
#   - Processed and saved data for frame 5190
#   - Processed and saved data for frame 5205
#   - Processed and saved data for frame 5220
#   - Processed and saved data for frame 5235
#   - Processed and saved data for frame 5250
#   - Processed and saved data for frame 5265
#   - Processed and saved data for frame 5280
#   - Processed and saved data for frame 5295
#   - Processed and saved data for frame 5310
#   - Processed and saved data for frame 5325
#   - Processed and saved data for frame 5340
#   - Processed and saved data for frame 5355
#   - Processed and saved data for frame 5370
#   - Processed and saved data for frame 5385
#   - Processed and saved data for frame 5400
#   - Processed and saved data for frame 5415
#   - Processed and saved data for frame 5430
#   - Processed and saved data for frame 5445
#   - Processed and saved data for frame 5460
#   - Processed and saved data for frame 5475
#   - Processed and saved data for frame 5490
#   - Processed and saved data for frame 5505
#   - Processed and saved data for frame 5520
#   - Processed and saved data for frame 5535
#   - Processed and saved data for frame 5550
#   - Processed and saved data for frame 5565
#   - Processed and saved data for frame 5580
#   - Processed and saved data for frame 5595
#   - Processed and saved data for frame 5610
#   - Processed and saved data for frame 5625
#   - Processed and saved data for frame 5640
#   - Processed and saved data for frame 5655
#   - Processed and saved data for frame 5670
#   - Processed and saved data for frame 5685
#   - Processed and saved data for frame 5700
#   - Processed and saved data for frame 5715
#   - Processed and saved data for frame 5730
#   - Processed and saved data for frame 5745
#   - Processed and saved data for frame 5760
#   - Processed and saved data for frame 5775
#   - Processed and saved data for frame 5790
#   - Processed and saved data for frame 5805
#   - Processed and saved data for frame 5820
#   - Processed and saved data for frame 5835
#   - Processed and saved data for frame 5850
#   - Processed and saved data for frame 5865
#   - Processed and saved data for frame 5880
#   - Processed and saved data for frame 5895
#   - Processed and saved data for frame 5910
#   - Processed and saved data for frame 5925
#   - Processed and saved data for frame 5940
#   - Processed and saved data for frame 5955
#   - Processed and saved data for frame 5970
#   - Processed and saved data for frame 5985
#   - Processed and saved data for frame 6000
#   - Processed and saved data for frame 6015
#   - Processed and saved data for frame 6030
#   - Processed and saved data for frame 6045
#   - Processed and saved data for frame 6060
#   - Processed and saved data for frame 6075
#   - Processed and saved data for frame 6090
#   - Processed and saved data for frame 6105
#   - Processed and saved data for frame 6120
#   - Processed and saved data for frame 6135
#   - Processed and saved data for frame 6150
#   - Processed and saved data for frame 6165
#   - Processed and saved data for frame 6180
#   - Processed and saved data for frame 6195
#   - Processed and saved data for frame 6210
#   - Processed and saved data for frame 6225
#   - Processed and saved data for frame 6240
#   - Processed and saved data for frame 6255
#   - Processed and saved data for frame 6270
#   - Processed and saved data for frame 6285
#   - Processed and saved data for frame 6300
#   - Processed and saved data for frame 6315
#   - Processed and saved data for frame 6330
#   - Processed and saved data for frame 6345
#   - Processed and saved data for frame 6360
#   - Processed and saved data for frame 6375
#   - Processed and saved data for frame 6390
#   - Processed and saved data for frame 6405
#   - Processed and saved data for frame 6420
#   - Processed and saved data for frame 6435
#   - Processed and saved data for frame 6450
#   - Processed and saved data for frame 6465
#   - Processed and saved data for frame 6480
#   - Processed and saved data for frame 6495
#   - Processed and saved data for frame 6510
#   - Processed and saved data for frame 6525
#   - Processed and saved data for frame 6540
#   - Processed and saved data for frame 6555
#   - Processed and saved data for frame 6570
#   - Processed and saved data for frame 6585
#   - Processed and saved data for frame 6600
#   - Processed and saved data for frame 6615
#   - Processed and saved data for frame 6630
#   - Processed and saved data for frame 6645
#   - Processed and saved data for frame 6660
#   - Processed and saved data for frame 6675
#   - Processed and saved data for frame 6690
#   - Processed and saved data for frame 6705
#   - Processed and saved data for frame 6720
#   - Processed and saved data for frame 6735
#   - Processed and saved data for frame 6750
#   - Processed and saved data for frame 6765
#   - Processed and saved data for frame 6780
#   - Processed and saved data for frame 6795
#   - Processed and saved data for frame 6810
#   - Processed and saved data for frame 6825
#   - Processed and saved data for frame 6840
#   - Processed and saved data for frame 6855
#   - Processed and saved data for frame 6870
#   - Processed and saved data for frame 6885
#   - Processed and saved data for frame 6900
#   - Processed and saved data for frame 6915
#   - Processed and saved data for frame 6930
#   - Processed and saved data for frame 6945
#   - Processed and saved data for frame 6960
#   - Processed and saved data for frame 6975
#   - Processed and saved data for frame 6990
#   - Processed and saved data for frame 7005
#   - Processed and saved data for frame 7020
#   - Processed and saved data for frame 7035
#   - Processed and saved data for frame 7050
#   - Processed and saved data for frame 7065
#   - Processed and saved data for frame 7080
#   - Processed and saved data for frame 7095
#   - Processed and saved data for frame 7110
#   - Processed and saved data for frame 7125
#   - Processed and saved data for frame 7140
#   - Processed and saved data for frame 7155
#   - Processed and saved data for frame 7170
#   - Processed and saved data for frame 7185
#   - Processed and saved data for frame 7200
#   - Processed and saved data for frame 7215
#   - Processed and saved data for frame 7230
#   - Processed and saved data for frame 7245
#   - Processed and saved data for frame 7260
#   - Processed and saved data for frame 7275
#   - Processed and saved data for frame 7290
#   - Processed and saved data for frame 7305
#   - Processed and saved data for frame 7320
#   - Processed and saved data for frame 7335
#   - Processed and saved data for frame 7350
#   - Processed and saved data for frame 7365
#   - Processed and saved data for frame 7380
#   - Processed and saved data for frame 7395
#   - Processed and saved data for frame 7410
#   - Processed and saved data for frame 7425
#   - Processed and saved data for frame 7440
#   - Processed and saved data for frame 7455
#   - Processed and saved data for frame 7470
#   - Processed and saved data for frame 7485
#   - Processed and saved data for frame 7500
#   - Processed and saved data for frame 7515
#   - Processed and saved data for frame 7530
#   - Processed and saved data for frame 7545
#   - Processed and saved data for frame 7560
#   - Processed and saved data for frame 7575
#   - Processed and saved data for frame 7590
#   - Processed and saved data for frame 7605
#   - Processed and saved data for frame 7620
#   - Processed and saved data for frame 7635
#   - Processed and saved data for frame 7650
#   - Processed and saved data for frame 7665
#   - Processed and saved data for frame 7680
#   - Processed and saved data for frame 7695
#   - Processed and saved data for frame 7710
#   - Processed and saved data for frame 7725
#   - Processed and saved data for frame 7740
#   - Processed and saved data for frame 7755
#   - Processed and saved data for frame 7770
#   - Processed and saved data for frame 7785
#   - Processed and saved data for frame 7800
#   - Processed and saved data for frame 7815
#   - Processed and saved data for frame 7830
#   - Processed and saved data for frame 7845
#   - Processed and saved data for frame 7860
#   - Processed and saved data for frame 7875
#   - Processed and saved data for frame 7890
#   - Processed and saved data for frame 7905
#   - Processed and saved data for frame 7920
#   - Processed and saved data for frame 7935
#   - Processed and saved data for frame 7950
#   - Processed and saved data for frame 7965
#   - Processed and saved data for frame 7980
#   - Processed and saved data for frame 7995
#   - Processed and saved data for frame 8010
#   - Processed and saved data for frame 8025
#   - Processed and saved data for frame 8040
#   - Processed and saved data for frame 8055
#   - Processed and saved data for frame 8070
#   - Processed and saved data for frame 8085
#   - Processed and saved data for frame 8100
#   - Processed and saved data for frame 8115
#   - Processed and saved data for frame 8130
#   - Processed and saved data for frame 8145
#   - Processed and saved data for frame 8160
#   - Processed and saved data for frame 8175
#   - Processed and saved data for frame 8190
#   - Processed and saved data for frame 8205
#   - Processed and saved data for frame 8220
#   - Processed and saved data for frame 8235
#   - Processed and saved data for frame 8250
#   - Processed and saved data for frame 8265
#   - Processed and saved data for frame 8280
#   - Processed and saved data for frame 8295
#   - Processed and saved data for frame 8310
#   - Processed and saved data for frame 8325
#   - Processed and saved data for frame 8340
#   - Processed and saved data for frame 8355
#   - Processed and saved data for frame 8370
#   - Processed and saved data for frame 8385
#   - Processed and saved data for frame 8400
#   - Processed and saved data for frame 8415
#   - Processed and saved data for frame 8430
#   - Processed and saved data for frame 8445
#   - Processed and saved data for frame 8460
#   - Processed and saved data for frame 8475
#   - Processed and saved data for frame 8490
#   - Processed and saved data for frame 8505
#   - Processed and saved data for frame 8520
#   - Processed and saved data for frame 8535
#   - Processed and saved data for frame 8550
#   - Processed and saved data for frame 8565
#   - Processed and saved data for frame 8580
#   - Processed and saved data for frame 8595
#   - Processed and saved data for frame 8610
#   - Processed and saved data for frame 8625
#   - Processed and saved data for frame 8640
#   - Processed and saved data for frame 8655
#   - Processed and saved data for frame 8670
#   - Processed and saved data for frame 8685
#   - Processed and saved data for frame 8700
#   - Processed and saved data for frame 8715
#   - Processed and saved data for frame 8730
#   - Processed and saved data for frame 8745
#   - Processed and saved data for frame 8760
#   - Processed and saved data for frame 8775
#   - Processed and saved data for frame 8790
#   - Processed and saved data for frame 8805
#   - Processed and saved data for frame 8820
#   - Processed and saved data for frame 8835
#   - Processed and saved data for frame 8850
#   - Processed and saved data for frame 8865
#   - Processed and saved data for frame 8880
#   - Processed and saved data for frame 8895
#   - Processed and saved data for frame 8910
#   - Processed and saved data for frame 8925
#   - Processed and saved data for frame 8940
#
# Reached end of video.
#
# --- Dataset Creation Finished! ---
# Total time taken: 811.02 seconds.
# Dataset saved in folder: 'street_dataset'

# %%
# ==============================================================================
# SCRIPT: create_apf_video.py
# ==============================================================================
# PURPOSE: To read the entire processed dataset (images, obstacles, depth)
#          and create a final video simulation showing the APF algorithm in action.
# ==============================================================================

import cv2
import os
import numpy as np
import json
import glob # يُستخدم للبحث عن كل الملفات في مجلد

def main():
    """Main function to run the video creation script."""

    # ==========================================================================
    # 1. SETTINGS
    # ==========================================================================

    # --- مجلد مجموعة البيانات المُدخلة ---
    DATASET_FOLDER = "C:/Users/ace/street_dataset"
    IMAGE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/images")
    OBSTACLE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/obstacles_json")
    
    # --- إعدادات الفيديو الناتج ---
    OUTPUT_FOLDER = "output_final_videos"
    os.makedirs(OUTPUT_FOLDER, exist_ok=True)
    OUTPUT_VIDEO_FILENAME = os.path.join(OUTPUT_FOLDER, "apf_simulation_video.mp4")
    
    # --- متغيرات خوارزمية APF ---
    ATTRACTIVE_FORCE_GAIN = 1.0 
    REPULSIVE_FORCE_GAIN = 200000.0 
    OBSTACLE_INFLUENCE_RADIUS = 200

    # ==========================================================================
    # 2. البحث عن كل الإطارات المعالجة وترتيبها
    # ==========================================================================
    
    # البحث عن كل ملفات الصور في مجموعة البيانات
    image_files = sorted(glob.glob(os.path.join(IMAGE_FOLDER, "*.jpg")))
    
    if not image_files:
        print(f"!!! خطأ: لم يتم العثور على صور في المجلد '{IMAGE_FOLDER}'.")
        print("يرجى تشغيل سكربت 'prepare_dataset.py' أولاً.")
        return
        
    print(f"تم العثور على {len(image_files)} إطارًا معالجًا. بدء إنشاء الفيديو...")

    # ==========================================================================
    # 3. إعداد كائن كتابة الفيديو
    # ==========================================================================

    # الحصول على الأبعاد من أول صورة
    first_frame = cv2.imread(image_files[0])
    height, width, _ = first_frame.shape
    
    # تحديد الكوديك وإنشاء كائن VideoWriter
    # 'mp4v' هو كوديك شائع لملفات .mp4
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') 
    # إنشاء كائن كتابة الفيديو بمعدل 10 إطارات في الثانية
    video_writer = cv2.VideoWriter(OUTPUT_VIDEO_FILENAME, fourcc, 10.0, (width, height))


    # ==========================================================================
    # 4. المرور على كل إطار، تطبيق APF، والكتابة في الفيديو
    # ==========================================================================
    
    for image_filepath in image_files:
        
        # --- تحميل البيانات للإطار الحالي ---
        base_filename = os.path.splitext(os.path.basename(image_filepath))[0]
        obstacle_filepath = os.path.join(OBSTACLE_FOLDER, f"{base_filename}.json")
        
        print(f"  - جاري معالجة {base_filename}")
        
        frame = cv2.imread(image_filepath)
        try:
            with open(obstacle_filepath, 'r') as f:
                obstacles_data = json.load(f)
        except FileNotFoundError:
            print(f"    - تحذير: ملف العقبات غير موجود لـ {base_filename}. سيتم تخطي الإطار.")
            continue

        # --- تطبيق خوارزمية APF ---
        
        # تعريف مواقع الروبوت والهدف
        robot_position = np.array([width / 2, height - 1]) 
        goal_position = np.array([width / 2, 0])
        
        # حساب القوة الجاذبة
        attractive_force = ATTRACTIVE_FORCE_GAIN * (goal_position - robot_position)
        
        # حساب القوة الطاردة
        total_repulsive_force = np.array([0.0, 0.0])
        for obs in obstacles_data:
            x, y, w, h = obs['box']
            obstacle_center = np.array([x + w / 2, y + h / 2])
            distance_to_obstacle = np.linalg.norm(robot_position - obstacle_center)
            
            if distance_to_obstacle > OBSTACLE_INFLUENCE_RADIUS or distance_to_obstacle == 0:
                continue
            
            repulsive_force = REPULSIVE_FORCE_GAIN * (1.0 / distance_to_obstacle - 1.0 / OBSTACLE_INFLUENCE_RADIUS) * \
                               (1.0 / distance_to_obstacle**2) * \
                               (robot_position - obstacle_center) / distance_to_obstacle
            total_repulsive_force += repulsive_force

        # حساب القوة النهائية
        final_force = attractive_force + total_repulsive_force
        final_direction = final_force / (np.linalg.norm(final_force) + 1e-6)

        # --- عرض النتيجة على الإطار ---
        
        # رسم العقبات
        for obs in obstacles_data:
            x, y, w, h = obs['box']
            obstacle_center = (int(x + w/2), int(y + h/2))
            cv2.circle(frame, obstacle_center, 20, (0, 0, 255), 2) # دائرة حمراء

        # رسم الروبوت والهدف
        cv2.circle(frame, tuple(robot_position.astype(int)), 15, (255, 0, 0), -1) # دائرة زرقاء
        cv2.circle(frame, tuple(goal_position.astype(int)), 15, (0, 255, 0), -1) # دائرة خضراء
        
        # رسم سهم الاتجاه
        arrow_end_point = robot_position + final_direction * 100
        cv2.arrowedLine(frame, tuple(robot_position.astype(int)), tuple(arrow_end_point.astype(int)), 
                        (0, 255, 255), 4, tipLength=0.4) # سهم أصفر

        # --- كتابة الإطار المعالج في ملف الفيديو ---
        video_writer.write(frame)

    # ==========================================================================
    # 5. الإنهاء والتنظيف
    # ==========================================================================
    
    # تحرير كائن كتابة الفيديو
    video_writer.release()
    print(f"\nنجاح! تم حفظ فيديو المحاكاة في: {OUTPUT_VIDEO_FILENAME}")

# تشغيل الدالة الرئيسية
if __name__ == '__main__':
    main()
# Out:
# تم العثور على 597 إطارًا معالجًا. بدء إنشاء الفيديو...
#   - جاري معالجة frame_00000
#   - جاري معالجة frame_00015
#   - جاري معالجة frame_00030
#   - جاري معالجة frame_00045
#   - جاري معالجة frame_00060
#   - جاري معالجة frame_00075
#   - جاري معالجة frame_00090
#   - جاري معالجة frame_00105
#   - جاري معالجة frame_00120
#   - جاري معالجة frame_00135
#   - جاري معالجة frame_00150
#   - جاري معالجة frame_00165
#   - جاري معالجة frame_00180
#   - جاري معالجة frame_00195
#   - جاري معالجة frame_00210
#   - جاري معالجة frame_00225
#   - جاري معالجة frame_00240
#   - جاري معالجة frame_00255
#   - جاري معالجة frame_00270
#   - جاري معالجة frame_00285
#   - جاري معالجة frame_00300
#   - جاري معالجة frame_00315
#   - جاري معالجة frame_00330
#   - جاري معالجة frame_00345
#   - جاري معالجة frame_00360
#   - جاري معالجة frame_00375
#   - جاري معالجة frame_00390
#   - جاري معالجة frame_00405
#   - جاري معالجة frame_00420
#   - جاري معالجة frame_00435
#   - جاري معالجة frame_00450
#   - جاري معالجة frame_00465
#   - جاري معالجة frame_00480
#   - جاري معالجة frame_00495
#   - جاري معالجة frame_00510
#   - جاري معالجة frame_00525
#   - جاري معالجة frame_00540
#   - جاري معالجة frame_00555
#   - جاري معالجة frame_00570
#   - جاري معالجة frame_00585
#   - جاري معالجة frame_00600
#   - جاري معالجة frame_00615
#   - جاري معالجة frame_00630
#   - جاري معالجة frame_00645
#   - جاري معالجة frame_00660
#   - جاري معالجة frame_00675
#   - جاري معالجة frame_00690
#   - جاري معالجة frame_00705
#   - جاري معالجة frame_00720
#   - جاري معالجة frame_00735
#   - جاري معالجة frame_00750
#   - جاري معالجة frame_00765
#   - جاري معالجة frame_00780
#   - جاري معالجة frame_00795
#   - جاري معالجة frame_00810
#   - جاري معالجة frame_00825
#   - جاري معالجة frame_00840
#   - جاري معالجة frame_00855
#   - جاري معالجة frame_00870
#   - جاري معالجة frame_00885
#   - جاري معالجة frame_00900
#   - جاري معالجة frame_00915
#   - جاري معالجة frame_00930
#   - جاري معالجة frame_00945
#   - جاري معالجة frame_00960
#   - جاري معالجة frame_00975
#   - جاري معالجة frame_00990
#   - جاري معالجة frame_01005
#   - جاري معالجة frame_01020
#   - جاري معالجة frame_01035
#   - جاري معالجة frame_01050
#   - جاري معالجة frame_01065
#   - جاري معالجة frame_01080
#   - جاري معالجة frame_01095
#   - جاري معالجة frame_01110
#   - جاري معالجة frame_01125
#   - جاري معالجة frame_01140
#   - جاري معالجة frame_01155
#   - جاري معالجة frame_01170
#   - جاري معالجة frame_01185
#   - جاري معالجة frame_01200
#   - جاري معالجة frame_01215
#   - جاري معالجة frame_01230
#   - جاري معالجة frame_01245
#   - جاري معالجة frame_01260
#   - جاري معالجة frame_01275
#   - جاري معالجة frame_01290
#   - جاري معالجة frame_01305
#   - جاري معالجة frame_01320
#   - جاري معالجة frame_01335
#   - جاري معالجة frame_01350
#   - جاري معالجة frame_01365
#   - جاري معالجة frame_01380
#   - جاري معالجة frame_01395
#   - جاري معالجة frame_01410
#   - جاري معالجة frame_01425
#   - جاري معالجة frame_01440
#   - جاري معالجة frame_01455
#   - جاري معالجة frame_01470
#   - جاري معالجة frame_01485
#   - جاري معالجة frame_01500
#   - جاري معالجة frame_01515
#   - جاري معالجة frame_01530
#   - جاري معالجة frame_01545
#   - جاري معالجة frame_01560
#   - جاري معالجة frame_01575
#   - جاري معالجة frame_01590
#   - جاري معالجة frame_01605
#   - جاري معالجة frame_01620
#   - جاري معالجة frame_01635
#   - جاري معالجة frame_01650
#   - جاري معالجة frame_01665
#   - جاري معالجة frame_01680
#   - جاري معالجة frame_01695
#   - جاري معالجة frame_01710
#   - جاري معالجة frame_01725
#   - جاري معالجة frame_01740
#   - جاري معالجة frame_01755
#   - جاري معالجة frame_01770
#   - جاري معالجة frame_01785
#   - جاري معالجة frame_01800
#   - جاري معالجة frame_01815
#   - جاري معالجة frame_01830
#   - جاري معالجة frame_01845
#   - جاري معالجة frame_01860
#   - جاري معالجة frame_01875
#   - جاري معالجة frame_01890
#   - جاري معالجة frame_01905
#   - جاري معالجة frame_01920
#   - جاري معالجة frame_01935
#   - جاري معالجة frame_01950
#   - جاري معالجة frame_01965
#   - جاري معالجة frame_01980
#   - جاري معالجة frame_01995
#   - جاري معالجة frame_02010
#   - جاري معالجة frame_02025
#   - جاري معالجة frame_02040
#   - جاري معالجة frame_02055
#   - جاري معالجة frame_02070
#   - جاري معالجة frame_02085
#   - جاري معالجة frame_02100
#   - جاري معالجة frame_02115
#   - جاري معالجة frame_02130
#   - جاري معالجة frame_02145
#   - جاري معالجة frame_02160
#   - جاري معالجة frame_02175
#   - جاري معالجة frame_02190
#   - جاري معالجة frame_02205
#   - جاري معالجة frame_02220
#   - جاري معالجة frame_02235
#   - جاري معالجة frame_02250
#   - جاري معالجة frame_02265
#   - جاري معالجة frame_02280
#   - جاري معالجة frame_02295
#   - جاري معالجة frame_02310
#   - جاري معالجة frame_02325
#   - جاري معالجة frame_02340
#   - جاري معالجة frame_02355
#   - جاري معالجة frame_02370
#   - جاري معالجة frame_02385
#   - جاري معالجة frame_02400
#   - جاري معالجة frame_02415
#   - جاري معالجة frame_02430
#   - جاري معالجة frame_02445
#   - جاري معالجة frame_02460
#   - جاري معالجة frame_02475
#   - جاري معالجة frame_02490
#   - جاري معالجة frame_02505
#   - جاري معالجة frame_02520
#   - جاري معالجة frame_02535
#   - جاري معالجة frame_02550
#   - جاري معالجة frame_02565
#   - جاري معالجة frame_02580
#   - جاري معالجة frame_02595
#   - جاري معالجة frame_02610
#   - جاري معالجة frame_02625
#   - جاري معالجة frame_02640
#   - جاري معالجة frame_02655
#   - جاري معالجة frame_02670
#   - جاري معالجة frame_02685
#   - جاري معالجة frame_02700
#   - جاري معالجة frame_02715
#   - جاري معالجة frame_02730
#   - جاري معالجة frame_02745
#   - جاري معالجة frame_02760
#   - جاري معالجة frame_02775
#   - جاري معالجة frame_02790
#   - جاري معالجة frame_02805
#   - جاري معالجة frame_02820
#   - جاري معالجة frame_02835
#   - جاري معالجة frame_02850
#   - جاري معالجة frame_02865
#   - جاري معالجة frame_02880
#   - جاري معالجة frame_02895
#   - جاري معالجة frame_02910
#   - جاري معالجة frame_02925
#   - جاري معالجة frame_02940
#   - جاري معالجة frame_02955
#   - جاري معالجة frame_02970
#   - جاري معالجة frame_02985
#   - جاري معالجة frame_03000
#   - جاري معالجة frame_03015
#   - جاري معالجة frame_03030
#   - جاري معالجة frame_03045
#   - جاري معالجة frame_03060
#   - جاري معالجة frame_03075
#   - جاري معالجة frame_03090
#   - جاري معالجة frame_03105
#   - جاري معالجة frame_03120
#   - جاري معالجة frame_03135
#   - جاري معالجة frame_03150
#   - جاري معالجة frame_03165
#   - جاري معالجة frame_03180
#   - جاري معالجة frame_03195
#   - جاري معالجة frame_03210
#   - جاري معالجة frame_03225
#   - جاري معالجة frame_03240
#   - جاري معالجة frame_03255
#   - جاري معالجة frame_03270
#   - جاري معالجة frame_03285
#   - جاري معالجة frame_03300
#   - جاري معالجة frame_03315
#   - جاري معالجة frame_03330
#   - جاري معالجة frame_03345
#   - جاري معالجة frame_03360
#   - جاري معالجة frame_03375
#   - جاري معالجة frame_03390
#   - جاري معالجة frame_03405
#   - جاري معالجة frame_03420
#   - جاري معالجة frame_03435
#   - جاري معالجة frame_03450
#   - جاري معالجة frame_03465
#   - جاري معالجة frame_03480
#   - جاري معالجة frame_03495
#   - جاري معالجة frame_03510
#   - جاري معالجة frame_03525
#   - جاري معالجة frame_03540
#   - جاري معالجة frame_03555
#   - جاري معالجة frame_03570
#   - جاري معالجة frame_03585
#   - جاري معالجة frame_03600
#   - جاري معالجة frame_03615
#   - جاري معالجة frame_03630
#   - جاري معالجة frame_03645
#   - جاري معالجة frame_03660
#   - جاري معالجة frame_03675
#   - جاري معالجة frame_03690
#   - جاري معالجة frame_03705
#   - جاري معالجة frame_03720
#   - جاري معالجة frame_03735
#   - جاري معالجة frame_03750
#   - جاري معالجة frame_03765
#   - جاري معالجة frame_03780
#   - جاري معالجة frame_03795
#   - جاري معالجة frame_03810
#   - جاري معالجة frame_03825
#   - جاري معالجة frame_03840
#   - جاري معالجة frame_03855
#   - جاري معالجة frame_03870
#   - جاري معالجة frame_03885
#   - جاري معالجة frame_03900
#   - جاري معالجة frame_03915
#   - جاري معالجة frame_03930
#   - جاري معالجة frame_03945
#   - جاري معالجة frame_03960
#   - جاري معالجة frame_03975
#   - جاري معالجة frame_03990
#   - جاري معالجة frame_04005
#   - جاري معالجة frame_04020
#   - جاري معالجة frame_04035
#   - جاري معالجة frame_04050
#   - جاري معالجة frame_04065
#   - جاري معالجة frame_04080
#   - جاري معالجة frame_04095
#   - جاري معالجة frame_04110
#   - جاري معالجة frame_04125
#   - جاري معالجة frame_04140
#   - جاري معالجة frame_04155
#   - جاري معالجة frame_04170
#   - جاري معالجة frame_04185
#   - جاري معالجة frame_04200
#   - جاري معالجة frame_04215
#   - جاري معالجة frame_04230
#   - جاري معالجة frame_04245
#   - جاري معالجة frame_04260
#   - جاري معالجة frame_04275
#   - جاري معالجة frame_04290
#   - جاري معالجة frame_04305
#   - جاري معالجة frame_04320
#   - جاري معالجة frame_04335
#   - جاري معالجة frame_04350
#   - جاري معالجة frame_04365
#   - جاري معالجة frame_04380
#   - جاري معالجة frame_04395
#   - جاري معالجة frame_04410
#   - جاري معالجة frame_04425
#   - جاري معالجة frame_04440
#   - جاري معالجة frame_04455
#   - جاري معالجة frame_04470
#   - جاري معالجة frame_04485
#   - جاري معالجة frame_04500
#   - جاري معالجة frame_04515
#   - جاري معالجة frame_04530
#   - جاري معالجة frame_04545
#   - جاري معالجة frame_04560
#   - جاري معالجة frame_04575
#   - جاري معالجة frame_04590
#   - جاري معالجة frame_04605
#   - جاري معالجة frame_04620
#   - جاري معالجة frame_04635
#   - جاري معالجة frame_04650
#   - جاري معالجة frame_04665
#   - جاري معالجة frame_04680
#   - جاري معالجة frame_04695
#   - جاري معالجة frame_04710
#   - جاري معالجة frame_04725
#   - جاري معالجة frame_04740
#   - جاري معالجة frame_04755
#   - جاري معالجة frame_04770
#   - جاري معالجة frame_04785
#   - جاري معالجة frame_04800
#   - جاري معالجة frame_04815
#   - جاري معالجة frame_04830
#   - جاري معالجة frame_04845
#   - جاري معالجة frame_04860
#   - جاري معالجة frame_04875
#   - جاري معالجة frame_04890
#   - جاري معالجة frame_04905
#   - جاري معالجة frame_04920
#   - جاري معالجة frame_04935
#   - جاري معالجة frame_04950
#   - جاري معالجة frame_04965
#   - جاري معالجة frame_04980
#   - جاري معالجة frame_04995
#   - جاري معالجة frame_05010
#   - جاري معالجة frame_05025
#   - جاري معالجة frame_05040
#   - جاري معالجة frame_05055
#   - جاري معالجة frame_05070
#   - جاري معالجة frame_05085
#   - جاري معالجة frame_05100
#   - جاري معالجة frame_05115
#   - جاري معالجة frame_05130
#   - جاري معالجة frame_05145
#   - جاري معالجة frame_05160
#   - جاري معالجة frame_05175
#   - جاري معالجة frame_05190
#   - جاري معالجة frame_05205
#   - جاري معالجة frame_05220
#   - جاري معالجة frame_05235
#   - جاري معالجة frame_05250
#   - جاري معالجة frame_05265
#   - جاري معالجة frame_05280
#   - جاري معالجة frame_05295
#   - جاري معالجة frame_05310
#   - جاري معالجة frame_05325
#   - جاري معالجة frame_05340
#   - جاري معالجة frame_05355
#   - جاري معالجة frame_05370
#   - جاري معالجة frame_05385
#   - جاري معالجة frame_05400
#   - جاري معالجة frame_05415
#   - جاري معالجة frame_05430
#   - جاري معالجة frame_05445
#   - جاري معالجة frame_05460
#   - جاري معالجة frame_05475
#   - جاري معالجة frame_05490
#   - جاري معالجة frame_05505
#   - جاري معالجة frame_05520
#   - جاري معالجة frame_05535
#   - جاري معالجة frame_05550
#   - جاري معالجة frame_05565
#   - جاري معالجة frame_05580
#   - جاري معالجة frame_05595
#   - جاري معالجة frame_05610
#   - جاري معالجة frame_05625
#   - جاري معالجة frame_05640
#   - جاري معالجة frame_05655
#   - جاري معالجة frame_05670
#   - جاري معالجة frame_05685
#   - جاري معالجة frame_05700
#   - جاري معالجة frame_05715
#   - جاري معالجة frame_05730
#   - جاري معالجة frame_05745
#   - جاري معالجة frame_05760
#   - جاري معالجة frame_05775
#   - جاري معالجة frame_05790
#   - جاري معالجة frame_05805
#   - جاري معالجة frame_05820
#   - جاري معالجة frame_05835
#   - جاري معالجة frame_05850
#   - جاري معالجة frame_05865
#   - جاري معالجة frame_05880
#   - جاري معالجة frame_05895
#   - جاري معالجة frame_05910
#   - جاري معالجة frame_05925
#   - جاري معالجة frame_05940
#   - جاري معالجة frame_05955
#   - جاري معالجة frame_05970
#   - جاري معالجة frame_05985
#   - جاري معالجة frame_06000
#   - جاري معالجة frame_06015
#   - جاري معالجة frame_06030
#   - جاري معالجة frame_06045
#   - جاري معالجة frame_06060
#   - جاري معالجة frame_06075
#   - جاري معالجة frame_06090
#   - جاري معالجة frame_06105
#   - جاري معالجة frame_06120
#   - جاري معالجة frame_06135
#   - جاري معالجة frame_06150
#   - جاري معالجة frame_06165
#   - جاري معالجة frame_06180
#   - جاري معالجة frame_06195
#   - جاري معالجة frame_06210
#   - جاري معالجة frame_06225
#   - جاري معالجة frame_06240
#   - جاري معالجة frame_06255
#   - جاري معالجة frame_06270
#   - جاري معالجة frame_06285
#   - جاري معالجة frame_06300
#   - جاري معالجة frame_06315
#   - جاري معالجة frame_06330
#   - جاري معالجة frame_06345
#   - جاري معالجة frame_06360
#   - جاري معالجة frame_06375
#   - جاري معالجة frame_06390
#   - جاري معالجة frame_06405
#   - جاري معالجة frame_06420
#   - جاري معالجة frame_06435
#   - جاري معالجة frame_06450
#   - جاري معالجة frame_06465
#   - جاري معالجة frame_06480
#   - جاري معالجة frame_06495
#   - جاري معالجة frame_06510
#   - جاري معالجة frame_06525
#   - جاري معالجة frame_06540
#   - جاري معالجة frame_06555
#   - جاري معالجة frame_06570
#   - جاري معالجة frame_06585
#   - جاري معالجة frame_06600
#   - جاري معالجة frame_06615
#   - جاري معالجة frame_06630
#   - جاري معالجة frame_06645
#   - جاري معالجة frame_06660
#   - جاري معالجة frame_06675
#   - جاري معالجة frame_06690
#   - جاري معالجة frame_06705
#   - جاري معالجة frame_06720
#   - جاري معالجة frame_06735
#   - جاري معالجة frame_06750
#   - جاري معالجة frame_06765
#   - جاري معالجة frame_06780
#   - جاري معالجة frame_06795
#   - جاري معالجة frame_06810
#   - جاري معالجة frame_06825
#   - جاري معالجة frame_06840
#   - جاري معالجة frame_06855
#   - جاري معالجة frame_06870
#   - جاري معالجة frame_06885
#   - جاري معالجة frame_06900
#   - جاري معالجة frame_06915
#   - جاري معالجة frame_06930
#   - جاري معالجة frame_06945
#   - جاري معالجة frame_06960
#   - جاري معالجة frame_06975
#   - جاري معالجة frame_06990
#   - جاري معالجة frame_07005
#   - جاري معالجة frame_07020
#   - جاري معالجة frame_07035
#   - جاري معالجة frame_07050
#   - جاري معالجة frame_07065
#   - جاري معالجة frame_07080
#   - جاري معالجة frame_07095
#   - جاري معالجة frame_07110
#   - جاري معالجة frame_07125
#   - جاري معالجة frame_07140
#   - جاري معالجة frame_07155
#   - جاري معالجة frame_07170
#   - جاري معالجة frame_07185
#   - جاري معالجة frame_07200
#   - جاري معالجة frame_07215
#   - جاري معالجة frame_07230
#   - جاري معالجة frame_07245
#   - جاري معالجة frame_07260
#   - جاري معالجة frame_07275
#   - جاري معالجة frame_07290
#   - جاري معالجة frame_07305
#   - جاري معالجة frame_07320
#   - جاري معالجة frame_07335
#   - جاري معالجة frame_07350
#   - جاري معالجة frame_07365
#   - جاري معالجة frame_07380
#   - جاري معالجة frame_07395
#   - جاري معالجة frame_07410
#   - جاري معالجة frame_07425
#   - جاري معالجة frame_07440
#   - جاري معالجة frame_07455
#   - جاري معالجة frame_07470
#   - جاري معالجة frame_07485
#   - جاري معالجة frame_07500
#   - جاري معالجة frame_07515
#   - جاري معالجة frame_07530
#   - جاري معالجة frame_07545
#   - جاري معالجة frame_07560
#   - جاري معالجة frame_07575
#   - جاري معالجة frame_07590
#   - جاري معالجة frame_07605
#   - جاري معالجة frame_07620
#   - جاري معالجة frame_07635
#   - جاري معالجة frame_07650
#   - جاري معالجة frame_07665
#   - جاري معالجة frame_07680
#   - جاري معالجة frame_07695
#   - جاري معالجة frame_07710
#   - جاري معالجة frame_07725
#   - جاري معالجة frame_07740
#   - جاري معالجة frame_07755
#   - جاري معالجة frame_07770
#   - جاري معالجة frame_07785
#   - جاري معالجة frame_07800
#   - جاري معالجة frame_07815
#   - جاري معالجة frame_07830
#   - جاري معالجة frame_07845
#   - جاري معالجة frame_07860
#   - جاري معالجة frame_07875
#   - جاري معالجة frame_07890
#   - جاري معالجة frame_07905
#   - جاري معالجة frame_07920
#   - جاري معالجة frame_07935
#   - جاري معالجة frame_07950
#   - جاري معالجة frame_07965
#   - جاري معالجة frame_07980
#   - جاري معالجة frame_07995
#   - جاري معالجة frame_08010
#   - جاري معالجة frame_08025
#   - جاري معالجة frame_08040
#   - جاري معالجة frame_08055
#   - جاري معالجة frame_08070
#   - جاري معالجة frame_08085
#   - جاري معالجة frame_08100
#   - جاري معالجة frame_08115
#   - جاري معالجة frame_08130
#   - جاري معالجة frame_08145
#   - جاري معالجة frame_08160
#   - جاري معالجة frame_08175
#   - جاري معالجة frame_08190
#   - جاري معالجة frame_08205
#   - جاري معالجة frame_08220
#   - جاري معالجة frame_08235
#   - جاري معالجة frame_08250
#   - جاري معالجة frame_08265
#   - جاري معالجة frame_08280
#   - جاري معالجة frame_08295
#   - جاري معالجة frame_08310
#   - جاري معالجة frame_08325
#   - جاري معالجة frame_08340
#   - جاري معالجة frame_08355
#   - جاري معالجة frame_08370
#   - جاري معالجة frame_08385
#   - جاري معالجة frame_08400
#   - جاري معالجة frame_08415
#   - جاري معالجة frame_08430
#   - جاري معالجة frame_08445
#   - جاري معالجة frame_08460
#   - جاري معالجة frame_08475
#   - جاري معالجة frame_08490
#   - جاري معالجة frame_08505
#   - جاري معالجة frame_08520
#   - جاري معالجة frame_08535
#   - جاري معالجة frame_08550
#   - جاري معالجة frame_08565
#   - جاري معالجة frame_08580
#   - جاري معالجة frame_08595
#   - جاري معالجة frame_08610
#   - جاري معالجة frame_08625
#   - جاري معالجة frame_08640
#   - جاري معالجة frame_08655
#   - جاري معالجة frame_08670
#   - جاري معالجة frame_08685
#   - جاري معالجة frame_08700
#   - جاري معالجة frame_08715
#   - جاري معالجة frame_08730
#   - جاري معالجة frame_08745
#   - جاري معالجة frame_08760
#   - جاري معالجة frame_08775
#   - جاري معالجة frame_08790
#   - جاري معالجة frame_08805
#   - جاري معالجة frame_08820
#   - جاري معالجة frame_08835
#   - جاري معالجة frame_08850
#   - جاري معالجة frame_08865
#   - جاري معالجة frame_08880
#   - جاري معالجة frame_08895
#   - جاري معالجة frame_08910
#   - جاري معالجة frame_08925
#   - جاري معالجة frame_08940
#
# نجاح! تم حفظ فيديو المحاكاة في: output_final_videos\apf_simulation_video.mp4

# %%
# ==============================================================================
# SCRIPT: create_3d_apf_video.py
# ==============================================================================
# PURPOSE: To create an ACCURATE simulation using a 3D Artificial Potential Field.
#          It uses the saved depth data to project obstacles into a real-world
#          coordinate system before calculating forces.
# ==============================================================================

import cv2
import os
import numpy as np
import json
import glob

def main():
    """Main function to run the 3D APF video creation script."""

    # ==========================================================================
    # 1. SETTINGS
    # ==========================================================================

    # --- Input Dataset Folder ---
    DATASET_FOLDER = "C:/Users/ace/street_dataset"
    IMAGE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/images")
    OBSTACLE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/obstacles_json")
    DEPTH_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/depth_maps_npy")
    
    # --- Output Video Settings ---
    OUTPUT_FOLDER = "output_final_videos"
    os.makedirs(OUTPUT_FOLDER, exist_ok=True)
    OUTPUT_VIDEO_FILENAME = os.path.join(OUTPUT_FOLDER, "apf_simulation_3D_accurate.mp4")
    
    # --- Camera and Image Settings ---
    PROCESSING_WIDTH = 480
    HORIZONTAL_FIELD_OF_VIEW = 60 # degrees

    # --- APF Algorithm Parameters (Now in Meters) ---
    ATTRACTIVE_FORCE_GAIN = 1.0
    REPULSIVE_FORCE_GAIN = 2.0  # Tuned for real-world meters
    OBSTACLE_INFLUENCE_RADIUS_M = 5.0 # Obstacles further than 5m have no effect

    # ==========================================================================
    # 2. FIND AND SORT ALL PROCESSED FRAMES
    # ==========================================================================
    
    image_files = sorted(glob.glob(os.path.join(IMAGE_FOLDER, "*.jpg")))
    if not image_files:
        print(f"!!! ERROR: No images found in '{IMAGE_FOLDER}'.")
        return
        
    print(f"Found {len(image_files)} frames. Starting accurate 3D simulation video...")

    # ==========================================================================
    # 3. SETUP VIDEO WRITER
    # ==========================================================================
    first_frame = cv2.imread(image_files[0])
    height, width, _ = first_frame.shape
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') 
    video_writer = cv2.VideoWriter(OUTPUT_VIDEO_FILENAME, fourcc, 10.0, (width, height))

    # Calculate camera focal length from FOV (approximation)
    FOCAL_LENGTH = (width / 2) / np.tan(np.deg2rad(HORIZONTAL_FIELD_OF_VIEW / 2))

    # ==========================================================================
    # 4. MAIN LOOP
    # ==========================================================================
    
    for image_filepath in image_files:
        
        base_filename = os.path.splitext(os.path.basename(image_filepath))[0]
        obstacle_filepath = os.path.join(OBSTACLE_FOLDER, f"{base_filename}.json")
        depth_filepath = os.path.join(DEPTH_FOLDER, f"{base_filename}.npy")
        
        print(f"  - Processing {base_filename}")
        
        frame = cv2.imread(image_filepath)
        try:
            with open(obstacle_filepath, 'r') as f:
                obstacles_data = json.load(f)
            depth_map = np.load(depth_filepath)
        except FileNotFoundError:
            print(f"    - Warning: Data file not found for {base_filename}. Skipping.")
            continue

        # --- Apply 3D APF Algorithm ---
        
        # Define Robot and Goal in real-world 3D space (X, Z)
        # Robot is at the origin (0, 0)
        robot_position_3d = np.array([0.0, 0.0]) 
        # Goal is 10 meters straight ahead
        goal_position_3d = np.array([0.0, 10.0]) 
        
        # --- Calculate Attractive Force in 3D ---
        attractive_force_3d = ATTRACTIVE_FORCE_GAIN * (goal_position_3d - robot_position_3d)
        
        # --- Calculate Repulsive Force in 3D ---
        total_repulsive_force_3d = np.array([0.0, 0.0])
        
        projected_obstacles_3d = [] # For visualization
        
        for obs in obstacles_data:
            x, y, w, h = obs['box']
            center_x_px, center_y_px = int(x + w/2), int(y + h/2)
            
            # Get depth from depth map. MiDaS output is inverse depth.
            inverse_depth = depth_map[center_y_px, center_x_px]
            real_depth_z = 1.0 / (inverse_depth + 1e-6) # Z-coordinate in meters

            # Convert pixel x-coordinate to real-world x-coordinate
            real_x = (center_x_px - width/2) * real_depth_z / FOCAL_LENGTH
            
            obstacle_position_3d = np.array([real_x, real_depth_z])
            projected_obstacles_3d.append(obstacle_position_3d) # Save for drawing

            # Calculate distance in meters
            distance_to_obstacle_m = np.linalg.norm(robot_position_3d - obstacle_position_3d)
            
            if distance_to_obstacle_m > OBSTACLE_INFLUENCE_RADIUS_M or distance_to_obstacle_m == 0:
                continue
            
            # Calculate repulsive force using real-world distances
            repulsive_force_3d = REPULSIVE_FORCE_GAIN * \
                                 (1.0 / distance_to_obstacle_m - 1.0 / OBSTACLE_INFLUENCE_RADIUS_M) * \
                                 (1.0 / distance_to_obstacle_m**2) * \
                                 (robot_position_3d - obstacle_position_3d) / distance_to_obstacle_m
            
            total_repulsive_force_3d += repulsive_force_3d

        # --- Calculate Final Force in 3D ---
        final_force_3d = attractive_force_3d + total_repulsive_force_3d
        final_direction_3d = final_force_3d / (np.linalg.norm(final_force_3d) + 1e-6)

        # --- Project the 3D direction vector back to 2D for visualization ---
        # We take the X and Z components of the direction and map them to the image plane
        direction_x_2d = final_direction_3d[0] * FOCAL_LENGTH
        direction_y_2d = -final_direction_3d[1] * 50 # Heuristic to point down/up
        final_direction_2d = np.array([direction_x_2d, direction_y_2d])
        final_direction_2d = final_direction_2d / (np.linalg.norm(final_direction_2d) + 1e-6)

        # --- Visualize the result on the frame ---
        
        # Draw obstacles
        for obs in obstacles_data:
             x, y, w, h = obs['box']
             cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 2)

        # Draw direction arrow
        robot_pos_2d = (int(width/2), height - 1)
        arrow_end_point = (int(robot_pos_2d[0] + final_direction_2d[0] * 150), 
                           int(robot_pos_2d[1] + final_direction_2d[1] * 150))
        cv2.arrowedLine(frame, robot_pos_2d, arrow_end_point, (0, 255, 255), 5, tipLength=0.4)

        # Write the visualized frame to the video file
        video_writer.write(frame)

    # ==========================================================================
    # 5. FINISH AND CLEAN UP
    # ==========================================================================
    
    video_writer.release()
    print(f"\nSUCCESS! Accurate 3D simulation video saved to: {OUTPUT_VIDEO_FILENAME}")

# Run the main function
if __name__ == '__main__':
    main()
# Out:
# Found 597 frames. Starting accurate 3D simulation video...
#   - Processing frame_00000
#   - Processing frame_00015
#   - Processing frame_00030
#   - Processing frame_00045
#   - Processing frame_00060
#   - Processing frame_00075
#   - Processing frame_00090
#   - Processing frame_00105
#   - Processing frame_00120
#   - Processing frame_00135
#   - Processing frame_00150
#   - Processing frame_00165
#   - Processing frame_00180
#   - Processing frame_00195
#   - Processing frame_00210
#   - Processing frame_00225
#   - Processing frame_00240
#   - Processing frame_00255
#   - Processing frame_00270
#   - Processing frame_00285
#   - Processing frame_00300
#   - Processing frame_00315
#   - Processing frame_00330
#   - Processing frame_00345
#   - Processing frame_00360
#   - Processing frame_00375
#   - Processing frame_00390
#   - Processing frame_00405
#   - Processing frame_00420
#   - Processing frame_00435
#   - Processing frame_00450
#   - Processing frame_00465
#   - Processing frame_00480
#   - Processing frame_00495
#   - Processing frame_00510
#   - Processing frame_00525
#   - Processing frame_00540
#   - Processing frame_00555
#   - Processing frame_00570
#   - Processing frame_00585
#   - Processing frame_00600
#   - Processing frame_00615
#   - Processing frame_00630
#   - Processing frame_00645
#   - Processing frame_00660
#   - Processing frame_00675
#   - Processing frame_00690
#   - Processing frame_00705
#   - Processing frame_00720
#   - Processing frame_00735
#   - Processing frame_00750
#   - Processing frame_00765
#   - Processing frame_00780
#   - Processing frame_08490
#   - Processing frame_08505
#   - Processing frame_08520
#   - Processing frame_08535
#   - Processing frame_08550
#   - Processing frame_08565
#   - Processing frame_08580
#   - Processing frame_08595
#   - Processing frame_08610
#   - Processing frame_08625
#   - Processing frame_08640
#   - Processing frame_08655
#   - Processing frame_08670
#   - Processing frame_08685
#   - Processing frame_08700
#   - Processing frame_08715
#   - Processing frame_08730
#   - Processing frame_08745
#   - Processing frame_08760
#   - Processing frame_08775
#   - Processing frame_08790
#   - Processing frame_08805
#   - Processing frame_08820
#   - Processing frame_08835
#   - Processing frame_08850
#   - Processing frame_08865
#   - Processing frame_08880
#   - Processing frame_08895
#   - Processing frame_08910
#   - Processing frame_08925
#   - Processing frame_08940
#
# SUCCESS! Accurate 3D simulation video saved to: output_final_videos\apf_simulation_3D_accurate.mp4

# %%
# ==============================================================================
# SCRIPT: create_professional_apf_video.py (Corrected)
# ==============================================================================
# PURPOSE: To create a professional and accurate simulation video with:
#          1. Labeled obstacles.
#          2. A formal, projected path line on the ground.
# ==============================================================================

import cv2
import os
import numpy as np
import json
import glob

def main():
    """Main function to run the professional video creation script."""

    # ==========================================================================
    # 1. SETTINGS
    # ==========================================================================
   
    DATASET_FOLDER = "C:/Users/ace/street_dataset"
    IMAGE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/images")
    OBSTACLE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/obstacles_json")
    DEPTH_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/depth_maps_npy")
    
    OUTPUT_FOLDER = "output_final_videos"
    os.makedirs(OUTPUT_FOLDER, exist_ok=True)
    OUTPUT_VIDEO_FILENAME = os.path.join(OUTPUT_FOLDER, "apf_simulation_professional.mp4")
    
    PROCESSING_WIDTH = 640
    HORIZONTAL_FIELD_OF_VIEW = 60 

    ATTRACTIVE_FORCE_GAIN = 1.0
    REPULSIVE_FORCE_GAIN = 2.0 
    OBSTACLE_INFLUENCE_RADIUS_M = 5.0

    PATH_PROJECTION_STEPS = 20
    PATH_STEP_SIZE_M = 0.2

    # *** THIS LINE WAS MISSING. IT IS NOW ADDED. ***
    MAP_SIZE_M = 10.0 # We will assume our virtual map is 10 meters deep for calculations

    # ==========================================================================
    # 2. FIND AND SORT FRAMES & SETUP VIDEO WRITER
    # ==========================================================================
    
    image_files = sorted(glob.glob(os.path.join(IMAGE_FOLDER, "*.jpg")))
    if not image_files:
        print(f"!!! ERROR: No images found in '{IMAGE_FOLDER}'.")
        return
        
    print(f"Found {len(image_files)} frames. Starting professional simulation video...")

    first_frame = cv2.imread(image_files[0])
    height, width, _ = first_frame.shape
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') 
    video_writer = cv2.VideoWriter(OUTPUT_VIDEO_FILENAME, fourcc, 10.0, (width, height))

    FOCAL_LENGTH = (width / 2) / np.tan(np.deg2rad(HORIZONTAL_FIELD_OF_VIEW / 2))

    # ==========================================================================
    # 3. MAIN LOOP
    # ==========================================================================
    
    for image_filepath in image_files:
        
        base_filename = os.path.splitext(os.path.basename(image_filepath))[0]
        obstacle_filepath = os.path.join(OBSTACLE_FOLDER, f"{base_filename}.json")
        depth_filepath = os.path.join(DEPTH_FOLDER, f"{base_filename}.npy")
        
        print(f"  - Processing {base_filename}")
        
        frame = cv2.imread(image_filepath)
        try:
            with open(obstacle_filepath, 'r') as f:
                obstacles_data = json.load(f)
            depth_map = np.load(depth_filepath)
        except FileNotFoundError:
            continue

        # --- 3D APF Logic (Same as before) ---
        robot_position_3d = np.array([0.0, 0.0]) 
        goal_position_3d = np.array([0.0, 10.0]) 
        attractive_force_3d = ATTRACTIVE_FORCE_GAIN * (goal_position_3d - robot_position_3d)
        total_repulsive_force_3d = np.array([0.0, 0.0])
        
        for obs in obstacles_data:
            x, y, w, h = obs['box']
            center_x_px, center_y_px = int(x + w/2), int(y + h/2)
            
            # Ensure coordinates are within the bounds of the depth map
            if 0 <= center_y_px < depth_map.shape[0] and 0 <= center_x_px < depth_map.shape[1]:
                inverse_depth = depth_map[center_y_px, center_x_px]
                real_depth_z = 1.0 / (inverse_depth + 1e-6)
                real_x = (center_x_px - width/2) * real_depth_z / FOCAL_LENGTH
                
                obstacle_position_3d = np.array([real_x, real_depth_z])
                distance_to_obstacle_m = np.linalg.norm(robot_position_3d - obstacle_position_3d)
                
                if distance_to_obstacle_m > OBSTACLE_INFLUENCE_RADIUS_M or distance_to_obstacle_m == 0:
                    continue
                
                repulsive_force_3d = REPULSIVE_FORCE_GAIN * (1.0 / distance_to_obstacle_m - 1.0 / OBSTACLE_INFLUENCE_RADIUS_M) * \
                                     (1.0 / distance_to_obstacle_m**2) * \
                                     (robot_position_3d - obstacle_position_3d) / distance_to_obstacle_m
                total_repulsive_force_3d += repulsive_force_3d

        final_force_3d = attractive_force_3d + total_repulsive_force_3d
        final_direction_3d = final_force_3d / (np.linalg.norm(final_force_3d) + 1e-6)

        # ======================================================================
        # 4. VISUALIZATION (UPGRADED)
        # ======================================================================
        
        # --- Draw Obstacle Boxes with Labels ---
        for obs in obstacles_data:
            x, y, w, h = obs['box']
            label = obs['label']
            confidence = obs['confidence']
            
            text_label = f"{label}: {int(confidence * 100)}%"
            
            (text_width, text_height), _ = cv2.getTextSize(text_label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2)
            cv2.rectangle(frame, (x, y - text_height - 10), (x + text_width, y), (0,0,0), -1)
            cv2.putText(frame, text_label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

        # --- Draw the Projected Path Line ---
        path_points_2d = []
        current_pos_3d = robot_position_3d.copy()

        for _ in range(PATH_PROJECTION_STEPS):
            current_pos_3d += final_direction_3d * PATH_STEP_SIZE_M
            
            # Avoid division by zero if Z component is too small
            if current_pos_3d[1] < 0.1:
                break
            
            px_x = int((current_pos_3d[0] * FOCAL_LENGTH / current_pos_3d[1]) + (width / 2))
            perspective_y = int(height - (current_pos_3d[1] / MAP_SIZE_M) * (height*0.5))
            
            if 0 < px_x < width:
                path_points_2d.append((px_x, perspective_y))

        if len(path_points_2d) > 1:
            # Use cv2.polylines to draw all segments at once. It's more efficient.
            path_pts_np = np.array(path_points_2d, dtype=np.int32)
            cv2.polylines(frame, [path_pts_np], isClosed=False, color=(255, 0, 0), thickness=3)

        video_writer.write(frame)

    # ==========================================================================
    # 5. FINISH AND CLEAN UP
    # ==========================================================================
    
    video_writer.release()
    print(f"\nSUCCESS! Professional simulation video saved to: {OUTPUT_VIDEO_FILENAME}")

if __name__ == '__main__':
    main()
# Out:
# Found 597 frames. Starting professional simulation video...
#   - Processing frame_00000
#   - Processing frame_00015
#   - Processing frame_00030
#   - Processing frame_00045
#   - Processing frame_00060
#   - Processing frame_00075
#   - Processing frame_00090
#   - Processing frame_00105
#   - Processing frame_00120
#   - Processing frame_00135
#   - Processing frame_00150
#   - Processing frame_00165
#   - Processing frame_00180
#   - Processing frame_00195
#   - Processing frame_00210
#   - Processing frame_00225
#   - Processing frame_00240
#   - Processing frame_00255
#   - Processing frame_00270
#   - Processing frame_00285
#   - Processing frame_00300
#   - Processing frame_00315
#   - Processing frame_00330
#   - Processing frame_00345
#   - Processing frame_00360
#   - Processing frame_00375
#   - Processing frame_00390
#   - Processing frame_00405
#   - Processing frame_00420
#   - Processing frame_00435
#   - Processing frame_00450
#   - Processing frame_00465
#   - Processing frame_00480
#   - Processing frame_00495
#   - Processing frame_00510
#   - Processing frame_00525
#   - Processing frame_00540
#   - Processing frame_00555
#   - Processing frame_00570
#   - Processing frame_00585
#   - Processing frame_00600
#   - Processing frame_00615
#   - Processing frame_00630
#   - Processing frame_00645
#   - Processing frame_00660
#   - Processing frame_00675
#   - Processing frame_00690
#   - Processing frame_00705
#   - Processing frame_00720
#   - Processing frame_00735
#   - Processing frame_00750
#   - Processing frame_00765
#   - Processing frame_00780
#   - Processing frame_00795
#   - Processing frame_00810
#   - Processing frame_00825
#   - Processing frame_00840
#   - Processing frame_00855
#   - Processing frame_00870
#   - Processing frame_00885
#   - Processing frame_00900
#   - Processing frame_00915
#   - Processing frame_00930
#   - Processing frame_00945
#   - Processing frame_00960
#   - Processing frame_00975
#   - Processing frame_00990
#   - Processing frame_01005
#   - Processing frame_01020
#   - Processing frame_01035
#   - Processing frame_01050
#   - Processing frame_01065
#   - Processing frame_01080
#   - Processing frame_01095
#   - Processing frame_01110
#   - Processing frame_01125
#   - Processing frame_01140
#   - Processing frame_01155
#   - Processing frame_01170
#   - Processing frame_01185
#   - Processing frame_01200
#   - Processing frame_01215
#   - Processing frame_01230
#   - Processing frame_01245
#   - Processing frame_01260
#   - Processing frame_01275
#   - Processing frame_01290
#   - Processing frame_01305
#   - Processing frame_01320
#   - Processing frame_01335
#   - Processing frame_01350
#   - Processing frame_01365
#   - Processing frame_01380
#   - Processing frame_01395
#   - Processing frame_01410
#   - Processing frame_01425
#   - Processing frame_01440
#   - Processing frame_01455
#   - Processing frame_01470
#   - Processing frame_01485
#   - Processing frame_01500
#   - Processing frame_01515
#   - Processing frame_01530
#   - Processing frame_01545
#   - Processing frame_01560
#   - Processing frame_01575
    IMAGE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/images")
    OBSTACLE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/obstacles_json")
    DEPTH_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/depth_maps_npy")
    
    OUTPUT_FOLDER = "output_final_videos"
    os.makedirs(OUTPUT_FOLDER, exist_ok=True)
    OUTPUT_VIDEO_FILENAME = os.path.join(OUTPUT_FOLDER, "apf_simulation_professional_path.mp4")
    
    PROCESSING_WIDTH = 640
    HORIZONTAL_FIELD_OF_VIEW = 60 

    ATTRACTIVE_FORCE_GAIN = 1.0
    REPULSIVE_FORCE_GAIN = 2.0 
    OBSTACLE_INFLUENCE_RADIUS_M = 5.0

    PATH_PROJECTION_STEPS = 30 # زدنا عدد النقاط لرسم مسار أطول
    PATH_STEP_SIZE_M = 0.2     

    # ==========================================================================
    # 2. FIND AND SORT FRAMES & SETUP VIDEO WRITER
    # ==========================================================================
    image_files = sorted(glob.glob(os.path.join(IMAGE_FOLDER, "*.jpg")))
    if not image_files:
        print(f"!!! ERROR: No images found in '{IMAGE_FOLDER}'.")
        return
        
    print(f"Found {len(image_files)} frames. Starting professional simulation video...")

    first_frame = cv2.imread(image_files[0])
    height, width, _ = first_frame.shape
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') 
    video_writer = cv2.VideoWriter(OUTPUT_VIDEO_FILENAME, fourcc, 10.0, (width, height))

    FOCAL_LENGTH = (width / 2) / np.tan(np.deg2rad(HORIZONTAL_FIELD_OF_VIEW / 2))

    # ==========================================================================
    # 3. *** جديد: تعريف مصفوفة تحويل المنظور ***
    # ==========================================================================
    # هذا هو جوهر الحل الجديد. نحدد "شبه منحرف" في الصورة
    # يمثل المستوى الأرضي، ونقوم بتحويله إلى عرض علوي مستطيل.
    
    # نقاط المصدر من الصورة (شبه منحرف يمثل الأرض)
    # قد تحتاج هذه النقاط إلى تعديل لتناسب منظور الفيديو الخاص بك.
    src_pts = np.float32([
        (width * 0.45, height * 0.6), # أعلى يسار الطريق
        (width * 0.55, height * 0.6), # أعلى يمين الطريق
        (width * 0.1, height),        # أسفل يسار الطريق
        (width * 0.9, height)         # أسفل يمين الطريق
    ])
    
    # نقاط الوجهة للعرض العلوي (مستطيل)
    dst_pts = np.float32([
        (0, 0),
        (width, 0),
        (0, height),
        (width, height)
    ])
    
    # الحصول على المصفوفة التي تحول من منظور العالم إلى منظور الصورة
    # نحن نحتاج إلى المصفوفة العكسية لإسقاط مسارنا ثلاثي الأبعاد مرة أخرى على الصورة
    M_world_to_image = cv2.getPerspectiveTransform(dst_pts, src_pts)


    # ==========================================================================
    # 4. MAIN LOOP
    # ==========================================================================
    for image_filepath in image_files:
        
        base_filename = os.path.splitext(os.path.basename(image_filepath))[0]
        # ... (بقية كود تحميل البيانات تبقى كما هي)
        obstacle_filepath = os.path.join(OBSTACLE_FOLDER, f"{base_filename}.json")
        depth_filepath = os.path.join(DEPTH_FOLDER, f"{base_filename}.npy")
        
        print(f"  - Processing {base_filename}")
        
        frame = cv2.imread(image_filepath)
        try:
            with open(obstacle_filepath, 'r') as f:
                obstacles_data = json.load(f)
            depth_map = np.load(depth_filepath)
        except FileNotFoundError:
            continue

        # --- منطق APF ثلاثي الأبعاد (يبقى كما هو) ---
        robot_position_3d = np.array([0.0, 0.0]) 
        goal_position_3d = np.array([0.0, 10.0]) 
        attractive_force_3d = ATTRACTIVE_FORCE_GAIN * (goal_position_3d - robot_position_3d)
        total_repulsive_force_3d = np.array([0.0, 0.0])
        
        for obs in obstacles_data:
            x, y, w, h = obs['box']
            center_x_px, center_y_px = int(x + w/2), int(y + h/2)
            if 0 <= center_y_px < depth_map.shape[0] and 0 <= center_x_px < depth_map.shape[1]:
                inverse_depth = depth_map[center_y_px, center_x_px]
                real_depth_z = 1.0 / (inverse_depth + 1e-6)
                real_x = (center_x_px - width/2) * real_depth_z / FOCAL_LENGTH
                obstacle_position_3d = np.array([real_x, real_depth_z])
                distance_to_obstacle_m = np.linalg.norm(robot_position_3d - obstacle_position_3d)
                if distance_to_obstacle_m > OBSTACLE_INFLUENCE_RADIUS_M or distance_to_obstacle_m == 0: continue
                repulsive_force_3d = REPULSIVE_FORCE_GAIN * (1.0/distance_to_obstacle_m - 1.0/OBSTACLE_INFLUENCE_RADIUS_M) * \
                                     (1.0/distance_to_obstacle_m**2) * (robot_position_3d - obstacle_position_3d) / distance_to_obstacle_m
                total_repulsive_force_3d += repulsive_force_3d

        final_force_3d = attractive_force_3d + total_repulsive_force_3d
        final_direction_3d = final_force_3d / (np.linalg.norm(final_force_3d) + 1e-6)

        # ======================================================================
        # 5. VISUALIZATION (مع رسم المسار الصحيح)
        # ======================================================================
        
        # --- رسم صناديق العقبات مع التسميات (يبقى كما هو) ---
        for obs in obstacles_data:
            x, y, w, h = obs['box']
            label = obs['label']
            confidence = obs['confidence']
            text_label = f"{label}: {int(confidence * 100)}%"
            (text_width, text_height), _ = cv2.getTextSize(text_label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2)
            cv2.rectangle(frame, (x, y - text_height - 10), (x + text_width, y), (0,0,0), -1)
            cv2.putText(frame, text_label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

        # --- *** جديد: رسم خط المسار المسقط بشكل صحيح *** ---
        path_points_3d = []
        current_pos_3d = robot_position_3d.copy()

        # محاكاة مسار الروبوت المستقبلي في الفضاء ثلاثي الأبعاد
        for _ in range(PATH_PROJECTION_STEPS):
            current_pos_3d += final_direction_3d * PATH_STEP_SIZE_M
            path_points_3d.append(current_pos_3d.copy())

        # الآن، نقوم بإسقاط هذه النقاط ثلاثية الأبعاد مرة أخرى على مستوى الصورة ثنائية الأبعاد
        if path_points_3d:
            # نحن بحاجة إلى تنسيق النقاط بشكل صحيح لدالة perspectiveTransform
            
            # تحويل مسارنا في العالم الحقيقي (س، ع) إلى المستوى المستطيل الوجهة
            path_on_dst_plane = []
            for pt_3d in path_points_3d:
                # تطبيع إحداثيات س و ع إلى النطاق 0-1 بناءً على مساحة رؤية معقولة
                # لنفترض أن منطقة الرؤية بعرض 10م (-5م إلى +5م) وعمق 10م (0م إلى 10م)
                norm_x = (pt_3d[0] + 5.0) / 10.0
                norm_y = pt_3d[1] / 10.0 # العمق هو محور ص على المستوى المسطح
                
                # تحويل الإحداثيات المطبعة إلى إحداثيات بكسل على المستوى الوجهة
                px_x = norm_x * width
                px_y = (1.0 - norm_y) * height # محور ص مقلوب
                path_on_dst_plane.append([px_x, px_y])

            path_on_dst_plane = np.array([path_on_dst_plane], dtype=np.float32)

            # استخدام مصفوفة المنظور العكسية لإسقاط المسار مرة أخرى على الصورة الأصلية
            path_on_image_plane = cv2.perspectiveTransform(path_on_dst_plane, M_world_to_image)

            # رسم المسار النهائي
            if path_on_image_plane is not None:
                # cv2.polylines هي أفضل دالة لرسم خطوط متصلة
                cv2.polylines(frame, [path_on_image_plane[0].astype(np.int32)], isClosed=False, color=(255, 0, 0), thickness=3)

        video_writer.write(frame)

    # ==========================================================================
    # 6. FINISH AND CLEAN UP
    # ==========================================================================
    
    video_writer.release()
    print(f"\nSUCCESS! Professional simulation video with correct path saved to: {OUTPUT_VIDEO_FILENAME}")

# تشغيل الدالة الرئيسية
if __name__ == '__main__':
    main()
# Out:
# Found 597 frames. Starting professional simulation video...
#   - Processing frame_00000
#   - Processing frame_00015
#   - Processing frame_00030
#   - Processing frame_00045
#   - Processing frame_00060
#   - Processing frame_00075
#   - Processing frame_00090
#   - Processing frame_00105
#   - Processing frame_00120
#   - Processing frame_00135
#   - Processing frame_00150
#   - Processing frame_00165
#   - Processing frame_00180
#   - Processing frame_00195
#   - Processing frame_00210
#   - Processing frame_00225
#   - Processing frame_00240
#   - Processing frame_00255
#   - Processing frame_00270
#   - Processing frame_00285
#   - Processing frame_00300
#   - Processing frame_00315
#   - Processing frame_00330
#   - Processing frame_00345
#   - Processing frame_00360
#   - Processing frame_00375
#   - Processing frame_00390
#   - Processing frame_00405
#   - Processing frame_00420
#   - Processing frame_00435
#   - Processing frame_00450
#   - Processing frame_00465
#   - Processing frame_00480
#   - Processing frame_00495
#   - Processing frame_00510
#   - Processing frame_00525
#   - Processing frame_00540
#   - Processing frame_00555
#   - Processing frame_00570
#   - Processing frame_00585
#   - Processing frame_00600
#   - Processing frame_00615
#   - Processing frame_00630
#   - Processing frame_00645
#   - Processing frame_00660
#   - Processing frame_00675
#   - Processing frame_00690
#   - Processing frame_00705
#   - Processing frame_00720
#   - Processing frame_00735
#   - Processing frame_00750
#   - Processing frame_00765
#   - Processing frame_00780
#   - Processing frame_00795
#   - Processing frame_00810
#   - Processing frame_00825
#   - Processing frame_00840
#   - Processing frame_00855
#   - Processing frame_00870
#   - Processing frame_00885
#   - Processing frame_00900
#   - Processing frame_00915
#   - Processing frame_00930
#   - Processing frame_00945
#   - Processing frame_00960
#   - Processing frame_00975
#   - Processing frame_00990
#   - Processing frame_01005
#   - Processing frame_01020
#   - Processing frame_01035
#   - Processing frame_01050
#   - Processing frame_01065
#   - Processing frame_01080
#   - Processing frame_01095
#   - Processing frame_08805
#   - Processing frame_08820
#   - Processing frame_08835
#   - Processing frame_08850
#   - Processing frame_08865
#   - Processing frame_08880
#   - Processing frame_08895
#   - Processing frame_08910
#   - Processing frame_08925
#   - Processing frame_08940
#
# SUCCESS! Professional simulation video with correct path saved to: output_final_videos\apf_simulation_professional_path.mp4

# %%
# ==============================================================================
# SCRIPT: final_navigation.py (Improved Version)
# ==============================================================================
# PURPOSE: An improved navigation algorithm combining a robust global A*
#          planner on an inflated costmap with path smoothing.
# ==============================================================================

import cv2
import os
import numpy as np
import json
import glob
from pathfinding.core.grid import Grid
from pathfinding.finder.a_star import AStarFinder
from pathfinding.core.diagonal_movement import DiagonalMovement

# ==============================================================================
# 1. HELPER FUNCTIONS FOR IMPROVED LOGIC
# ==============================================================================

def create_costmap(frame, depth_map, obstacles_data, settings):
    """
    Creates a costmap for navigation.

    IMPROVEMENT: This function encapsulates costmap creation and adds
    obstacle inflation for safer pathing.
    """
    # Unpack settings for clarity
    width, height = settings['width'], settings['height']
    costmap_w = settings['costmap_width']
    focal_length = settings['focal_length']
    src_pts = settings['src_pts']
    cost_sidewalk = settings['cost_sidewalk']
    cost_obstacle = settings['cost_obstacle']
    map_world_size_m = settings['map_world_size_m']

    # --- Step 1.1: Identify Drivable Area (Sidewalk) ---
    # Start with a base costmap where everything is an obstacle
    costmap = np.full((costmap_w, costmap_w), cost_obstacle, dtype=np.int32)

    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    lower_gray = np.array([0, 0, 40])
    upper_gray = np.array([180, 40, 220])
    sidewalk_mask = cv2.inRange(hsv_frame, lower_gray, upper_gray)

    M_image_to_world = cv2.getPerspectiveTransform(src_pts, settings['dst_pts'])
    top_down_sidewalk = cv2.warpPerspective(sidewalk_mask, M_image_to_world, (width, height))
    top_down_sidewalk_resized = cv2.resize(top_down_sidewalk, (costmap_w, costmap_w))
    
    sidewalk_indices = top_down_sidewalk_resized > 128
    costmap[sidewalk_indices] = cost_sidewalk

    # --- Step 1.2: Project Obstacles and Inflate Costs ---
    # Create a separate binary map for obstacle locations
    obstacle_map = np.zeros_like(costmap, dtype=np.uint8)

    for obs in obstacles_data:
        x, y, w, h = obs['box']
        center_x_px, center_y_px = int(x + w/2), int(y + h/2)

        if 0 <= center_y_px < depth_map.shape[0] and 0 <= center_x_px < depth_map.shape[1]:
            inverse_depth = depth_map[center_y_px, center_x_px]
            if inverse_depth <= 0: continue

            real_depth_z = 1.0 / inverse_depth
            if real_depth_z > map_world_size_m: continue # Ignore obstacles too far away

            real_x = (center_x_px - width/2) * real_depth_z / focal_length
            real_w = (w * real_depth_z) / focal_length

            # Convert real-world coordinates to costmap coordinates
            map_x = int((real_x + map_world_size_m/2) / map_world_size_m * costmap_w)
            map_y = int(costmap_w - (real_depth_z / map_world_size_m * costmap_w))
            map_w = max(1, int(real_w / map_world_size_m * costmap_w)) # Ensure at least 1 pixel wide

            if 0 <= map_y < costmap_w and 0 <= map_x < costmap_w:
                cv2.rectangle(obstacle_map, (map_x - map_w//2, map_y - map_w//2), (map_x + map_w//2, map_y + map_w//2), 255, -1)

    # --- Step 1.3: Inflate Obstacles ---
    # IMPROVEMENT: Instead of hard obstacles, create a cost gradient.
    # This pushes the path away from obstacles, creating a safer margin.
    if np.any(obstacle_map):
        # Use blur to create a "force field" effect around obstacles.
        # A larger kernel size means a wider safety margin.
        inflation_kernel_size = int(costmap_w * 0.1) | 1 # Must be odd
        inflated_map = cv2.GaussianBlur(obstacle_map.astype(np.float32), (inflation_kernel_size, inflation_kernel_size), 0)
        
        # Normalize the blurred values and scale them to be high-cost
        inflated_costs = (inflated_map / np.max(inflated_map)) * (cost_obstacle - cost_sidewalk)
        
        # Add the inflated costs to the base costmap, ensuring not to overwrite sidewalk costs completely
        costmap = np.maximum(costmap, inflated_costs.astype(np.int32))
        
    return costmap, sidewalk_indices

def find_and_smooth_path(costmap, sidewalk_indices, settings):
    """
    Finds the global path using A* and then smooths it.
    
    IMPROVEMENT: Dynamically finds the best goal and smooths the final path.
    """
    costmap_w = settings['costmap_width']
    grid = Grid(matrix=costmap)
    start = grid.node(costmap_w // 2, costmap_w - 1)

    # --- Step 2.1: Dynamic Goal Finding ---
    # IMPROVEMENT: Instead of a fixed goal, find the furthest reachable
    # point on the sidewalk. This adapts to curves.
    sidewalk_y, sidewalk_x = np.where(sidewalk_indices)
    if len(sidewalk_y) == 0: return None, None # No sidewalk found

    # Find sidewalk points in the top 20% of the map to set as a goal
    far_sidewalk_indices = np.where(sidewalk_y < costmap_w * 0.2)[0]
    if len(far_sidewalk_indices) > 0:
        # Find the furthest, most central point
        furthest_y = np.min(sidewalk_y[far_sidewalk_indices])
        candidate_xs = sidewalk_x[sidewalk_y == furthest_y]
        # Choose the one closest to the center
        goal_x = candidate_xs[np.argmin(np.abs(candidate_xs - costmap_w // 2))]
        end = grid.node(goal_x, furthest_y)
    else:
        # Fallback: if no sidewalk far away, use the old fixed goal
        end = grid.node(costmap_w // 2, 0)

    # --- Step 2.2: Run A* Search ---
    # IMPROVEMENT: Allow diagonal movement for more natural paths. The library
    # correctly weights diagonal moves as sqrt(2) vs 1 for cardinal.
    finder = AStarFinder(diagonal_movement=DiagonalMovement.always)
    path, runs = finder.find_path(start, end, grid)

    if not path or len(path) < 2:
        return None, None

    # --- Step 2.3: Path Smoothing ---
    # IMPROVEMENT: Smooth the jagged A* path for a more realistic trajectory.
    # Uses a simple moving average.
    smoothed_path = []
    if path:
        path_arr = np.array([(p.x, p.y) for p in path], dtype=float)
        window_size = 5 # Adjust for more or less smoothing
        
        # Pad the ends to handle edges correctly
        padded_path = np.pad(path_arr, ((window_size//2, window_size//2), (0,0)), 'edge')
        
        for i in range(len(path_arr)):
            avg = np.mean(padded_path[i : i+window_size], axis=0)
            smoothed_path.append(tuple(avg))
            
    return path, smoothed_path


def main():
    # ==========================================================================
    # 1. SETTINGS
    # ==========================================================================
    DATASET_FOLDER = "C:/Users/ace/street_dataset"
    IMAGE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/images")
    OBSTACLE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/obstacles_json")
    DEPTH_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/depth_maps_npy")
    OUTPUT_FOLDER = "output_final_videos"
    os.makedirs(OUTPUT_FOLDER, exist_ok=True)
    OUTPUT_VIDEO_FILENAME = os.path.join(OUTPUT_FOLDER, "final_navigation_video_improved.mp4")
    
    PROCESSING_WIDTH = 640
    HORIZONTAL_FIELD_OF_VIEW = 60

    # --- Path Planning Settings Dictionary ---
    # Bundling settings makes them easier to pass to helper functions
    settings = {
        'costmap_width': 100,         # The grid will be 100x100
        'map_world_size_m': 15.0,     # Costmap represents a 15x15 meter area ahead/sideways
        'cost_sidewalk': 1,           # Low cost for drivable area
        'cost_obstacle': 5000,        # Very high cost for obstacles
        'apf_attractive_gain': 1.0,
        # Other settings will be added dynamically below
    }

    # ==========================================================================
    # 2. SETUP AND PRE-CALCULATIONS
    # ==========================================================================
    image_files = sorted(glob.glob(os.path.join(IMAGE_FOLDER, "*.jpg")))
    if not image_files: print("!!! ERROR: No images found."); return
        
    print(f"Found {len(image_files)} frames. Starting IMPROVED navigation simulation...")

    first_frame = cv2.imread(image_files[0])
    height, width, _ = first_frame.shape
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') 
    video_writer = cv2.VideoWriter(OUTPUT_VIDEO_FILENAME, fourcc, 10.0, (width, height))
    
    # Add dynamic settings to the dictionary
    settings['width'] = width
    settings['height'] = height
    settings['focal_length'] = (width / 2) / np.tan(np.deg2rad(HORIZONTAL_FIELD_OF_VIEW / 2))
    settings['src_pts'] = np.float32([(width*0.45, height*0.6), (width*0.55, height*0.6), (width*0.1, height), (width*0.9, height)])
    settings['dst_pts'] = np.float32([(0, 0), (width, 0), (0, height), (width, height)])
    
    M_world_to_image = cv2.getPerspectiveTransform(settings['dst_pts'], settings['src_pts'])

    # ==========================================================================
    # 3. MAIN LOOP
    # ==========================================================================
    for image_filepath in image_files:
        base_filename = os.path.splitext(os.path.basename(image_filepath))[0]
        obstacle_filepath = os.path.join(OBSTACLE_FOLDER, f"{base_filename}.json")
        depth_filepath = os.path.join(DEPTH_FOLDER, f"{base_filename}.npy")
        
        print(f"  - Processing {base_filename}")
        
        frame = cv2.imread(image_filepath)
        try:
            with open(obstacle_filepath, 'r') as f:
                obstacles_data = json.load(f)
            depth_map = np.load(depth_filepath)
        except FileNotFoundError:
            video_writer.write(frame) # Write frame even if data is missing
            continue

        # --- Step 1: Create the Inflated Costmap ---
        costmap, sidewalk_indices = create_costmap(frame, depth_map, obstacles_data, settings)
        
        # --- Step 2: Find and Smooth the Global Path ---
        raw_path, smoothed_path = find_and_smooth_path(costmap, sidewalk_indices, settings)

        # --- Step 3: Get Immediate Direction (Local Planner) ---
        final_direction = np.array([0.0, -1.0]) # Default: move forward
        if smoothed_path:
            # The next waypoint is the second point in the smoothed path
            next_waypoint_map = smoothed_path[1]
            robot_pos_map = (settings['costmap_width']//2, settings['costmap_width']-1)
            direction_to_waypoint = np.array([next_waypoint_map[0] - robot_pos_map[0], next_waypoint_map[1] - robot_pos_map[1]])
            if np.linalg.norm(direction_to_waypoint) > 0:
                final_direction = direction_to_waypoint / np.linalg.norm(direction_to_waypoint)

        # --- Step 4: Visualize ---
        if smoothed_path:
            path_on_map_plane = []
            map_w = settings['costmap_width']
            map_size_m = settings['map_world_size_m']
            
            for p in smoothed_path:
                # Convert map coords back to a flat plane for projection
                norm_x = p[0] / map_w
                norm_y = 1.0 - (p[1] / map_w)
                path_on_map_plane.append([norm_x * width, norm_y * height])
        
            path_on_image = cv2.perspectiveTransform(np.array([path_on_map_plane], dtype=np.float32), M_world_to_image)
            if path_on_image is not None:
                cv2.polylines(frame, [path_on_image[0].astype(np.int32)], False, (0, 255, 0), 3) # Green for smoothed path
                
        # Draw Labeled Obstacles (same as before)
        for obs in obstacles_data:
            x, y, w, h = obs['box']
            label = f"{obs['label']}: {int(obs['confidence'] * 100)}%"
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 165, 255), 2)
            cv2.putText(frame, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
        
        video_writer.write(frame)

    video_writer.release()
    print(f"\nSUCCESS! Improved navigation video saved to: {OUTPUT_VIDEO_FILENAME}")

if __name__ == '__main__':
    main()
# Out:
# Found 597 frames. Starting IMPROVED navigation simulation...
#   - Processing frame_00000
#   - Processing frame_00015
#   - Processing frame_00030
#   - Processing frame_00045
#   - Processing frame_00060
#   - Processing frame_00075
#   - Processing frame_00090
#   - Processing frame_00105
#   - Processing frame_00120
#   - Processing frame_00135
#   - Processing frame_00150
#   - Processing frame_00165
#   - Processing frame_00180
#   - Processing frame_00195
#   - Processing frame_00210
#   - Processing frame_00225
#   - Processing frame_00240
#   - Processing frame_00255
#   - Processing frame_00270
#   - Processing frame_00285
#   - Processing frame_00300
#   - Processing frame_00315
#   - Processing frame_00330
#   - Processing frame_00345
#   - Processing frame_00360
#   - Processing frame_00375
#   - Processing frame_00390
#   - Processing frame_00405
#   - Processing frame_00420
#   - Processing frame_00435
#   - Processing frame_00450
#   - Processing frame_00465
#   - Processing frame_00480
#   - Processing frame_00495
#   - Processing frame_00510
#   - Processing frame_00525
#   - Processing frame_00540
#   - Processing frame_00555
#   - Processing frame_00570
#   - Processing frame_00585
#   - Processing frame_00600
#   - Processing frame_00615
#   - Processing frame_00630
#   - Processing frame_00645
#   - Processing frame_00660
#   - Processing frame_00675
#   - Processing frame_00690
#   - Processing frame_00705
#   - Processing frame_00720
#   - Processing frame_00735
#   - Processing frame_00750
#   - Processing frame_00765
#   - Processing frame_00780
#   - Processing frame_00795
#   - Processing frame_00810
#   - Processing frame_00825
#   - Processing frame_00840
#   - Processing frame_00855
#   - Processing frame_00870
#   - Processing frame_00885
#   - Processing frame_00900
#   - Processing frame_00915
#   - Processing frame_00930
#   - Processing frame_00945
#   - Processing frame_00960
#   - Processing frame_00975
#   - Processing frame_00990
#   - Processing frame_01005
#   - Processing frame_01020
#   - Processing frame_01035
#   - Processing frame_01050
#   - Processing frame_01065
#   - Processing frame_01080
#   - Processing frame_01095
#   - Processing frame_08805
#   - Processing frame_08820
#   - Processing frame_08835
#   - Processing frame_08850
#   - Processing frame_08865
#   - Processing frame_08880
#   - Processing frame_08895
#   - Processing frame_08910
#   - Processing frame_08925
#   - Processing frame_08940
#
# SUCCESS! Improved navigation video saved to: output_final_videos\final_navigation_video_improved.mp4

# %%
# ==============================================================================
# SCRIPT: final_navigation.py (Improved Version w/ Wait & Retreat)
# ==============================================================================
# PURPOSE: A robust navigation algorithm with a state machine to handle
#          blocked paths by waiting and then retreating.
# ==============================================================================

import cv2
import os
import numpy as np
import json
import glob
from pathfinding.core.grid import Grid
from pathfinding.finder.a_star import AStarFinder
from pathfinding.core.diagonal_movement import DiagonalMovement

# --- State Machine Definitions ---
STATE_NAVIGATING = 'NAVIGATING'
STATE_WAITING = 'WAITING'
STATE_RETREATING = 'RETREATING'

# ==============================================================================
# 1. HELPER FUNCTIONS (Unchanged from previous improvement)
# ==============================================================================

def create_costmap(frame, depth_map, obstacles_data, settings):
    """Creates a costmap with inflated obstacles for safer pathing."""
    width, height = settings['width'], settings['height']
    costmap_w = settings['costmap_width']
    focal_length = settings['focal_length']
    src_pts = settings['src_pts']
    cost_sidewalk = settings['cost_sidewalk']
    cost_obstacle = settings['cost_obstacle']
    map_world_size_m = settings['map_world_size_m']

    costmap = np.full((costmap_w, costmap_w), cost_obstacle, dtype=np.int32)
    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    lower_gray = np.array([0, 0, 40])
    upper_gray = np.array([180, 40, 220])
    sidewalk_mask = cv2.inRange(hsv_frame, lower_gray, upper_gray)

    M_image_to_world = cv2.getPerspectiveTransform(src_pts, settings['dst_pts'])
    top_down_sidewalk = cv2.warpPerspective(sidewalk_mask, M_image_to_world, (width, height))
    top_down_sidewalk_resized = cv2.resize(top_down_sidewalk, (costmap_w, costmap_w))
    
    sidewalk_indices = top_down_sidewalk_resized > 128
    costmap[sidewalk_indices] = cost_sidewalk

    obstacle_map = np.zeros_like(costmap, dtype=np.uint8)
    for obs in obstacles_data:
        x, y, w, h = obs['box']
        center_x_px, center_y_px = int(x + w/2), int(y + h/2)
        if 0 <= center_y_px < depth_map.shape[0] and 0 <= center_x_px < depth_map.shape[1]:
            inverse_depth = depth_map[center_y_px, center_x_px]
            if inverse_depth <= 0 or (1.0 / inverse_depth) > map_world_size_m: continue
            
            real_depth_z = 1.0 / inverse_depth
            real_x = (center_x_px - width/2) * real_depth_z / focal_length
            real_w = (w * real_depth_z) / focal_length
            map_x = int((real_x + map_world_size_m/2) / map_world_size_m * costmap_w)
            map_y = int(costmap_w - (real_depth_z / map_world_size_m * costmap_w))
            map_w = max(1, int(real_w / map_world_size_m * costmap_w))

            if 0 <= map_y < costmap_w and 0 <= map_x < costmap_w:
                cv2.rectangle(obstacle_map, (map_x - map_w//2, map_y - map_w//2), (map_x + map_w//2, map_y + map_w//2), 255, -1)

    if np.any(obstacle_map):
        inflation_kernel_size = int(costmap_w * 0.1) | 1
        inflated_map = cv2.GaussianBlur(obstacle_map.astype(np.float32), (inflation_kernel_size, inflation_kernel_size), 0)
        inflated_costs = (inflated_map / (np.max(inflated_map) + 1e-6)) * (cost_obstacle - cost_sidewalk)
        costmap = np.maximum(costmap, inflated_costs.astype(np.int32))
        
    return costmap, sidewalk_indices

def find_and_smooth_path(costmap, start_node, end_node, settings):
    """Finds the global path using A* and then smooths it."""
    grid = Grid(matrix=costmap)
    start = grid.node(start_node[0], start_node[1])
    end = grid.node(end_node[0], end_node[1])

    finder = AStarFinder(diagonal_movement=DiagonalMovement.always)
    path, runs = finder.find_path(start, end, grid)

    if not path or len(path) < 2: return None

    path_arr = np.array([(p.x, p.y) for p in path], dtype=float)
    window_size = 5
    padded_path = np.pad(path_arr, ((window_size//2, window_size//2), (0,0)), 'edge')
    smoothed_path = [tuple(np.mean(padded_path[i : i+window_size], axis=0)) for i in range(len(path_arr))]
            
    return smoothed_path

def draw_path_on_frame(frame, path, color, settings, M_world_to_image):
    """Projects and draws a given path onto the image frame."""
    if not path: return
    
    map_w = settings['costmap_width']
    width, height = settings['width'], settings['height']
    
    path_on_map_plane = []
    for p in path:
        norm_x = p[0] / map_w
        norm_y = 1.0 - (p[1] / map_w)
        path_on_map_plane.append([norm_x * width, norm_y * height])
    
    path_on_image = cv2.perspectiveTransform(np.array([path_on_map_plane], dtype=np.float32), M_world_to_image)
    if path_on_image is not None:
        cv2.polylines(frame, [path_on_image[0].astype(np.int32)], False, color, 3, cv2.LINE_AA)
        
def draw_status_text(frame, text, y_pos=30):
    """Draws highly visible status text on the frame."""
    font = cv2.FONT_HERSHEY_SIMPLEX
    text_size = cv2.getTextSize(text, font, 0.8, 2)[0]
    text_x = (frame.shape[1] - text_size[0]) // 2
    cv2.putText(frame, text, (text_x, y_pos), font, 0.8, (255, 255, 255), 2, cv2.LINE_AA)

# ==========================================================================
# 2. MAIN EXECUTION
# ==========================================================================
def main():
    # --- Settings ---
    DATASET_FOLDER = "C:/Users/ace/street_dataset"
   
    IMAGE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/images")
    OBSTACLE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/obstacles_json")
    DEPTH_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/depth_maps_npy")
    OUTPUT_FOLDER = "output_final_videos"
    os.makedirs(OUTPUT_FOLDER, exist_ok=True)
    VIDEO_FPS = 10.0
    OUTPUT_VIDEO_FILENAME = os.path.join(OUTPUT_FOLDER, "final_navigation_video_with_states.mp4")
    
    # --- State Machine Settings ---
    WAIT_DURATION_SECONDS = 5 * 60 # 5 minutes
    WAIT_DURATION_FRAMES = int(WAIT_DURATION_SECONDS * VIDEO_FPS)
    
    settings = {
        'costmap_width': 100,
        'map_world_size_m': 15.0,
        'cost_sidewalk': 1,
        'cost_obstacle': 5000,
    }

    # --- Setup ---
    image_files = sorted(glob.glob(os.path.join(IMAGE_FOLDER, "*.jpg")))
    if not image_files: print("!!! ERROR: No images found."); return
        
    print(f"Found {len(image_files)} frames. Starting advanced navigation simulation...")
    first_frame = cv2.imread(image_files[0])
    height, width, _ = first_frame.shape
    video_writer = cv2.VideoWriter(OUTPUT_VIDEO_FILENAME, cv2.VideoWriter_fourcc(*'mp4v'), VIDEO_FPS, (width, height))
    
    settings.update({
        'width': width, 'height': height,
        'focal_length': (width / 2) / np.tan(np.deg2rad(60 / 2)),
        'src_pts': np.float32([(width*0.45, height*0.6), (width*0.55, height*0.6), (width*0.1, height), (width*0.9, height)]),
        'dst_pts': np.float32([(0, 0), (width, 0), (0, height), (width, height)])
    })
    M_world_to_image = cv2.getPerspectiveTransform(settings['dst_pts'], settings['src_pts'])

    # --- Initialize State Variables ---
    current_state = STATE_NAVIGATING
    wait_start_frame = -1

    # ==========================================================================
    # 3. MAIN LOOP
    # ==========================================================================
    for frame_idx, image_filepath in enumerate(image_files):
        base_filename = os.path.splitext(os.path.basename(image_filepath))[0]
        print(f"  - Frame {frame_idx}: Processing {base_filename} (State: {current_state})")
        
        frame = cv2.imread(image_filepath)
        try:
            with open(os.path.join(OBSTACLE_FOLDER, f"{base_filename}.json"), 'r') as f:
                obstacles_data = json.load(f)
            depth_map = np.load(os.path.join(DEPTH_FOLDER, f"{base_filename}.npy"))
        except FileNotFoundError:
            draw_status_text(frame, "Data missing for this frame.")
            video_writer.write(frame)
            continue

        # --- Step 1: Create Costmap ---
        costmap, sidewalk_indices = create_costmap(frame, depth_map, obstacles_data, settings)
        
        # --- Step 2: Pathfinding and State Logic ---
        start_node = (settings['costmap_width'] // 2, settings['costmap_width'] - 1)
        
        # Determine the primary (forward) goal
        forward_goal_node = None
        sidewalk_y, sidewalk_x = np.where(sidewalk_indices)
        if len(sidewalk_y) > 0:
            far_sidewalk_indices = np.where(sidewalk_y < settings['costmap_width'] * 0.2)[0]
            if len(far_sidewalk_indices) > 0:
                furthest_y = np.min(sidewalk_y[far_sidewalk_indices])
                candidate_xs = sidewalk_x[sidewalk_y == furthest_y]
                goal_x = candidate_xs[np.argmin(np.abs(candidate_xs - settings['costmap_width'] // 2))]
                forward_goal_node = (goal_x, furthest_y)
            
        # Try to find a forward path, regardless of current state.
        # If a path opens up, we should take it immediately.
        forward_path = None
        if forward_goal_node:
            forward_path = find_and_smooth_path(costmap, start_node, forward_goal_node, settings)

        if forward_path:
            # If a path is found, always switch back to NAVIGATING
            current_state = STATE_NAVIGATING
            wait_start_frame = -1 # Reset wait timer
            draw_path_on_frame(frame, forward_path, (0, 255, 0), settings, M_world_to_image) # Green for forward path
            draw_status_text(frame, "Status: Navigating Forward")
        else:
            # NO FORWARD PATH FOUND. ENACT STATE-BASED BEHAVIOR.
            if current_state == STATE_NAVIGATING:
                # We were navigating but just lost the path, so start waiting
                current_state = STATE_WAITING
                wait_start_frame = frame_idx
                draw_status_text(frame, "Path Blocked! Waiting...")

            elif current_state == STATE_WAITING:
                elapsed_frames = frame_idx - wait_start_frame
                if elapsed_frames < WAIT_DURATION_FRAMES:
                    # Continue waiting
                    remaining_sec = (WAIT_DURATION_FRAMES - elapsed_frames) / VIDEO_FPS
                    draw_status_text(frame, f"Path Blocked. Waiting... ({int(remaining_sec)}s)")
                else:
                    # Wait time is over, switch to retreating
                    current_state = STATE_RETREATING
                    draw_status_text(frame, "Wait Time Exceeded! Retreating.")

            elif current_state == STATE_RETREATING:
                # We are in retreat mode, so plan a path backwards
                draw_status_text(frame, "Status: Planning Retreat")
                retreat_goal_node = start_node # Goal is to go back to the start
                # The "start" for the retreat path is a point near the top-center
                retreat_start_node = (settings['costmap_width'] // 2, 5) 
                
                retreat_path = find_and_smooth_path(costmap, retreat_start_node, retreat_goal_node, settings)
                
                if retreat_path:
                    draw_path_on_frame(frame, retreat_path, (0, 0, 255), settings, M_world_to_image) # Red for retreat path
                else:
                    # This is the worst-case scenario: trapped
                    draw_status_text(frame, "CRITICAL: Retreat Path Blocked! TRAPPED!", 60)

        # --- Step 3: Visualize Obstacles (Unchanged) ---
        for obs in obstacles_data:
            x, y, w, h = obs['box']
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 165, 255), 2)
        
        video_writer.write(frame)

    video_writer.release()
    print(f"\nSUCCESS! Advanced navigation video saved to: {OUTPUT_VIDEO_FILENAME}")

if __name__ == '__main__':
    main()
# Out:
# Found 597 frames. Starting advanced navigation simulation...
#   - Frame 0: Processing frame_00000 (State: NAVIGATING)
#   - Frame 1: Processing frame_00015 (State: NAVIGATING)
#   - Frame 2: Processing frame_00030 (State: NAVIGATING)
#   - Frame 3: Processing frame_00045 (State: NAVIGATING)
#   - Frame 4: Processing frame_00060 (State: NAVIGATING)
#   - Frame 5: Processing frame_00075 (State: NAVIGATING)
#   - Frame 6: Processing frame_00090 (State: NAVIGATING)
#   - Frame 7: Processing frame_00105 (State: NAVIGATING)
#   - Frame 8: Processing frame_00120 (State: NAVIGATING)
#   - Frame 9: Processing frame_00135 (State: NAVIGATING)
#   - Frame 10: Processing frame_00150 (State: NAVIGATING)
#   - Frame 11: Processing frame_00165 (State: NAVIGATING)
#   - Frame 12: Processing frame_00180 (State: NAVIGATING)
#   - Frame 13: Processing frame_00195 (State: WAITING)
#   - Frame 14: Processing frame_00210 (State: NAVIGATING)
#   - Frame 15: Processing frame_00225 (State: NAVIGATING)
#   - Frame 16: Processing frame_00240 (State: NAVIGATING)
#   - Frame 17: Processing frame_00255 (State: NAVIGATING)
#   - Frame 18: Processing frame_00270 (State: NAVIGATING)
#   - Frame 19: Processing frame_00285 (State: NAVIGATING)
#   - Frame 20: Processing frame_00300 (State: NAVIGATING)
#   - Frame 21: Processing frame_00315 (State: NAVIGATING)
#   - Frame 22: Processing frame_00330 (State: NAVIGATING)
#   - Frame 23: Processing frame_00345 (State: NAVIGATING)
#   - Frame 24: Processing frame_00360 (State: NAVIGATING)
#   - Frame 25: Processing frame_00375 (State: NAVIGATING)
#   - Frame 26: Processing frame_00390 (State: NAVIGATING)
#   - Frame 27: Processing frame_00405 (State: NAVIGATING)
#   - Frame 28: Processing frame_00420 (State: NAVIGATING)
#   - Frame 29: Processing frame_00435 (State: NAVIGATING)
#   - Frame 30: Processing frame_00450 (State: NAVIGATING)
#   - Frame 31: Processing frame_00465 (State: NAVIGATING)
#   - Frame 32: Processing frame_00480 (State: NAVIGATING)
#   - Frame 33: Processing frame_00495 (State: NAVIGATING)
#   - Frame 34: Processing frame_00510 (State: NAVIGATING)
#   - Frame 35: Processing frame_00525 (State: NAVIGATING)
#   - Frame 36: Processing frame_00540 (State: NAVIGATING)
#   - Frame 37: Processing frame_00555 (State: NAVIGATING)
#   - Frame 38: Processing frame_00570 (State: NAVIGATING)
#   - Frame 39: Processing frame_00585 (State: NAVIGATING)
#   - Frame 40: Processing frame_00600 (State: NAVIGATING)
#   - Frame 41: Processing frame_00615 (State: NAVIGATING)
#   - Frame 42: Processing frame_00630 (State: NAVIGATING)
#   - Frame 43: Processing frame_00645 (State: NAVIGATING)
#   - Frame 44: Processing frame_00660 (State: NAVIGATING)
#   - Frame 45: Processing frame_00675 (State: NAVIGATING)
#   - Frame 46: Processing frame_00690 (State: NAVIGATING)
#   - Frame 47: Processing frame_00705 (State: NAVIGATING)
#   - Frame 48: Processing frame_00720 (State: NAVIGATING)
#   - Frame 49: Processing frame_00735 (State: NAVIGATING)
#   - Frame 50: Processing frame_00750 (State: NAVIGATING)
#   - Frame 51: Processing frame_00765 (State: NAVIGATING)
#   - Frame 52: Processing frame_00780 (State: NAVIGATING)
#   - Frame 53: Processing frame_00795 (State: NAVIGATING)
#   - Frame 54: Processing frame_00810 (State: NAVIGATING)
#   - Frame 55: Processing frame_00825 (State: NAVIGATING)
#   - Frame 56: Processing frame_00840 (State: NAVIGATING)
#   - Frame 57: Processing frame_00855 (State: NAVIGATING)
#   - Frame 58: Processing frame_00870 (State: NAVIGATING)
#   - Frame 59: Processing frame_00885 (State: NAVIGATING)
#   - Frame 60: Processing frame_00900 (State: NAVIGATING)
#   - Frame 61: Processing frame_00915 (State: NAVIGATING)
#   - Frame 62: Processing frame_00930 (State: NAVIGATING)
#   - Frame 63: Processing frame_00945 (State: NAVIGATING)
#   - Frame 64: Processing frame_00960 (State: NAVIGATING)
#   - Frame 65: Processing frame_00975 (State: NAVIGATING)
#   - Frame 66: Processing frame_00990 (State: NAVIGATING)
#   - Frame 67: Processing frame_01005 (State: NAVIGATING)
#   - Frame 68: Processing frame_01020 (State: NAVIGATING)
#   - Frame 69: Processing frame_01035 (State: NAVIGATING)
#   - Frame 70: Processing frame_01050 (State: NAVIGATING)
#   - Frame 71: Processing frame_01065 (State: NAVIGATING)
#   - Frame 72: Processing frame_01080 (State: NAVIGATING)
#   - Frame 73: Processing frame_01095 (State: NAVIGATING)
#   - Frame 74: Processing frame_01110 (State: NAVIGATING)
#   - Frame 75: Processing frame_01125 (State: NAVIGATING)
#   - Frame 76: Processing frame_01140 (State: NAVIGATING)
#   - Frame 77: Processing frame_01155 (State: NAVIGATING)
#   - Frame 78: Processing frame_01170 (State: NAVIGATING)
#   - Frame 79: Processing frame_01185 (State: NAVIGATING)
#   - Frame 80: Processing frame_01200 (State: NAVIGATING)
#   - Frame 81: Processing frame_01215 (State: NAVIGATING)
#   - Frame 82: Processing frame_01230 (State: NAVIGATING)
#   - Frame 83: Processing frame_01245 (State: NAVIGATING)
#   - Frame 84: Processing frame_01260 (State: NAVIGATING)
#   - Frame 85: Processing frame_01275 (State: NAVIGATING)
#   - Frame 86: Processing frame_01290 (State: NAVIGATING)
#   - Frame 87: Processing frame_01305 (State: NAVIGATING)
#   - Frame 88: Processing frame_01320 (State: NAVIGATING)
#   - Frame 89: Processing frame_01335 (State: NAVIGATING)
#   - Frame 90: Processing frame_01350 (State: NAVIGATING)
#   - Frame 91: Processing frame_01365 (State: NAVIGATING)
#   - Frame 92: Processing frame_01380 (State: NAVIGATING)
#   - Frame 93: Processing frame_01395 (State: NAVIGATING)
#   - Frame 94: Processing frame_01410 (State: NAVIGATING)
#   - Frame 95: Processing frame_01425 (State: NAVIGATING)
#   - Frame 96: Processing frame_01440 (State: NAVIGATING)
#   - Frame 97: Processing frame_01455 (State: NAVIGATING)
#   - Frame 98: Processing frame_01470 (State: NAVIGATING)
#   - Frame 99: Processing frame_01485 (State: NAVIGATING)
#   - Frame 100: Processing frame_01500 (State: NAVIGATING)
#   - Frame 101: Processing frame_01515 (State: NAVIGATING)
#   - Frame 102: Processing frame_01530 (State: NAVIGATING)
#   - Frame 103: Processing frame_01545 (State: NAVIGATING)
#   - Frame 104: Processing frame_01560 (State: NAVIGATING)
#   - Frame 105: Processing frame_01575 (State: NAVIGATING)
#   - Frame 106: Processing frame_01590 (State: NAVIGATING)
#   - Frame 107: Processing frame_01605 (State: NAVIGATING)
#   - Frame 108: Processing frame_01620 (State: NAVIGATING)
#   - Frame 109: Processing frame_01635 (State: NAVIGATING)
#   - Frame 110: Processing frame_01650 (State: NAVIGATING)
#   - Frame 111: Processing frame_01665 (State: NAVIGATING)
#   - Frame 112: Processing frame_01680 (State: NAVIGATING)
#   - Frame 113: Processing frame_01695 (State: NAVIGATING)
#   - Frame 114: Processing frame_01710 (State: NAVIGATING)
#   - Frame 115: Processing frame_01725 (State: NAVIGATING)
#   - Frame 116: Processing frame_01740 (State: NAVIGATING)
#   - Frame 117: Processing frame_01755 (State: NAVIGATING)
#   - Frame 118: Processing frame_01770 (State: NAVIGATING)
#   - Frame 119: Processing frame_01785 (State: NAVIGATING)
#   - Frame 120: Processing frame_01800 (State: NAVIGATING)
#   - Frame 121: Processing frame_01815 (State: NAVIGATING)
#   - Frame 122: Processing frame_01830 (State: NAVIGATING)
#   - Frame 123: Processing frame_01845 (State: NAVIGATING)
#   - Frame 124: Processing frame_01860 (State: NAVIGATING)
#   - Frame 125: Processing frame_01875 (State: WAITING)
#   - Frame 126: Processing frame_01890 (State: NAVIGATING)
#   - Frame 127: Processing frame_01905 (State: NAVIGATING)
#   - Frame 128: Processing frame_01920 (State: NAVIGATING)
#   - Frame 129: Processing frame_01935 (State: NAVIGATING)
#   - Frame 130: Processing frame_01950 (State: NAVIGATING)
#   - Frame 131: Processing frame_01965 (State: NAVIGATING)
#   - Frame 132: Processing frame_01980 (State: NAVIGATING)
#   - Frame 133: Processing frame_01995 (State: NAVIGATING)
#   - Frame 134: Processing frame_02010 (State: NAVIGATING)
#   - Frame 135: Processing frame_02025 (State: NAVIGATING)
#   - Frame 136: Processing frame_02040 (State: NAVIGATING)
#   - Frame 137: Processing frame_02055 (State: NAVIGATING)
#   - Frame 138: Processing frame_02070 (State: NAVIGATING)
#   - Frame 139: Processing frame_02085 (State: NAVIGATING)
#   - Frame 140: Processing frame_02100 (State: NAVIGATING)
#   - Frame 141: Processing frame_02115 (State: NAVIGATING)
#   - Frame 142: Processing frame_02130 (State: NAVIGATING)
#   - Frame 143: Processing frame_02145 (State: NAVIGATING)
#   - Frame 144: Processing frame_02160 (State: NAVIGATING)
#   - Frame 145: Processing frame_02175 (State: NAVIGATING)
#   - Frame 146: Processing frame_02190 (State: NAVIGATING)
#   - Frame 147: Processing frame_02205 (State: NAVIGATING)
#   - Frame 148: Processing frame_02220 (State: NAVIGATING)
#   - Frame 149: Processing frame_02235 (State: NAVIGATING)
#   - Frame 150: Processing frame_02250 (State: NAVIGATING)
#   - Frame 151: Processing frame_02265 (State: NAVIGATING)
#   - Frame 152: Processing frame_02280 (State: NAVIGATING)
#   - Frame 153: Processing frame_02295 (State: NAVIGATING)
#   - Frame 154: Processing frame_02310 (State: NAVIGATING)
#   - Frame 155: Processing frame_02325 (State: NAVIGATING)
#   - Frame 156: Processing frame_02340 (State: NAVIGATING)
#   - Frame 157: Processing frame_02355 (State: NAVIGATING)
#   - Frame 158: Processing frame_02370 (State: NAVIGATING)
#   - Frame 159: Processing frame_02385 (State: NAVIGATING)
#   - Frame 160: Processing frame_02400 (State: NAVIGATING)
#   - Frame 161: Processing frame_02415 (State: NAVIGATING)
#   - Frame 162: Processing frame_02430 (State: NAVIGATING)
#   - Frame 163: Processing frame_02445 (State: NAVIGATING)
#   - Frame 164: Processing frame_02460 (State: NAVIGATING)
#   - Frame 165: Processing frame_02475 (State: NAVIGATING)
#   - Frame 166: Processing frame_02490 (State: WAITING)
#   - Frame 167: Processing frame_02505 (State: WAITING)
#   - Frame 168: Processing frame_02520 (State: NAVIGATING)
#   - Frame 169: Processing frame_02535 (State: NAVIGATING)
#   - Frame 170: Processing frame_02550 (State: NAVIGATING)
#   - Frame 171: Processing frame_02565 (State: NAVIGATING)
#   - Frame 172: Processing frame_02580 (State: NAVIGATING)
#   - Frame 173: Processing frame_02595 (State: NAVIGATING)
#   - Frame 174: Processing frame_02610 (State: NAVIGATING)
#   - Frame 175: Processing frame_02625 (State: NAVIGATING)
#   - Frame 176: Processing frame_02640 (State: NAVIGATING)
#   - Frame 177: Processing frame_02655 (State: NAVIGATING)
#   - Frame 178: Processing frame_02670 (State: NAVIGATING)
#   - Frame 179: Processing frame_02685 (State: NAVIGATING)
#   - Frame 180: Processing frame_02700 (State: NAVIGATING)
#   - Frame 181: Processing frame_02715 (State: NAVIGATING)
#   - Frame 182: Processing frame_02730 (State: NAVIGATING)
#   - Frame 183: Processing frame_02745 (State: NAVIGATING)
#   - Frame 184: Processing frame_02760 (State: NAVIGATING)
#   - Frame 185: Processing frame_02775 (State: NAVIGATING)
#   - Frame 186: Processing frame_02790 (State: NAVIGATING)
#   - Frame 187: Processing frame_02805 (State: NAVIGATING)
#   - Frame 188: Processing frame_02820 (State: NAVIGATING)
#   - Frame 189: Processing frame_02835 (State: NAVIGATING)
#   - Frame 190: Processing frame_02850 (State: NAVIGATING)
#   - Frame 191: Processing frame_02865 (State: NAVIGATING)
#   - Frame 192: Processing frame_02880 (State: NAVIGATING)
#   - Frame 193: Processing frame_02895 (State: NAVIGATING)
#   - Frame 194: Processing frame_02910 (State: NAVIGATING)
#   - Frame 195: Processing frame_02925 (State: NAVIGATING)
#   - Frame 196: Processing frame_02940 (State: NAVIGATING)
#   - Frame 197: Processing frame_02955 (State: NAVIGATING)
#   - Frame 198: Processing frame_02970 (State: NAVIGATING)
#   - Frame 199: Processing frame_02985 (State: NAVIGATING)
#   - Frame 200: Processing frame_03000 (State: NAVIGATING)
#   - Frame 201: Processing frame_03015 (State: NAVIGATING)
#   - Frame 202: Processing frame_03030 (State: NAVIGATING)
#   - Frame 203: Processing frame_03045 (State: NAVIGATING)
#   - Frame 204: Processing frame_03060 (State: NAVIGATING)
#   - Frame 205: Processing frame_03075 (State: NAVIGATING)
#   - Frame 206: Processing frame_03090 (State: NAVIGATING)
#   - Frame 207: Processing frame_03105 (State: NAVIGATING)
#   - Frame 208: Processing frame_03120 (State: NAVIGATING)
#   - Frame 209: Processing frame_03135 (State: NAVIGATING)
#   - Frame 210: Processing frame_03150 (State: NAVIGATING)
#   - Frame 211: Processing frame_03165 (State: NAVIGATING)
#   - Frame 212: Processing frame_03180 (State: NAVIGATING)
#   - Frame 213: Processing frame_03195 (State: NAVIGATING)
#   - Frame 214: Processing frame_03210 (State: NAVIGATING)
#   - Frame 215: Processing frame_03225 (State: NAVIGATING)
#   - Frame 216: Processing frame_03240 (State: NAVIGATING)
#   - Frame 217: Processing frame_03255 (State: NAVIGATING)
#   - Frame 218: Processing frame_03270 (State: NAVIGATING)
#   - Frame 219: Processing frame_03285 (State: NAVIGATING)
#   - Frame 220: Processing frame_03300 (State: NAVIGATING)
#   - Frame 221: Processing frame_03315 (State: NAVIGATING)
#   - Frame 222: Processing frame_03330 (State: NAVIGATING)
#   - Frame 223: Processing frame_03345 (State: NAVIGATING)
#   - Frame 224: Processing frame_03360 (State: WAITING)
#   - Frame 225: Processing frame_03375 (State: NAVIGATING)
#   - Frame 226: Processing frame_03390 (State: NAVIGATING)
#   - Frame 227: Processing frame_03405 (State: NAVIGATING)
#   - Frame 228: Processing frame_03420 (State: NAVIGATING)
#   - Frame 229: Processing frame_03435 (State: NAVIGATING)
#   - Frame 230: Processing frame_03450 (State: NAVIGATING)
#   - Frame 231: Processing frame_03465 (State: NAVIGATING)
#   - Frame 232: Processing frame_03480 (State: NAVIGATING)
#   - Frame 233: Processing frame_03495 (State: NAVIGATING)
#   - Frame 234: Processing frame_03510 (State: NAVIGATING)
#   - Frame 235: Processing frame_03525 (State: NAVIGATING)
#   - Frame 236: Processing frame_03540 (State: NAVIGATING)
#   - Frame 237: Processing frame_03555 (State: NAVIGATING)
#   - Frame 238: Processing frame_03570 (State: NAVIGATING)
#   - Frame 239: Processing frame_03585 (State: NAVIGATING)
#   - Frame 240: Processing frame_03600 (State: NAVIGATING)
#   - Frame 241: Processing frame_03615 (State: NAVIGATING)
#   - Frame 242: Processing frame_03630 (State: NAVIGATING)
#   - Frame 243: Processing frame_03645 (State: NAVIGATING)
#   - Frame 244: Processing frame_03660 (State: NAVIGATING)
#   - Frame 245: Processing frame_03675 (State: NAVIGATING)
#   - Frame 246: Processing frame_03690 (State: NAVIGATING)
#   - Frame 247: Processing frame_03705 (State: NAVIGATING)
#   - Frame 248: Processing frame_03720 (State: NAVIGATING)
#   - Frame 249: Processing frame_03735 (State: NAVIGATING)
#   - Frame 250: Processing frame_03750 (State: NAVIGATING)
#   - Frame 251: Processing frame_03765 (State: NAVIGATING)
#   - Frame 252: Processing frame_03780 (State: NAVIGATING)
#   - Frame 253: Processing frame_03795 (State: NAVIGATING)
#   - Frame 254: Processing frame_03810 (State: NAVIGATING)
#   - Frame 255: Processing frame_03825 (State: NAVIGATING)
#   - Frame 256: Processing frame_03840 (State: NAVIGATING)
#   - Frame 257: Processing frame_03855 (State: NAVIGATING)
#   - Frame 258: Processing frame_03870 (State: NAVIGATING)
#   - Frame 259: Processing frame_03885 (State: NAVIGATING)
#   - Frame 260: Processing frame_03900 (State: NAVIGATING)
#   - Frame 261: Processing frame_03915 (State: NAVIGATING)
#   - Frame 262: Processing frame_03930 (State: NAVIGATING)
#   - Frame 263: Processing frame_03945 (State: NAVIGATING)
#   - Frame 264: Processing frame_03960 (State: NAVIGATING)
#   - Frame 265: Processing frame_03975 (State: NAVIGATING)
#   - Frame 266: Processing frame_03990 (State: NAVIGATING)
#   - Frame 267: Processing frame_04005 (State: NAVIGATING)
#   - Frame 268: Processing frame_04020 (State: NAVIGATING)
#   - Frame 269: Processing frame_04035 (State: NAVIGATING)
#   - Frame 270: Processing frame_04050 (State: NAVIGATING)
#   - Frame 271: Processing frame_04065 (State: NAVIGATING)
#   - Frame 272: Processing frame_04080 (State: NAVIGATING)
#   - Frame 273: Processing frame_04095 (State: NAVIGATING)
#   - Frame 274: Processing frame_04110 (State: NAVIGATING)
#   - Frame 275: Processing frame_04125 (State: NAVIGATING)
#   - Frame 276: Processing frame_04140 (State: NAVIGATING)
#   - Frame 277: Processing frame_04155 (State: NAVIGATING)
#   - Frame 278: Processing frame_04170 (State: NAVIGATING)
#   - Frame 279: Processing frame_04185 (State: NAVIGATING)
#   - Frame 280: Processing frame_04200 (State: NAVIGATING)
#   - Frame 281: Processing frame_04215 (State: NAVIGATING)
#   - Frame 282: Processing frame_04230 (State: NAVIGATING)
#   - Frame 283: Processing frame_04245 (State: NAVIGATING)
#   - Frame 284: Processing frame_04260 (State: NAVIGATING)
#   - Frame 285: Processing frame_04275 (State: NAVIGATING)
#   - Frame 286: Processing frame_04290 (State: NAVIGATING)
#   - Frame 287: Processing frame_04305 (State: NAVIGATING)
#   - Frame 288: Processing frame_04320 (State: NAVIGATING)
#   - Frame 289: Processing frame_04335 (State: NAVIGATING)
#   - Frame 290: Processing frame_04350 (State: NAVIGATING)
#   - Frame 291: Processing frame_04365 (State: NAVIGATING)
#   - Frame 292: Processing frame_04380 (State: NAVIGATING)
#   - Frame 293: Processing frame_04395 (State: NAVIGATING)
#   - Frame 294: Processing frame_04410 (State: NAVIGATING)
#   - Frame 295: Processing frame_04425 (State: NAVIGATING)
#   - Frame 296: Processing frame_04440 (State: NAVIGATING)
#   - Frame 297: Processing frame_04455 (State: NAVIGATING)
#   - Frame 298: Processing frame_04470 (State: NAVIGATING)
#   - Frame 299: Processing frame_04485 (State: NAVIGATING)
#   - Frame 300: Processing frame_04500 (State: NAVIGATING)
#   - Frame 301: Processing frame_04515 (State: NAVIGATING)
#   - Frame 302: Processing frame_04530 (State: NAVIGATING)
#   - Frame 303: Processing frame_04545 (State: NAVIGATING)
#   - Frame 304: Processing frame_04560 (State: NAVIGATING)
#   - Frame 305: Processing frame_04575 (State: NAVIGATING)
#   - Frame 306: Processing frame_04590 (State: NAVIGATING)
#   - Frame 307: Processing frame_04605 (State: NAVIGATING)
#   - Frame 308: Processing frame_04620 (State: NAVIGATING)
#   - Frame 309: Processing frame_04635 (State: NAVIGATING)
#   - Frame 310: Processing frame_04650 (State: NAVIGATING)
#   - Frame 311: Processing frame_04665 (State: NAVIGATING)
#   - Frame 312: Processing frame_04680 (State: NAVIGATING)
#   - Frame 313: Processing frame_04695 (State: NAVIGATING)
#   - Frame 314: Processing frame_04710 (State: NAVIGATING)
#   - Frame 315: Processing frame_04725 (State: WAITING)
#   - Frame 316: Processing frame_04740 (State: WAITING)
#   - Frame 317: Processing frame_04755 (State: NAVIGATING)
#   - Frame 318: Processing frame_04770 (State: NAVIGATING)
#   - Frame 319: Processing frame_04785 (State: WAITING)
#   - Frame 320: Processing frame_04800 (State: NAVIGATING)
#   - Frame 321: Processing frame_04815 (State: NAVIGATING)
#   - Frame 322: Processing frame_04830 (State: NAVIGATING)
#   - Frame 323: Processing frame_04845 (State: NAVIGATING)
#   - Frame 324: Processing frame_04860 (State: WAITING)
#   - Frame 325: Processing frame_04875 (State: NAVIGATING)
#   - Frame 326: Processing frame_04890 (State: NAVIGATING)
#   - Frame 327: Processing frame_04905 (State: NAVIGATING)
#   - Frame 328: Processing frame_04920 (State: NAVIGATING)
#   - Frame 329: Processing frame_04935 (State: NAVIGATING)
#   - Frame 330: Processing frame_04950 (State: NAVIGATING)
#   - Frame 331: Processing frame_04965 (State: NAVIGATING)
#   - Frame 332: Processing frame_04980 (State: NAVIGATING)
#   - Frame 333: Processing frame_04995 (State: NAVIGATING)
#   - Frame 334: Processing frame_05010 (State: NAVIGATING)
#   - Frame 335: Processing frame_05025 (State: NAVIGATING)
#   - Frame 336: Processing frame_05040 (State: NAVIGATING)
#   - Frame 337: Processing frame_05055 (State: NAVIGATING)
#   - Frame 338: Processing frame_05070 (State: NAVIGATING)
#   - Frame 339: Processing frame_05085 (State: NAVIGATING)
#   - Frame 340: Processing frame_05100 (State: NAVIGATING)
#   - Frame 341: Processing frame_05115 (State: NAVIGATING)
#   - Frame 342: Processing frame_05130 (State: NAVIGATING)
#   - Frame 343: Processing frame_05145 (State: NAVIGATING)
#   - Frame 344: Processing frame_05160 (State: NAVIGATING)
#   - Frame 345: Processing frame_05175 (State: NAVIGATING)
#   - Frame 346: Processing frame_05190 (State: NAVIGATING)
#   - Frame 347: Processing frame_05205 (State: NAVIGATING)
#   - Frame 348: Processing frame_05220 (State: NAVIGATING)
#   - Frame 349: Processing frame_05235 (State: NAVIGATING)
#   - Frame 350: Processing frame_05250 (State: NAVIGATING)
#   - Frame 351: Processing frame_05265 (State: NAVIGATING)
#   - Frame 352: Processing frame_05280 (State: NAVIGATING)
#   - Frame 353: Processing frame_05295 (State: NAVIGATING)
#   - Frame 354: Processing frame_05310 (State: NAVIGATING)
#   - Frame 355: Processing frame_05325 (State: NAVIGATING)
#   - Frame 356: Processing frame_05340 (State: NAVIGATING)
#   - Frame 357: Processing frame_05355 (State: NAVIGATING)
#   - Frame 358: Processing frame_05370 (State: NAVIGATING)
#   - Frame 359: Processing frame_05385 (State: NAVIGATING)
#   - Frame 360: Processing frame_05400 (State: NAVIGATING)
#   - Frame 361: Processing frame_05415 (State: NAVIGATING)
#   - Frame 362: Processing frame_05430 (State: NAVIGATING)
#   - Frame 363: Processing frame_05445 (State: WAITING)
#   - Frame 364: Processing frame_05460 (State: NAVIGATING)
#   - Frame 365: Processing frame_05475 (State: NAVIGATING)
#   - Frame 366: Processing frame_05490 (State: NAVIGATING)
#   - Frame 367: Processing frame_05505 (State: NAVIGATING)
#   - Frame 368: Processing frame_05520 (State: NAVIGATING)
#   - Frame 369: Processing frame_05535 (State: NAVIGATING)
#   - Frame 370: Processing frame_05550 (State: NAVIGATING)
#   - Frame 371: Processing frame_05565 (State: NAVIGATING)
#   - Frame 372: Processing frame_05580 (State: NAVIGATING)
#   - Frame 373: Processing frame_05595 (State: NAVIGATING)
#   - Frame 374: Processing frame_05610 (State: NAVIGATING)
#   - Frame 375: Processing frame_05625 (State: NAVIGATING)
#   - Frame 376: Processing frame_05640 (State: NAVIGATING)
#   - Frame 377: Processing frame_05655 (State: NAVIGATING)
#   - Frame 378: Processing frame_05670 (State: NAVIGATING)
#   - Frame 379: Processing frame_05685 (State: NAVIGATING)
#   - Frame 380: Processing frame_05700 (State: NAVIGATING)
#   - Frame 381: Processing frame_05715 (State: NAVIGATING)
#   - Frame 382: Processing frame_05730 (State: NAVIGATING)
#   - Frame 383: Processing frame_05745 (State: NAVIGATING)
#   - Frame 384: Processing frame_05760 (State: NAVIGATING)
#   - Frame 385: Processing frame_05775 (State: NAVIGATING)
#   - Frame 386: Processing frame_05790 (State: NAVIGATING)
#   - Frame 387: Processing frame_05805 (State: NAVIGATING)
#   - Frame 388: Processing frame_05820 (State: NAVIGATING)
#   - Frame 389: Processing frame_05835 (State: NAVIGATING)
#   - Frame 390: Processing frame_05850 (State: NAVIGATING)
#   - Frame 391: Processing frame_05865 (State: NAVIGATING)
#   - Frame 392: Processing frame_05880 (State: NAVIGATING)
#   - Frame 393: Processing frame_05895 (State: NAVIGATING)
#   - Frame 394: Processing frame_05910 (State: NAVIGATING)
#   - Frame 395: Processing frame_05925 (State: NAVIGATING)
#   - Frame 396: Processing frame_05940 (State: NAVIGATING)
#   - Frame 397: Processing frame_05955 (State: NAVIGATING)
#   - Frame 398: Processing frame_05970 (State: NAVIGATING)
#   - Frame 399: Processing frame_05985 (State: NAVIGATING)
#   - Frame 400: Processing frame_06000 (State: NAVIGATING)
#   - Frame 401: Processing frame_06015 (State: NAVIGATING)
#   - Frame 402: Processing frame_06030 (State: NAVIGATING)
#   - Frame 403: Processing frame_06045 (State: WAITING)
#   - Frame 404: Processing frame_06060 (State: NAVIGATING)
#   - Frame 405: Processing frame_06075 (State: NAVIGATING)
#   - Frame 406: Processing frame_06090 (State: NAVIGATING)
#   - Frame 407: Processing frame_06105 (State: NAVIGATING)
#   - Frame 408: Processing frame_06120 (State: NAVIGATING)
#   - Frame 409: Processing frame_06135 (State: NAVIGATING)
#   - Frame 410: Processing frame_06150 (State: NAVIGATING)
#   - Frame 411: Processing frame_06165 (State: NAVIGATING)
#   - Frame 412: Processing frame_06180 (State: NAVIGATING)
#   - Frame 413: Processing frame_06195 (State: NAVIGATING)
#   - Frame 414: Processing frame_06210 (State: NAVIGATING)
#   - Frame 415: Processing frame_06225 (State: NAVIGATING)
#   - Frame 416: Processing frame_06240 (State: NAVIGATING)
#   - Frame 417: Processing frame_06255 (State: NAVIGATING)
#   - Frame 418: Processing frame_06270 (State: NAVIGATING)
#   - Frame 419: Processing frame_06285 (State: NAVIGATING)
#   - Frame 420: Processing frame_06300 (State: NAVIGATING)
#   - Frame 421: Processing frame_06315 (State: NAVIGATING)
#   - Frame 422: Processing frame_06330 (State: NAVIGATING)
#   - Frame 423: Processing frame_06345 (State: NAVIGATING)
#   - Frame 424: Processing frame_06360 (State: NAVIGATING)
#   - Frame 425: Processing frame_06375 (State: NAVIGATING)
#   - Frame 426: Processing frame_06390 (State: NAVIGATING)
#   - Frame 427: Processing frame_06405 (State: NAVIGATING)
#   - Frame 428: Processing frame_06420 (State: NAVIGATING)
#   - Frame 429: Processing frame_06435 (State: NAVIGATING)
#   - Frame 430: Processing frame_06450 (State: NAVIGATING)
#   - Frame 431: Processing frame_06465 (State: NAVIGATING)
#   - Frame 432: Processing frame_06480 (State: NAVIGATING)
#   - Frame 433: Processing frame_06495 (State: NAVIGATING)
#   - Frame 434: Processing frame_06510 (State: NAVIGATING)
#   - Frame 435: Processing frame_06525 (State: NAVIGATING)
#   - Frame 436: Processing frame_06540 (State: NAVIGATING)
#   - Frame 437: Processing frame_06555 (State: NAVIGATING)
#   - Frame 438: Processing frame_06570 (State: NAVIGATING)
#   - Frame 439: Processing frame_06585 (State: NAVIGATING)
#   - Frame 440: Processing frame_06600 (State: NAVIGATING)
#   - Frame 441: Processing frame_06615 (State: NAVIGATING)
#   - Frame 442: Processing frame_06630 (State: NAVIGATING)
#   - Frame 443: Processing frame_06645 (State: NAVIGATING)
#   - Frame 444: Processing frame_06660 (State: NAVIGATING)
#   - Frame 445: Processing frame_06675 (State: NAVIGATING)
#   - Frame 446: Processing frame_06690 (State: NAVIGATING)
#   - Frame 447: Processing frame_06705 (State: NAVIGATING)
#   - Frame 448: Processing frame_06720 (State: NAVIGATING)
#   - Frame 449: Processing frame_06735 (State: NAVIGATING)
#   - Frame 450: Processing frame_06750 (State: NAVIGATING)
#   - Frame 451: Processing frame_06765 (State: NAVIGATING)
#   - Frame 452: Processing frame_06780 (State: NAVIGATING)
#   - Frame 453: Processing frame_06795 (State: NAVIGATING)
#   - Frame 454: Processing frame_06810 (State: NAVIGATING)
#   - Frame 455: Processing frame_06825 (State: NAVIGATING)
#   - Frame 456: Processing frame_06840 (State: NAVIGATING)
#   - Frame 457: Processing frame_06855 (State: NAVIGATING)
#   - Frame 458: Processing frame_06870 (State: NAVIGATING)
#   - Frame 459: Processing frame_06885 (State: NAVIGATING)
#   - Frame 460: Processing frame_06900 (State: NAVIGATING)
#   - Frame 461: Processing frame_06915 (State: NAVIGATING)
#   - Frame 462: Processing frame_06930 (State: NAVIGATING)
#   - Frame 463: Processing frame_06945 (State: NAVIGATING)
#   - Frame 464: Processing frame_06960 (State: NAVIGATING)
#   - Frame 465: Processing frame_06975 (State: NAVIGATING)
#   - Frame 466: Processing frame_06990 (State: NAVIGATING)
#   - Frame 467: Processing frame_07005 (State: NAVIGATING)
#   - Frame 468: Processing frame_07020 (State: NAVIGATING)
#   - Frame 469: Processing frame_07035 (State: NAVIGATING)
#   - Frame 470: Processing frame_07050 (State: WAITING)
#   - Frame 471: Processing frame_07065 (State: WAITING)
#   - Frame 472: Processing frame_07080 (State: NAVIGATING)
#   - Frame 473: Processing frame_07095 (State: NAVIGATING)
#   - Frame 474: Processing frame_07110 (State: WAITING)
#   - Frame 475: Processing frame_07125 (State: WAITING)
#   - Frame 476: Processing frame_07140 (State: WAITING)
#   - Frame 477: Processing frame_07155 (State: WAITING)
#   - Frame 478: Processing frame_07170 (State: WAITING)
#   - Frame 479: Processing frame_07185 (State: NAVIGATING)
#   - Frame 480: Processing frame_07200 (State: NAVIGATING)
#   - Frame 481: Processing frame_07215 (State: WAITING)
#   - Frame 482: Processing frame_07230 (State: NAVIGATING)
#   - Frame 483: Processing frame_07245 (State: NAVIGATING)
#   - Frame 484: Processing frame_07260 (State: NAVIGATING)
#   - Frame 485: Processing frame_07275 (State: NAVIGATING)
#   - Frame 486: Processing frame_07290 (State: NAVIGATING)
#   - Frame 487: Processing frame_07305 (State: NAVIGATING)
#   - Frame 488: Processing frame_07320 (State: NAVIGATING)
#   - Frame 489: Processing frame_07335 (State: NAVIGATING)
#   - Frame 490: Processing frame_07350 (State: NAVIGATING)
#   - Frame 491: Processing frame_07365 (State: NAVIGATING)
#   - Frame 492: Processing frame_07380 (State: NAVIGATING)
#   - Frame 493: Processing frame_07395 (State: NAVIGATING)
#   - Frame 494: Processing frame_07410 (State: NAVIGATING)
#   - Frame 495: Processing frame_07425 (State: NAVIGATING)
#   - Frame 496: Processing frame_07440 (State: NAVIGATING)
#   - Frame 497: Processing frame_07455 (State: NAVIGATING)
#   - Frame 498: Processing frame_07470 (State: NAVIGATING)
#   - Frame 499: Processing frame_07485 (State: NAVIGATING)
#   - Frame 500: Processing frame_07500 (State: NAVIGATING)
#   - Frame 501: Processing frame_07515 (State: NAVIGATING)
#   - Frame 502: Processing frame_07530 (State: NAVIGATING)
#   - Frame 503: Processing frame_07545 (State: NAVIGATING)
#   - Frame 504: Processing frame_07560 (State: NAVIGATING)
#   - Frame 505: Processing frame_07575 (State: NAVIGATING)
#   - Frame 506: Processing frame_07590 (State: NAVIGATING)
#   - Frame 507: Processing frame_07605 (State: WAITING)
#   - Frame 508: Processing frame_07620 (State: NAVIGATING)
#   - Frame 509: Processing frame_07635 (State: NAVIGATING)
#   - Frame 510: Processing frame_07650 (State: NAVIGATING)
#   - Frame 511: Processing frame_07665 (State: NAVIGATING)
#   - Frame 512: Processing frame_07680 (State: NAVIGATING)
#   - Frame 513: Processing frame_07695 (State: NAVIGATING)
#   - Frame 514: Processing frame_07710 (State: NAVIGATING)
#   - Frame 515: Processing frame_07725 (State: NAVIGATING)
#   - Frame 516: Processing frame_07740 (State: NAVIGATING)
#   - Frame 517: Processing frame_07755 (State: NAVIGATING)
#   - Frame 518: Processing frame_07770 (State: NAVIGATING)
#   - Frame 519: Processing frame_07785 (State: NAVIGATING)
#   - Frame 520: Processing frame_07800 (State: NAVIGATING)
#   - Frame 521: Processing frame_07815 (State: NAVIGATING)
#   - Frame 522: Processing frame_07830 (State: NAVIGATING)
#   - Frame 523: Processing frame_07845 (State: NAVIGATING)
#   - Frame 524: Processing frame_07860 (State: NAVIGATING)
#   - Frame 525: Processing frame_07875 (State: NAVIGATING)
#   - Frame 526: Processing frame_07890 (State: NAVIGATING)
#   - Frame 527: Processing frame_07905 (State: NAVIGATING)
#   - Frame 528: Processing frame_07920 (State: NAVIGATING)
#   - Frame 529: Processing frame_07935 (State: NAVIGATING)
#   - Frame 530: Processing frame_07950 (State: NAVIGATING)
#   - Frame 531: Processing frame_07965 (State: NAVIGATING)
#   - Frame 532: Processing frame_07980 (State: NAVIGATING)
#   - Frame 533: Processing frame_07995 (State: NAVIGATING)
#   - Frame 534: Processing frame_08010 (State: NAVIGATING)
#   - Frame 535: Processing frame_08025 (State: NAVIGATING)
#   - Frame 536: Processing frame_08040 (State: NAVIGATING)
#   - Frame 537: Processing frame_08055 (State: NAVIGATING)
#   - Frame 538: Processing frame_08070 (State: NAVIGATING)
#   - Frame 539: Processing frame_08085 (State: NAVIGATING)
#   - Frame 540: Processing frame_08100 (State: NAVIGATING)
#   - Frame 541: Processing frame_08115 (State: NAVIGATING)
#   - Frame 542: Processing frame_08130 (State: NAVIGATING)
#   - Frame 543: Processing frame_08145 (State: NAVIGATING)
#   - Frame 544: Processing frame_08160 (State: NAVIGATING)
#   - Frame 545: Processing frame_08175 (State: NAVIGATING)
#   - Frame 546: Processing frame_08190 (State: NAVIGATING)
#   - Frame 547: Processing frame_08205 (State: NAVIGATING)
#   - Frame 548: Processing frame_08220 (State: NAVIGATING)
#   - Frame 549: Processing frame_08235 (State: NAVIGATING)
#   - Frame 550: Processing frame_08250 (State: NAVIGATING)
#   - Frame 551: Processing frame_08265 (State: NAVIGATING)
#   - Frame 552: Processing frame_08280 (State: NAVIGATING)
#   - Frame 553: Processing frame_08295 (State: NAVIGATING)
#   - Frame 554: Processing frame_08310 (State: NAVIGATING)
#   - Frame 555: Processing frame_08325 (State: NAVIGATING)
#   - Frame 556: Processing frame_08340 (State: NAVIGATING)
#   - Frame 557: Processing frame_08355 (State: NAVIGATING)
#   - Frame 558: Processing frame_08370 (State: NAVIGATING)
#   - Frame 559: Processing frame_08385 (State: NAVIGATING)
#   - Frame 560: Processing frame_08400 (State: NAVIGATING)
#   - Frame 561: Processing frame_08415 (State: NAVIGATING)
#   - Frame 562: Processing frame_08430 (State: NAVIGATING)
#   - Frame 563: Processing frame_08445 (State: NAVIGATING)
#   - Frame 564: Processing frame_08460 (State: NAVIGATING)
#   - Frame 565: Processing frame_08475 (State: NAVIGATING)
#   - Frame 566: Processing frame_08490 (State: NAVIGATING)
#   - Frame 567: Processing frame_08505 (State: NAVIGATING)
#   - Frame 568: Processing frame_08520 (State: NAVIGATING)
#   - Frame 569: Processing frame_08535 (State: NAVIGATING)
#   - Frame 570: Processing frame_08550 (State: NAVIGATING)
#   - Frame 571: Processing frame_08565 (State: NAVIGATING)
#   - Frame 572: Processing frame_08580 (State: NAVIGATING)
#   - Frame 573: Processing frame_08595 (State: NAVIGATING)
#   - Frame 574: Processing frame_08610 (State: NAVIGATING)
#   - Frame 575: Processing frame_08625 (State: NAVIGATING)
#   - Frame 576: Processing frame_08640 (State: NAVIGATING)
#   - Frame 577: Processing frame_08655 (State: NAVIGATING)
#   - Frame 578: Processing frame_08670 (State: NAVIGATING)
#   - Frame 579: Processing frame_08685 (State: NAVIGATING)
#   - Frame 580: Processing frame_08700 (State: NAVIGATING)
#   - Frame 581: Processing frame_08715 (State: NAVIGATING)
#   - Frame 582: Processing frame_08730 (State: NAVIGATING)
#   - Frame 583: Processing frame_08745 (State: NAVIGATING)
#   - Frame 584: Processing frame_08760 (State: NAVIGATING)
#   - Frame 585: Processing frame_08775 (State: NAVIGATING)
#   - Frame 586: Processing frame_08790 (State: NAVIGATING)
#   - Frame 587: Processing frame_08805 (State: NAVIGATING)
#   - Frame 588: Processing frame_08820 (State: NAVIGATING)
#   - Frame 589: Processing frame_08835 (State: NAVIGATING)
#   - Frame 590: Processing frame_08850 (State: NAVIGATING)
#   - Frame 591: Processing frame_08865 (State: NAVIGATING)
#   - Frame 592: Processing frame_08880 (State: NAVIGATING)
#   - Frame 593: Processing frame_08895 (State: NAVIGATING)
#   - Frame 594: Processing frame_08910 (State: NAVIGATING)
#   - Frame 595: Processing frame_08925 (State: NAVIGATING)
#   - Frame 596: Processing frame_08940 (State: NAVIGATING)
#
# SUCCESS! Advanced navigation video saved to: output_final_videos\final_navigation_video_with_states.mp4

# %%
# ==============================================================================
# SCRIPT: final_navigation.py (Full Version: States + Labels)
# ==============================================================================
# PURPOSE: A complete navigation algorithm combining a state machine for handling
#          blocked paths with clear visualization of obstacle labels.
# ==============================================================================

import cv2
import os
import numpy as np
import json
import glob
from pathfinding.core.grid import Grid
from pathfinding.finder.a_star import AStarFinder
from pathfinding.core.diagonal_movement import DiagonalMovement

# --- State Machine Definitions ---
STATE_NAVIGATING = 'NAVIGATING'
STATE_WAITING = 'WAITING'
STATE_RETREATING = 'RETREATING'

# ==============================================================================
# 1. HELPER FUNCTIONS (Unchanged)
# ==============================================================================

def create_costmap(frame, depth_map, obstacles_data, settings):
    """Creates a costmap with inflated obstacles for safer pathing."""
    width, height = settings['width'], settings['height']
    costmap_w = settings['costmap_width']
    focal_length = settings['focal_length']
    src_pts = settings['src_pts']
    cost_sidewalk = settings['cost_sidewalk']
    cost_obstacle = settings['cost_obstacle']
    map_world_size_m = settings['map_world_size_m']

    costmap = np.full((costmap_w, costmap_w), cost_obstacle, dtype=np.int32)
    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    lower_gray = np.array([0, 0, 40])
    upper_gray = np.array([180, 40, 220])
    sidewalk_mask = cv2.inRange(hsv_frame, lower_gray, upper_gray)

    M_image_to_world = cv2.getPerspectiveTransform(src_pts, settings['dst_pts'])
    top_down_sidewalk = cv2.warpPerspective(sidewalk_mask, M_image_to_world, (width, height))
    top_down_sidewalk_resized = cv2.resize(top_down_sidewalk, (costmap_w, costmap_w))
    
    sidewalk_indices = top_down_sidewalk_resized > 128
    costmap[sidewalk_indices] = cost_sidewalk

    obstacle_map = np.zeros_like(costmap, dtype=np.uint8)
    for obs in obstacles_data:
        x, y, w, h = obs['box']
        center_x_px, center_y_px = int(x + w/2), int(y + h/2)
        if 0 <= center_y_px < depth_map.shape[0] and 0 <= center_x_px < depth_map.shape[1]:
            inverse_depth = depth_map[center_y_px, center_x_px]
            if inverse_depth <= 0 or (1.0 / inverse_depth) > map_world_size_m: continue
            
            real_depth_z = 1.0 / inverse_depth
            real_x = (center_x_px - width/2) * real_depth_z / focal_length
            real_w = (w * real_depth_z) / focal_length
            map_x = int((real_x + map_world_size_m/2) / map_world_size_m * costmap_w)
            map_y = int(costmap_w - (real_depth_z / map_world_size_m * costmap_w))
            map_w = max(1, int(real_w / map_world_size_m * costmap_w))

            if 0 <= map_y < costmap_w and 0 <= map_x < costmap_w:
                cv2.rectangle(obstacle_map, (map_x - map_w//2, map_y - map_w//2), (map_x + map_w//2, map_y + map_w//2), 255, -1)

    if np.any(obstacle_map):
        inflation_kernel_size = int(costmap_w * 0.1) | 1
        inflated_map = cv2.GaussianBlur(obstacle_map.astype(np.float32), (inflation_kernel_size, inflation_kernel_size), 0)
        inflated_costs = (inflated_map / (np.max(inflated_map) + 1e-6)) * (cost_obstacle - cost_sidewalk)
        costmap = np.maximum(costmap, inflated_costs.astype(np.int32))
        
    return costmap, sidewalk_indices

def find_and_smooth_path(costmap, start_node, end_node, settings):
    """Finds the global path using A* and then smooths it."""
    grid = Grid(matrix=costmap)
    start = grid.node(start_node[0], start_node[1])
    end = grid.node(end_node[0], end_node[1])

    finder = AStarFinder(diagonal_movement=DiagonalMovement.always)
    path, runs = finder.find_path(start, end, grid)

    if not path or len(path) < 2: return None

    path_arr = np.array([(p.x, p.y) for p in path], dtype=float)
    window_size = 5
    padded_path = np.pad(path_arr, ((window_size//2, window_size//2), (0,0)), 'edge')
    smoothed_path = [tuple(np.mean(padded_path[i : i+window_size], axis=0)) for i in range(len(path_arr))]
            
    return smoothed_path

def draw_path_on_frame(frame, path, color, settings, M_world_to_image):
    """Projects and draws a given path onto the image frame."""
    if not path: return
    
    map_w = settings['costmap_width']
    width, height = settings['width'], settings['height']
    
    path_on_map_plane = []
    for p in path:
        norm_x = p[0] / map_w
        norm_y = 1.0 - (p[1] / map_w)
        path_on_map_plane.append([norm_x * width, norm_y * height])
    
    path_on_image = cv2.perspectiveTransform(np.array([path_on_map_plane], dtype=np.float32), M_world_to_image)
    if path_on_image is not None:
        cv2.polylines(frame, [path_on_image[0].astype(np.int32)], False, color, 3, cv2.LINE_AA)
        
def draw_status_text(frame, text, y_pos=30):
    """Draws highly visible status text on the frame."""
    font = cv2.FONT_HERSHEY_SIMPLEX
    text_size = cv2.getTextSize(text, font, 0.8, 2)[0]
    text_x = (frame.shape[1] - text_size[0]) // 2
    cv2.putText(frame, text, (text_x, y_pos), font, 0.8, (255, 255, 255), 2, cv2.LINE_AA)

# ==========================================================================
# 2. MAIN EXECUTION
# ==========================================================================
def main():
    # --- Settings ---
    DATASET_FOLDER = "C:/Users/ace/street_dataset"
    IMAGE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/images")
    OBSTACLE_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/obstacles_json")
    DEPTH_FOLDER = os.path.join(DATASET_FOLDER, "C:/Users/acer/street_dataset/depth_maps_npy")
    OUTPUT_FOLDER = "output_final_videos"
    os.makedirs(OUTPUT_FOLDER, exist_ok=True)
    VIDEO_FPS = 10.0
    OUTPUT_VIDEO_FILENAME = os.path.join(OUTPUT_FOLDER, "final_navigation_video_with_labels.mp4")
    
    # --- State Machine Settings ---
    WAIT_DURATION_SECONDS = 5 * 60 # 5 minutes
    WAIT_DURATION_FRAMES = int(WAIT_DURATION_SECONDS * VIDEO_FPS)
    
    settings = {
        'costmap_width': 100,
        'map_world_size_m': 15.0,
        'cost_sidewalk': 1,
        'cost_obstacle': 5000,
    }

    # --- Setup ---
    image_files = sorted(glob.glob(os.path.join(IMAGE_FOLDER, "*.jpg")))
    if not image_files: print("!!! ERROR: No images found."); return
        
    print(f"Found {len(image_files)} frames. Starting advanced navigation simulation with labels...")
    first_frame = cv2.imread(image_files[0])
    height, width, _ = first_frame.shape
    video_writer = cv2.VideoWriter(OUTPUT_VIDEO_FILENAME, cv2.VideoWriter_fourcc(*'mp4v'), VIDEO_FPS, (width, height))
    
    settings.update({
        'width': width, 'height': height,
        'focal_length': (width / 2) / np.tan(np.deg2rad(60 / 2)),
        'src_pts': np.float32([(width*0.45, height*0.6), (width*0.55, height*0.6), (width*0.1, height), (width*0.9, height)]),
        'dst_pts': np.float32([(0, 0), (width, 0), (0, height), (width, height)])
    })
    M_world_to_image = cv2.getPerspectiveTransform(settings['dst_pts'], settings['src_pts'])

    # --- Initialize State Variables ---
    current_state = STATE_NAVIGATING
    wait_start_frame = -1

    # ==========================================================================
    # 3. MAIN LOOP
    # ==========================================================================
    for frame_idx, image_filepath in enumerate(image_files):
        base_filename = os.path.splitext(os.path.basename(image_filepath))[0]
        print(f"  - Frame {frame_idx}: Processing {base_filename} (State: {current_state})")
        
        frame = cv2.imread(image_filepath)
        try:
            with open(os.path.join(OBSTACLE_FOLDER, f"{base_filename}.json"), 'r') as f:
                obstacles_data = json.load(f)
            depth_map = np.load(os.path.join(DEPTH_FOLDER, f"{base_filename}.npy"))
        except FileNotFoundError:
            draw_status_text(frame, "Data missing for this frame.")
            video_writer.write(frame)
            continue

        # --- Step 1: Create Costmap ---
        costmap, sidewalk_indices = create_costmap(frame, depth_map, obstacles_data, settings)
        
        # --- Step 2: Pathfinding and State Logic ---
        start_node = (settings['costmap_width'] // 2, settings['costmap_width'] - 1)
        
        forward_goal_node = None
        sidewalk_y, sidewalk_x = np.where(sidewalk_indices)
        if len(sidewalk_y) > 0:
            far_sidewalk_indices = np.where(sidewalk_y < settings['costmap_width'] * 0.2)[0]
            if len(far_sidewalk_indices) > 0:
                furthest_y = np.min(sidewalk_y[far_sidewalk_indices])
                candidate_xs = sidewalk_x[sidewalk_y == furthest_y]
                goal_x = candidate_xs[np.argmin(np.abs(candidate_xs - settings['costmap_width'] // 2))]
                forward_goal_node = (goal_x, furthest_y)
            
        forward_path = None
        if forward_goal_node:
            forward_path = find_and_smooth_path(costmap, start_node, forward_goal_node, settings)

        if forward_path:
            current_state = STATE_NAVIGATING
            wait_start_frame = -1
            draw_path_on_frame(frame, forward_path, (0, 255, 0), settings, M_world_to_image) # Green for forward path
            draw_status_text(frame, "Status: Navigating Forward")
        else:
            if current_state == STATE_NAVIGATING:
                current_state = STATE_WAITING
                wait_start_frame = frame_idx
                draw_status_text(frame, "Path Blocked! Waiting...")
            elif current_state == STATE_WAITING:
                elapsed_frames = frame_idx - wait_start_frame
                if elapsed_frames < WAIT_DURATION_FRAMES:
                    remaining_sec = (WAIT_DURATION_FRAMES - elapsed_frames) / VIDEO_FPS
                    draw_status_text(frame, f"Path Blocked. Waiting... ({int(remaining_sec)}s)")
                else:
                    current_state = STATE_RETREATING
                    draw_status_text(frame, "Wait Time Exceeded! Retreating.")
            elif current_state == STATE_RETREATING:
                draw_status_text(frame, "Status: Planning Retreat")
                retreat_goal_node = start_node
                retreat_start_node = (settings['costmap_width'] // 2, 5) 
                retreat_path = find_and_smooth_path(costmap, retreat_start_node, retreat_goal_node, settings)
                if retreat_path:
                    draw_path_on_frame(frame, retreat_path, (0, 0, 255), settings, M_world_to_image) # Red for retreat path
                else:
                    draw_status_text(frame, "CRITICAL: Retreat Path Blocked! TRAPPED!", 60)

        # --- Step 3: Visualize Labeled Obstacles ---
        # THIS SECTION IS THE PRIMARY CHANGE
        for obs in obstacles_data:
            x, y, w, h = obs['box']
            # Draw the bounding box
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 165, 255), 2) # Orange box
            
            # Prepare the label text
            label = f"{obs['label']} {int(obs['confidence'] * 100)}%"
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 0.5
            font_thickness = 1
            
            # Get text size to create a background
            (text_w, text_h), baseline = cv2.getTextSize(label, font, font_scale, font_thickness)
            
            # Draw a black rectangle as a background for the label
            cv2.rectangle(frame, (x, y - text_h - 10), (x + text_w, y), (0, 0, 0), -1)
            
            # Put the white text on top of the background
            cv2.putText(frame, label, (x, y - 5), font, font_scale, (255, 255, 255), font_thickness, cv2.LINE_AA)
        
        video_writer.write(frame)

    video_writer.release()
    print(f"\nSUCCESS! Labeled navigation video saved to: {OUTPUT_VIDEO_FILENAME}")

if __name__ == '__main__':
    main()
# Out:
# Found 597 frames. Starting advanced navigation simulation with labels...
#   - Frame 0: Processing frame_00000 (State: NAVIGATING)
#   - Frame 1: Processing frame_00015 (State: NAVIGATING)
#   - Frame 2: Processing frame_00030 (State: NAVIGATING)
#   - Frame 3: Processing frame_00045 (State: NAVIGATING)
#   - Frame 4: Processing frame_00060 (State: NAVIGATING)
#   - Frame 5: Processing frame_00075 (State: NAVIGATING)
#   - Frame 6: Processing frame_00090 (State: NAVIGATING)
#   - Frame 7: Processing frame_00105 (State: NAVIGATING)
#   - Frame 8: Processing frame_00120 (State: NAVIGATING)
#   - Frame 9: Processing frame_00135 (State: NAVIGATING)
#   - Frame 10: Processing frame_00150 (State: NAVIGATING)
#   - Frame 11: Processing frame_00165 (State: NAVIGATING)
#   - Frame 12: Processing frame_00180 (State: NAVIGATING)
#   - Frame 13: Processing frame_00195 (State: WAITING)
#   - Frame 14: Processing frame_00210 (State: NAVIGATING)
#   - Frame 15: Processing frame_00225 (State: NAVIGATING)
#   - Frame 16: Processing frame_00240 (State: NAVIGATING)
#   - Frame 17: Processing frame_00255 (State: NAVIGATING)
#   - Frame 18: Processing frame_00270 (State: NAVIGATING)
#   - Frame 19: Processing frame_00285 (State: NAVIGATING)
#   - Frame 20: Processing frame_00300 (State: NAVIGATING)
#   - Frame 21: Processing frame_00315 (State: NAVIGATING)
#   - Frame 22: Processing frame_00330 (State: NAVIGATING)
#   - Frame 23: Processing frame_00345 (State: NAVIGATING)
#   - Frame 24: Processing frame_00360 (State: NAVIGATING)
#   - Frame 25: Processing frame_00375 (State: NAVIGATING)
#   - Frame 26: Processing frame_00390 (State: NAVIGATING)
#   - Frame 27: Processing frame_00405 (State: NAVIGATING)
#   - Frame 28: Processing frame_00420 (State: NAVIGATING)
#   - Frame 29: Processing frame_00435 (State: NAVIGATING)
#   - Frame 30: Processing frame_00450 (State: NAVIGATING)
#   - Frame 31: Processing frame_00465 (State: NAVIGATING)
#   - Frame 32: Processing frame_00480 (State: NAVIGATING)
#   - Frame 33: Processing frame_00495 (State: NAVIGATING)
#   - Frame 34: Processing frame_00510 (State: NAVIGATING)
#   - Frame 35: Processing frame_00525 (State: NAVIGATING)
#   - Frame 36: Processing frame_00540 (State: NAVIGATING)
#   - Frame 37: Processing frame_00555 (State: NAVIGATING)
#   - Frame 38: Processing frame_00570 (State: NAVIGATING)
#   - Frame 39: Processing frame_00585 (State: NAVIGATING)
#   - Frame 40: Processing frame_00600 (State: NAVIGATING)
#   - Frame 41: Processing frame_00615 (State: NAVIGATING)
#   - Frame 42: Processing frame_00630 (State: NAVIGATING)
#   - Frame 43: Processing frame_00645 (State: NAVIGATING)
#   - Frame 44: Processing frame_00660 (State: NAVIGATING)
#   - Frame 45: Processing frame_00675 (State: NAVIGATING)
#   - Frame 46: Processing frame_00690 (State: NAVIGATING)
#   - Frame 47: Processing frame_00705 (State: NAVIGATING)
#   - Frame 48: Processing frame_00720 (State: NAVIGATING)
#   - Frame 49: Processing frame_00735 (State: NAVIGATING)
#   - Frame 50: Processing frame_00750 (State: NAVIGATING)
#   - Frame 51: Processing frame_00765 (State: NAVIGATING)
#   - Frame 52: Processing frame_00780 (State: NAVIGATING)
#   - Frame 53: Processing frame_00795 (State: NAVIGATING)
#   - Frame 54: Processing frame_00810 (State: NAVIGATING)
#   - Frame 55: Processing frame_00825 (State: NAVIGATING)
#   - Frame 56: Processing frame_00840 (State: NAVIGATING)
#   - Frame 57: Processing frame_00855 (State: NAVIGATING)
#   - Frame 58: Processing frame_00870 (State: NAVIGATING)
#   - Frame 59: Processing frame_00885 (State: NAVIGATING)
#   - Frame 60: Processing frame_00900 (State: NAVIGATING)
#   - Frame 61: Processing frame_00915 (State: NAVIGATING)
#   - Frame 62: Processing frame_00930 (State: NAVIGATING)
#   - Frame 63: Processing frame_00945 (State: NAVIGATING)
#   - Frame 64: Processing frame_00960 (State: NAVIGATING)
#   - Frame 65: Processing frame_00975 (State: NAVIGATING)
#   - Frame 66: Processing frame_00990 (State: NAVIGATING)
#   - Frame 67: Processing frame_01005 (State: NAVIGATING)
#   - Frame 68: Processing frame_01020 (State: NAVIGATING)
#   - Frame 69: Processing frame_01035 (State: NAVIGATING)
#   - Frame 70: Processing frame_01050 (State: NAVIGATING)
#   - Frame 71: Processing frame_01065 (State: NAVIGATING)
#   - Frame 72: Processing frame_01080 (State: NAVIGATING)
#   - Frame 73: Processing frame_01095 (State: NAVIGATING)
#   - Frame 74: Processing frame_01110 (State: NAVIGATING)
#   - Frame 75: Processing frame_01125 (State: NAVIGATING)
#   - Frame 76: Processing frame_01140 (State: NAVIGATING)
#   - Frame 77: Processing frame_01155 (State: NAVIGATING)
#   - Frame 78: Processing frame_01170 (State: NAVIGATING)
#   - Frame 79: Processing frame_01185 (State: NAVIGATING)
#   - Frame 80: Processing frame_01200 (State: NAVIGATING)
#   - Frame 81: Processing frame_01215 (State: NAVIGATING)
#   - Frame 82: Processing frame_01230 (State: NAVIGATING)
#   - Frame 83: Processing frame_01245 (State: NAVIGATING)
#   - Frame 84: Processing frame_01260 (State: NAVIGATING)
#   - Frame 85: Processing frame_01275 (State: NAVIGATING)
#   - Frame 86: Processing frame_01290 (State: NAVIGATING)
#   - Frame 87: Processing frame_01305 (State: NAVIGATING)
#   - Frame 88: Processing frame_01320 (State: NAVIGATING)
#   - Frame 89: Processing frame_01335 (State: NAVIGATING)
#   - Frame 90: Processing frame_01350 (State: NAVIGATING)
#   - Frame 91: Processing frame_01365 (State: NAVIGATING)
#   - Frame 92: Processing frame_01380 (State: NAVIGATING)
#   - Frame 93: Processing frame_01395 (State: NAVIGATING)
#   - Frame 94: Processing frame_01410 (State: NAVIGATING)
#   - Frame 95: Processing frame_01425 (State: NAVIGATING)
#   - Frame 96: Processing frame_01440 (State: NAVIGATING)
#   - Frame 97: Processing frame_01455 (State: NAVIGATING)
#   - Frame 98: Processing frame_01470 (State: NAVIGATING)
#   - Frame 99: Processing frame_01485 (State: NAVIGATING)
#   - Frame 100: Processing frame_01500 (State: NAVIGATING)
#   - Frame 101: Processing frame_01515 (State: NAVIGATING)
#   - Frame 102: Processing frame_01530 (State: NAVIGATING)
#   - Frame 103: Processing frame_01545 (State: NAVIGATING)
#   - Frame 104: Processing frame_01560 (State: NAVIGATING)
#   - Frame 105: Processing frame_01575 (State: NAVIGATING)
#   - Frame 106: Processing frame_01590 (State: NAVIGATING)
#   - Frame 107: Processing frame_01605 (State: NAVIGATING)
#   - Frame 108: Processing frame_01620 (State: NAVIGATING)
#   - Frame 109: Processing frame_01635 (State: NAVIGATING)
#   - Frame 110: Processing frame_01650 (State: NAVIGATING)
#   - Frame 111: Processing frame_01665 (State: NAVIGATING)
#   - Frame 112: Processing frame_01680 (State: NAVIGATING)
#   - Frame 113: Processing frame_01695 (State: NAVIGATING)
#   - Frame 114: Processing frame_01710 (State: NAVIGATING)
#   - Frame 115: Processing frame_01725 (State: NAVIGATING)
#   - Frame 116: Processing frame_01740 (State: NAVIGATING)
#   - Frame 117: Processing frame_01755 (State: NAVIGATING)
#   - Frame 118: Processing frame_01770 (State: NAVIGATING)
#   - Frame 119: Processing frame_01785 (State: NAVIGATING)
#   - Frame 120: Processing frame_01800 (State: NAVIGATING)
#   - Frame 121: Processing frame_01815 (State: NAVIGATING)
#   - Frame 122: Processing frame_01830 (State: NAVIGATING)
#   - Frame 123: Processing frame_01845 (State: NAVIGATING)
#   - Frame 124: Processing frame_01860 (State: NAVIGATING)
#   - Frame 125: Processing frame_01875 (State: WAITING)
#   - Frame 126: Processing frame_01890 (State: NAVIGATING)
#   - Frame 127: Processing frame_01905 (State: NAVIGATING)
#   - Frame 128: Processing frame_01920 (State: NAVIGATING)
#   - Frame 129: Processing frame_01935 (State: NAVIGATING)
#   - Frame 130: Processing frame_01950 (State: NAVIGATING)
#   - Frame 131: Processing frame_01965 (State: NAVIGATING)
#   - Frame 132: Processing frame_01980 (State: NAVIGATING)
#   - Frame 133: Processing frame_01995 (State: NAVIGATING)
#   - Frame 134: Processing frame_02010 (State: NAVIGATING)
#   - Frame 135: Processing frame_02025 (State: NAVIGATING)
#   - Frame 136: Processing frame_02040 (State: NAVIGATING)
#   - Frame 137: Processing frame_02055 (State: NAVIGATING)
#   - Frame 138: Processing frame_02070 (State: NAVIGATING)
#   - Frame 139: Processing frame_02085 (State: NAVIGATING)
#   - Frame 140: Processing frame_02100 (State: NAVIGATING)
#   - Frame 141: Processing frame_02115 (State: NAVIGATING)
#   - Frame 142: Processing frame_02130 (State: NAVIGATING)
#   - Frame 143: Processing frame_02145 (State: NAVIGATING)
#   - Frame 144: Processing frame_02160 (State: NAVIGATING)
#   - Frame 145: Processing frame_02175 (State: NAVIGATING)
#   - Frame 146: Processing frame_02190 (State: NAVIGATING)
#   - Frame 147: Processing frame_02205 (State: NAVIGATING)
#   - Frame 148: Processing frame_02220 (State: NAVIGATING)
#   - Frame 149: Processing frame_02235 (State: NAVIGATING)
#   - Frame 150: Processing frame_02250 (State: NAVIGATING)
#   - Frame 151: Processing frame_02265 (State: NAVIGATING)
#   - Frame 152: Processing frame_02280 (State: NAVIGATING)
#   - Frame 153: Processing frame_02295 (State: NAVIGATING)
#   - Frame 154: Processing frame_02310 (State: NAVIGATING)
#   - Frame 155: Processing frame_02325 (State: NAVIGATING)
#   - Frame 156: Processing frame_02340 (State: NAVIGATING)
#   - Frame 157: Processing frame_02355 (State: NAVIGATING)
#   - Frame 158: Processing frame_02370 (State: NAVIGATING)
#   - Frame 159: Processing frame_02385 (State: NAVIGATING)
#   - Frame 160: Processing frame_02400 (State: NAVIGATING)
#   - Frame 161: Processing frame_02415 (State: NAVIGATING)
#   - Frame 162: Processing frame_02430 (State: NAVIGATING)
#   - Frame 163: Processing frame_02445 (State: NAVIGATING)
#   - Frame 164: Processing frame_02460 (State: NAVIGATING)
#   - Frame 165: Processing frame_02475 (State: NAVIGATING)
#   - Frame 166: Processing frame_02490 (State: WAITING)
#   - Frame 167: Processing frame_02505 (State: WAITING)
#   - Frame 168: Processing frame_02520 (State: NAVIGATING)
#   - Frame 169: Processing frame_02535 (State: NAVIGATING)
#   - Frame 170: Processing frame_02550 (State: NAVIGATING)
#   - Frame 171: Processing frame_02565 (State: NAVIGATING)
#   - Frame 172: Processing frame_02580 (State: NAVIGATING)
#   - Frame 173: Processing frame_02595 (State: NAVIGATING)
#   - Frame 174: Processing frame_02610 (State: NAVIGATING)
#   - Frame 175: Processing frame_02625 (State: NAVIGATING)
#   - Frame 176: Processing frame_02640 (State: NAVIGATING)
#   - Frame 177: Processing frame_02655 (State: NAVIGATING)
#   - Frame 178: Processing frame_02670 (State: NAVIGATING)
#   - Frame 179: Processing frame_02685 (State: NAVIGATING)
#   - Frame 180: Processing frame_02700 (State: NAVIGATING)
#   - Frame 181: Processing frame_02715 (State: NAVIGATING)
#   - Frame 182: Processing frame_02730 (State: NAVIGATING)
#   - Frame 183: Processing frame_02745 (State: NAVIGATING)
#   - Frame 184: Processing frame_02760 (State: NAVIGATING)
#   - Frame 185: Processing frame_02775 (State: NAVIGATING)
#   - Frame 186: Processing frame_02790 (State: NAVIGATING)
#   - Frame 187: Processing frame_02805 (State: NAVIGATING)
#   - Frame 188: Processing frame_02820 (State: NAVIGATING)
#   - Frame 189: Processing frame_02835 (State: NAVIGATING)
#   - Frame 190: Processing frame_02850 (State: NAVIGATING)
#   - Frame 191: Processing frame_02865 (State: NAVIGATING)
#   - Frame 192: Processing frame_02880 (State: NAVIGATING)
#   - Frame 193: Processing frame_02895 (State: NAVIGATING)
#   - Frame 194: Processing frame_02910 (State: NAVIGATING)
#   - Frame 195: Processing frame_02925 (State: NAVIGATING)
#   - Frame 196: Processing frame_02940 (State: NAVIGATING)
#   - Frame 197: Processing frame_02955 (State: NAVIGATING)
#   - Frame 198: Processing frame_02970 (State: NAVIGATING)
#   - Frame 199: Processing frame_02985 (State: NAVIGATING)
#   - Frame 200: Processing frame_03000 (State: NAVIGATING)
#   - Frame 201: Processing frame_03015 (State: NAVIGATING)
#   - Frame 202: Processing frame_03030 (State: NAVIGATING)
#   - Frame 203: Processing frame_03045 (State: NAVIGATING)
#   - Frame 204: Processing frame_03060 (State: NAVIGATING)
#   - Frame 205: Processing frame_03075 (State: NAVIGATING)
#   - Frame 206: Processing frame_03090 (State: NAVIGATING)
#   - Frame 207: Processing frame_03105 (State: NAVIGATING)
#   - Frame 208: Processing frame_03120 (State: NAVIGATING)
#   - Frame 209: Processing frame_03135 (State: NAVIGATING)
#   - Frame 210: Processing frame_03150 (State: NAVIGATING)
#   - Frame 211: Processing frame_03165 (State: NAVIGATING)
#   - Frame 212: Processing frame_03180 (State: NAVIGATING)
#   - Frame 213: Processing frame_03195 (State: NAVIGATING)
#   - Frame 214: Processing frame_03210 (State: NAVIGATING)
#   - Frame 215: Processing frame_03225 (State: NAVIGATING)
#   - Frame 216: Processing frame_03240 (State: NAVIGATING)
#   - Frame 217: Processing frame_03255 (State: NAVIGATING)
#   - Frame 218: Processing frame_03270 (State: NAVIGATING)
#   - Frame 219: Processing frame_03285 (State: NAVIGATING)
#   - Frame 220: Processing frame_03300 (State: NAVIGATING)
#   - Frame 221: Processing frame_03315 (State: NAVIGATING)
#   - Frame 222: Processing frame_03330 (State: NAVIGATING)
#   - Frame 223: Processing frame_03345 (State: NAVIGATING)
#   - Frame 224: Processing frame_03360 (State: WAITING)
#   - Frame 225: Processing frame_03375 (State: NAVIGATING)
#   - Frame 226: Processing frame_03390 (State: NAVIGATING)
#   - Frame 227: Processing frame_03405 (State: NAVIGATING)
#   - Frame 228: Processing frame_03420 (State: NAVIGATING)
#   - Frame 229: Processing frame_03435 (State: NAVIGATING)
#   - Frame 230: Processing frame_03450 (State: NAVIGATING)
#   - Frame 231: Processing frame_03465 (State: NAVIGATING)
#   - Frame 232: Processing frame_03480 (State: NAVIGATING)
#   - Frame 233: Processing frame_03495 (State: NAVIGATING)
#   - Frame 234: Processing frame_03510 (State: NAVIGATING)
#   - Frame 235: Processing frame_03525 (State: NAVIGATING)
#   - Frame 236: Processing frame_03540 (State: NAVIGATING)
#   - Frame 237: Processing frame_03555 (State: NAVIGATING)
#   - Frame 238: Processing frame_03570 (State: NAVIGATING)
#   - Frame 239: Processing frame_03585 (State: NAVIGATING)
#   - Frame 240: Processing frame_03600 (State: NAVIGATING)
#   - Frame 241: Processing frame_03615 (State: NAVIGATING)
#   - Frame 242: Processing frame_03630 (State: NAVIGATING)
#   - Frame 243: Processing frame_03645 (State: NAVIGATING)
#   - Frame 244: Processing frame_03660 (State: NAVIGATING)
#   - Frame 245: Processing frame_03675 (State: NAVIGATING)
#   - Frame 246: Processing frame_03690 (State: NAVIGATING)
#   - Frame 247: Processing frame_03705 (State: NAVIGATING)
#   - Frame 248: Processing frame_03720 (State: NAVIGATING)
#   - Frame 249: Processing frame_03735 (State: NAVIGATING)
#   - Frame 250: Processing frame_03750 (State: NAVIGATING)
#   - Frame 251: Processing frame_03765 (State: NAVIGATING)
#   - Frame 252: Processing frame_03780 (State: NAVIGATING)
#   - Frame 253: Processing frame_03795 (State: NAVIGATING)
#   - Frame 254: Processing frame_03810 (State: NAVIGATING)
#   - Frame 255: Processing frame_03825 (State: NAVIGATING)
#   - Frame 256: Processing frame_03840 (State: NAVIGATING)
#   - Frame 257: Processing frame_03855 (State: NAVIGATING)
#   - Frame 258: Processing frame_03870 (State: NAVIGATING)
#   - Frame 259: Processing frame_03885 (State: NAVIGATING)
#   - Frame 260: Processing frame_03900 (State: NAVIGATING)
#   - Frame 261: Processing frame_03915 (State: NAVIGATING)
#   - Frame 262: Processing frame_03930 (State: NAVIGATING)
#   - Frame 263: Processing frame_03945 (State: NAVIGATING)
#   - Frame 264: Processing frame_03960 (State: NAVIGATING)
#   - Frame 265: Processing frame_03975 (State: NAVIGATING)
#   - Frame 266: Processing frame_03990 (State: NAVIGATING)
#   - Frame 267: Processing frame_04005 (State: NAVIGATING)
#   - Frame 268: Processing frame_04020 (State: NAVIGATING)
#   - Frame 269: Processing frame_04035 (State: NAVIGATING)
#   - Frame 270: Processing frame_04050 (State: NAVIGATING)
#   - Frame 271: Processing frame_04065 (State: NAVIGATING)
#   - Frame 272: Processing frame_04080 (State: NAVIGATING)
#   - Frame 273: Processing frame_04095 (State: NAVIGATING)
#   - Frame 274: Processing frame_04110 (State: NAVIGATING)
#   - Frame 275: Processing frame_04125 (State: NAVIGATING)
#   - Frame 276: Processing frame_04140 (State: NAVIGATING)
#   - Frame 277: Processing frame_04155 (State: NAVIGATING)
#   - Frame 278: Processing frame_04170 (State: NAVIGATING)
#   - Frame 279: Processing frame_04185 (State: NAVIGATING)
#   - Frame 280: Processing frame_04200 (State: NAVIGATING)
#   - Frame 281: Processing frame_04215 (State: NAVIGATING)
#   - Frame 282: Processing frame_04230 (State: NAVIGATING)
#   - Frame 283: Processing frame_04245 (State: NAVIGATING)
#   - Frame 284: Processing frame_04260 (State: NAVIGATING)
#   - Frame 285: Processing frame_04275 (State: NAVIGATING)
#   - Frame 286: Processing frame_04290 (State: NAVIGATING)
#   - Frame 287: Processing frame_04305 (State: NAVIGATING)
#   - Frame 288: Processing frame_04320 (State: NAVIGATING)
#   - Frame 289: Processing frame_04335 (State: NAVIGATING)
#   - Frame 290: Processing frame_04350 (State: NAVIGATING)
#   - Frame 291: Processing frame_04365 (State: NAVIGATING)
#   - Frame 292: Processing frame_04380 (State: NAVIGATING)
#   - Frame 293: Processing frame_04395 (State: NAVIGATING)
#   - Frame 294: Processing frame_04410 (State: NAVIGATING)
#   - Frame 295: Processing frame_04425 (State: NAVIGATING)
#   - Frame 296: Processing frame_04440 (State: NAVIGATING)
#   - Frame 297: Processing frame_04455 (State: NAVIGATING)
#   - Frame 298: Processing frame_04470 (State: NAVIGATING)
#   - Frame 299: Processing frame_04485 (State: NAVIGATING)
#   - Frame 300: Processing frame_04500 (State: NAVIGATING)
#   - Frame 301: Processing frame_04515 (State: NAVIGATING)
#   - Frame 302: Processing frame_04530 (State: NAVIGATING)
#   - Frame 303: Processing frame_04545 (State: NAVIGATING)
#   - Frame 304: Processing frame_04560 (State: NAVIGATING)
#   - Frame 305: Processing frame_04575 (State: NAVIGATING)
#   - Frame 306: Processing frame_04590 (State: NAVIGATING)
#   - Frame 307: Processing frame_04605 (State: NAVIGATING)
#   - Frame 308: Processing frame_04620 (State: NAVIGATING)
#   - Frame 309: Processing frame_04635 (State: NAVIGATING)
#   - Frame 310: Processing frame_04650 (State: NAVIGATING)
#   - Frame 311: Processing frame_04665 (State: NAVIGATING)
#   - Frame 312: Processing frame_04680 (State: NAVIGATING)
#   - Frame 313: Processing frame_04695 (State: NAVIGATING)
#   - Frame 314: Processing frame_04710 (State: NAVIGATING)
#   - Frame 315: Processing frame_04725 (State: WAITING)
#   - Frame 316: Processing frame_04740 (State: WAITING)
#   - Frame 317: Processing frame_04755 (State: NAVIGATING)
#   - Frame 318: Processing frame_04770 (State: NAVIGATING)
#   - Frame 319: Processing frame_04785 (State: WAITING)
#   - Frame 320: Processing frame_04800 (State: NAVIGATING)
#   - Frame 321: Processing frame_04815 (State: NAVIGATING)
#   - Frame 322: Processing frame_04830 (State: NAVIGATING)
#   - Frame 323: Processing frame_04845 (State: NAVIGATING)
#   - Frame 324: Processing frame_04860 (State: WAITING)
#   - Frame 325: Processing frame_04875 (State: NAVIGATING)
#   - Frame 326: Processing frame_04890 (State: NAVIGATING)
#   - Frame 327: Processing frame_04905 (State: NAVIGATING)
#   - Frame 328: Processing frame_04920 (State: NAVIGATING)
#   - Frame 329: Processing frame_04935 (State: NAVIGATING)
#   - Frame 330: Processing frame_04950 (State: NAVIGATING)
#   - Frame 331: Processing frame_04965 (State: NAVIGATING)
#   - Frame 332: Processing frame_04980 (State: NAVIGATING)
#   - Frame 333: Processing frame_04995 (State: NAVIGATING)
#   - Frame 334: Processing frame_05010 (State: NAVIGATING)
#   - Frame 335: Processing frame_05025 (State: NAVIGATING)
#   - Frame 336: Processing frame_05040 (State: NAVIGATING)
#   - Frame 337: Processing frame_05055 (State: NAVIGATING)
#   - Frame 338: Processing frame_05070 (State: NAVIGATING)
#   - Frame 339: Processing frame_05085 (State: NAVIGATING)
#   - Frame 340: Processing frame_05100 (State: NAVIGATING)
#   - Frame 341: Processing frame_05115 (State: NAVIGATING)
#   - Frame 342: Processing frame_05130 (State: NAVIGATING)
#   - Frame 343: Processing frame_05145 (State: NAVIGATING)
#   - Frame 344: Processing frame_05160 (State: NAVIGATING)
#   - Frame 345: Processing frame_05175 (State: NAVIGATING)
#   - Frame 346: Processing frame_05190 (State: NAVIGATING)
#   - Frame 347: Processing frame_05205 (State: NAVIGATING)
#   - Frame 348: Processing frame_05220 (State: NAVIGATING)
#   - Frame 349: Processing frame_05235 (State: NAVIGATING)
#   - Frame 350: Processing frame_05250 (State: NAVIGATING)
#   - Frame 351: Processing frame_05265 (State: NAVIGATING)
#   - Frame 352: Processing frame_05280 (State: NAVIGATING)
#   - Frame 353: Processing frame_05295 (State: NAVIGATING)
#   - Frame 354: Processing frame_05310 (State: NAVIGATING)
#   - Frame 355: Processing frame_05325 (State: NAVIGATING)
#   - Frame 356: Processing frame_05340 (State: NAVIGATING)
#   - Frame 357: Processing frame_05355 (State: NAVIGATING)
#   - Frame 358: Processing frame_05370 (State: NAVIGATING)
#   - Frame 359: Processing frame_05385 (State: NAVIGATING)
#   - Frame 360: Processing frame_05400 (State: NAVIGATING)
#   - Frame 361: Processing frame_05415 (State: NAVIGATING)
#   - Frame 362: Processing frame_05430 (State: NAVIGATING)
#   - Frame 363: Processing frame_05445 (State: WAITING)
#   - Frame 364: Processing frame_05460 (State: NAVIGATING)
#   - Frame 365: Processing frame_05475 (State: NAVIGATING)
#   - Frame 366: Processing frame_05490 (State: NAVIGATING)
#   - Frame 367: Processing frame_05505 (State: NAVIGATING)
#   - Frame 368: Processing frame_05520 (State: NAVIGATING)
#   - Frame 369: Processing frame_05535 (State: NAVIGATING)
#   - Frame 370: Processing frame_05550 (State: NAVIGATING)
#   - Frame 371: Processing frame_05565 (State: NAVIGATING)
#   - Frame 372: Processing frame_05580 (State: NAVIGATING)
#   - Frame 373: Processing frame_05595 (State: NAVIGATING)
#   - Frame 374: Processing frame_05610 (State: NAVIGATING)
#   - Frame 375: Processing frame_05625 (State: NAVIGATING)
#   - Frame 376: Processing frame_05640 (State: NAVIGATING)
#   - Frame 377: Processing frame_05655 (State: NAVIGATING)
#   - Frame 378: Processing frame_05670 (State: NAVIGATING)
#   - Frame 379: Processing frame_05685 (State: NAVIGATING)
#   - Frame 380: Processing frame_05700 (State: NAVIGATING)
#   - Frame 381: Processing frame_05715 (State: NAVIGATING)
#   - Frame 382: Processing frame_05730 (State: NAVIGATING)
#   - Frame 383: Processing frame_05745 (State: NAVIGATING)
#   - Frame 384: Processing frame_05760 (State: NAVIGATING)
#   - Frame 385: Processing frame_05775 (State: NAVIGATING)
#   - Frame 386: Processing frame_05790 (State: NAVIGATING)
#   - Frame 387: Processing frame_05805 (State: NAVIGATING)
#   - Frame 388: Processing frame_05820 (State: NAVIGATING)
#   - Frame 389: Processing frame_05835 (State: NAVIGATING)
#   - Frame 390: Processing frame_05850 (State: NAVIGATING)
#   - Frame 391: Processing frame_05865 (State: NAVIGATING)
#   - Frame 392: Processing frame_05880 (State: NAVIGATING)
#   - Frame 393: Processing frame_05895 (State: NAVIGATING)
#   - Frame 394: Processing frame_05910 (State: NAVIGATING)
#   - Frame 395: Processing frame_05925 (State: NAVIGATING)
#   - Frame 396: Processing frame_05940 (State: NAVIGATING)
#   - Frame 397: Processing frame_05955 (State: NAVIGATING)
#   - Frame 398: Processing frame_05970 (State: NAVIGATING)
#   - Frame 399: Processing frame_05985 (State: NAVIGATING)
#   - Frame 400: Processing frame_06000 (State: NAVIGATING)
#   - Frame 401: Processing frame_06015 (State: NAVIGATING)
#   - Frame 402: Processing frame_06030 (State: NAVIGATING)
#   - Frame 403: Processing frame_06045 (State: WAITING)
#   - Frame 404: Processing frame_06060 (State: NAVIGATING)
#   - Frame 405: Processing frame_06075 (State: NAVIGATING)
#   - Frame 406: Processing frame_06090 (State: NAVIGATING)
#   - Frame 407: Processing frame_06105 (State: NAVIGATING)
#   - Frame 408: Processing frame_06120 (State: NAVIGATING)
#   - Frame 409: Processing frame_06135 (State: NAVIGATING)
#   - Frame 410: Processing frame_06150 (State: NAVIGATING)
#   - Frame 411: Processing frame_06165 (State: NAVIGATING)
#   - Frame 412: Processing frame_06180 (State: NAVIGATING)
#   - Frame 413: Processing frame_06195 (State: NAVIGATING)
#   - Frame 414: Processing frame_06210 (State: NAVIGATING)
#   - Frame 415: Processing frame_06225 (State: NAVIGATING)
#   - Frame 416: Processing frame_06240 (State: NAVIGATING)
#   - Frame 417: Processing frame_06255 (State: NAVIGATING)
#   - Frame 418: Processing frame_06270 (State: NAVIGATING)
#   - Frame 419: Processing frame_06285 (State: NAVIGATING)
#   - Frame 420: Processing frame_06300 (State: NAVIGATING)
#   - Frame 421: Processing frame_06315 (State: NAVIGATING)
#   - Frame 422: Processing frame_06330 (State: NAVIGATING)
#   - Frame 423: Processing frame_06345 (State: NAVIGATING)
#   - Frame 424: Processing frame_06360 (State: NAVIGATING)
#   - Frame 425: Processing frame_06375 (State: NAVIGATING)
#   - Frame 426: Processing frame_06390 (State: NAVIGATING)
#   - Frame 427: Processing frame_06405 (State: NAVIGATING)
#   - Frame 428: Processing frame_06420 (State: NAVIGATING)
#   - Frame 429: Processing frame_06435 (State: NAVIGATING)
#   - Frame 430: Processing frame_06450 (State: NAVIGATING)
#   - Frame 431: Processing frame_06465 (State: NAVIGATING)
#   - Frame 432: Processing frame_06480 (State: NAVIGATING)
#   - Frame 433: Processing frame_06495 (State: NAVIGATING)
#   - Frame 434: Processing frame_06510 (State: NAVIGATING)
#   - Frame 435: Processing frame_06525 (State: NAVIGATING)
#   - Frame 436: Processing frame_06540 (State: NAVIGATING)
#   - Frame 437: Processing frame_06555 (State: NAVIGATING)
#   - Frame 438: Processing frame_06570 (State: NAVIGATING)
#   - Frame 439: Processing frame_06585 (State: NAVIGATING)
#   - Frame 440: Processing frame_06600 (State: NAVIGATING)
#   - Frame 441: Processing frame_06615 (State: NAVIGATING)
#   - Frame 442: Processing frame_06630 (State: NAVIGATING)
#   - Frame 443: Processing frame_06645 (State: NAVIGATING)
#   - Frame 444: Processing frame_06660 (State: NAVIGATING)
#   - Frame 445: Processing frame_06675 (State: NAVIGATING)
#   - Frame 446: Processing frame_06690 (State: NAVIGATING)
#   - Frame 447: Processing frame_06705 (State: NAVIGATING)
#   - Frame 448: Processing frame_06720 (State: NAVIGATING)
#   - Frame 449: Processing frame_06735 (State: NAVIGATING)
#   - Frame 450: Processing frame_06750 (State: NAVIGATING)
#   - Frame 451: Processing frame_06765 (State: NAVIGATING)
#   - Frame 452: Processing frame_06780 (State: NAVIGATING)
#   - Frame 453: Processing frame_06795 (State: NAVIGATING)
#   - Frame 454: Processing frame_06810 (State: NAVIGATING)
#   - Frame 455: Processing frame_06825 (State: NAVIGATING)
#   - Frame 456: Processing frame_06840 (State: NAVIGATING)
#   - Frame 457: Processing frame_06855 (State: NAVIGATING)
#   - Frame 458: Processing frame_06870 (State: NAVIGATING)
#   - Frame 459: Processing frame_06885 (State: NAVIGATING)
#   - Frame 460: Processing frame_06900 (State: NAVIGATING)
#   - Frame 461: Processing frame_06915 (State: NAVIGATING)
#   - Frame 462: Processing frame_06930 (State: NAVIGATING)
#   - Frame 463: Processing frame_06945 (State: NAVIGATING)
#   - Frame 464: Processing frame_06960 (State: NAVIGATING)
#   - Frame 465: Processing frame_06975 (State: NAVIGATING)
#   - Frame 466: Processing frame_06990 (State: NAVIGATING)
#   - Frame 467: Processing frame_07005 (State: NAVIGATING)
#   - Frame 468: Processing frame_07020 (State: NAVIGATING)
#   - Frame 469: Processing frame_07035 (State: NAVIGATING)
#   - Frame 470: Processing frame_07050 (State: WAITING)
#   - Frame 471: Processing frame_07065 (State: WAITING)
#   - Frame 472: Processing frame_07080 (State: NAVIGATING)
#   - Frame 473: Processing frame_07095 (State: NAVIGATING)
#   - Frame 474: Processing frame_07110 (State: WAITING)
#   - Frame 475: Processing frame_07125 (State: WAITING)
#   - Frame 476: Processing frame_07140 (State: WAITING)
#   - Frame 477: Processing frame_07155 (State: WAITING)
#   - Frame 478: Processing frame_07170 (State: WAITING)
#   - Frame 479: Processing frame_07185 (State: NAVIGATING)
#   - Frame 480: Processing frame_07200 (State: NAVIGATING)
#   - Frame 481: Processing frame_07215 (State: WAITING)
#   - Frame 482: Processing frame_07230 (State: NAVIGATING)
#   - Frame 483: Processing frame_07245 (State: NAVIGATING)
#   - Frame 484: Processing frame_07260 (State: NAVIGATING)
#   - Frame 485: Processing frame_07275 (State: NAVIGATING)
#   - Frame 486: Processing frame_07290 (State: NAVIGATING)
#   - Frame 487: Processing frame_07305 (State: NAVIGATING)
#   - Frame 488: Processing frame_07320 (State: NAVIGATING)
#   - Frame 489: Processing frame_07335 (State: NAVIGATING)
#   - Frame 490: Processing frame_07350 (State: NAVIGATING)
#   - Frame 491: Processing frame_07365 (State: NAVIGATING)
#   - Frame 492: Processing frame_07380 (State: NAVIGATING)
#   - Frame 493: Processing frame_07395 (State: NAVIGATING)
#   - Frame 494: Processing frame_07410 (State: NAVIGATING)
#   - Frame 495: Processing frame_07425 (State: NAVIGATING)
#   - Frame 496: Processing frame_07440 (State: NAVIGATING)
#   - Frame 497: Processing frame_07455 (State: NAVIGATING)
#   - Frame 498: Processing frame_07470 (State: NAVIGATING)
#   - Frame 499: Processing frame_07485 (State: NAVIGATING)
#   - Frame 500: Processing frame_07500 (State: NAVIGATING)
#   - Frame 501: Processing frame_07515 (State: NAVIGATING)
#   - Frame 502: Processing frame_07530 (State: NAVIGATING)
#   - Frame 503: Processing frame_07545 (State: NAVIGATING)
#   - Frame 504: Processing frame_07560 (State: NAVIGATING)
#   - Frame 505: Processing frame_07575 (State: NAVIGATING)
#   - Frame 506: Processing frame_07590 (State: NAVIGATING)
#   - Frame 507: Processing frame_07605 (State: WAITING)
#   - Frame 508: Processing frame_07620 (State: NAVIGATING)
#   - Frame 509: Processing frame_07635 (State: NAVIGATING)
#   - Frame 510: Processing frame_07650 (State: NAVIGATING)
#   - Frame 511: Processing frame_07665 (State: NAVIGATING)
#   - Frame 512: Processing frame_07680 (State: NAVIGATING)
#   - Frame 513: Processing frame_07695 (State: NAVIGATING)
#   - Frame 514: Processing frame_07710 (State: NAVIGATING)
#   - Frame 515: Processing frame_07725 (State: NAVIGATING)
#   - Frame 516: Processing frame_07740 (State: NAVIGATING)
#   - Frame 517: Processing frame_07755 (State: NAVIGATING)
#   - Frame 518: Processing frame_07770 (State: NAVIGATING)
#   - Frame 519: Processing frame_07785 (State: NAVIGATING)
#   - Frame 520: Processing frame_07800 (State: NAVIGATING)
#   - Frame 521: Processing frame_07815 (State: NAVIGATING)
#   - Frame 522: Processing frame_07830 (State: NAVIGATING)
#   - Frame 523: Processing frame_07845 (State: NAVIGATING)
#   - Frame 524: Processing frame_07860 (State: NAVIGATING)
#   - Frame 525: Processing frame_07875 (State: NAVIGATING)
#   - Frame 526: Processing frame_07890 (State: NAVIGATING)
#   - Frame 527: Processing frame_07905 (State: NAVIGATING)
#   - Frame 528: Processing frame_07920 (State: NAVIGATING)
#   - Frame 529: Processing frame_07935 (State: NAVIGATING)
#   - Frame 530: Processing frame_07950 (State: NAVIGATING)
#   - Frame 531: Processing frame_07965 (State: NAVIGATING)
#   - Frame 532: Processing frame_07980 (State: NAVIGATING)
#   - Frame 533: Processing frame_07995 (State: NAVIGATING)
#   - Frame 534: Processing frame_08010 (State: NAVIGATING)
#   - Frame 535: Processing frame_08025 (State: NAVIGATING)
#   - Frame 536: Processing frame_08040 (State: NAVIGATING)
#   - Frame 537: Processing frame_08055 (State: NAVIGATING)
#   - Frame 538: Processing frame_08070 (State: NAVIGATING)
#   - Frame 539: Processing frame_08085 (State: NAVIGATING)
#   - Frame 540: Processing frame_08100 (State: NAVIGATING)
#   - Frame 541: Processing frame_08115 (State: NAVIGATING)
#   - Frame 542: Processing frame_08130 (State: NAVIGATING)
#   - Frame 543: Processing frame_08145 (State: NAVIGATING)
#   - Frame 544: Processing frame_08160 (State: NAVIGATING)
#   - Frame 545: Processing frame_08175 (State: NAVIGATING)
#   - Frame 546: Processing frame_08190 (State: NAVIGATING)
#   - Frame 547: Processing frame_08205 (State: NAVIGATING)
#   - Frame 548: Processing frame_08220 (State: NAVIGATING)
#   - Frame 549: Processing frame_08235 (State: NAVIGATING)
#   - Frame 550: Processing frame_08250 (State: NAVIGATING)
#   - Frame 551: Processing frame_08265 (State: NAVIGATING)
#   - Frame 552: Processing frame_08280 (State: NAVIGATING)
#   - Frame 553: Processing frame_08295 (State: NAVIGATING)
#   - Frame 554: Processing frame_08310 (State: NAVIGATING)
#   - Frame 555: Processing frame_08325 (State: NAVIGATING)
#   - Frame 556: Processing frame_08340 (State: NAVIGATING)
#   - Frame 557: Processing frame_08355 (State: NAVIGATING)
#   - Frame 558: Processing frame_08370 (State: NAVIGATING)
#   - Frame 559: Processing frame_08385 (State: NAVIGATING)
#   - Frame 560: Processing frame_08400 (State: NAVIGATING)
#   - Frame 561: Processing frame_08415 (State: NAVIGATING)
#   - Frame 562: Processing frame_08430 (State: NAVIGATING)
#   - Frame 563: Processing frame_08445 (State: NAVIGATING)
#   - Frame 564: Processing frame_08460 (State: NAVIGATING)
#   - Frame 565: Processing frame_08475 (State: NAVIGATING)
#   - Frame 566: Processing frame_08490 (State: NAVIGATING)
#   - Frame 567: Processing frame_08505 (State: NAVIGATING)
#   - Frame 568: Processing frame_08520 (State: NAVIGATING)
#   - Frame 569: Processing frame_08535 (State: NAVIGATING)
#   - Frame 570: Processing frame_08550 (State: NAVIGATING)
#   - Frame 571: Processing frame_08565 (State: NAVIGATING)
#   - Frame 572: Processing frame_08580 (State: NAVIGATING)
#   - Frame 573: Processing frame_08595 (State: NAVIGATING)
#   - Frame 574: Processing frame_08610 (State: NAVIGATING)
#   - Frame 575: Processing frame_08625 (State: NAVIGATING)
#   - Frame 576: Processing frame_08640 (State: NAVIGATING)
#   - Frame 577: Processing frame_08655 (State: NAVIGATING)
#   - Frame 578: Processing frame_08670 (State: NAVIGATING)
#   - Frame 579: Processing frame_08685 (State: NAVIGATING)
#   - Frame 580: Processing frame_08700 (State: NAVIGATING)
#   - Frame 581: Processing frame_08715 (State: NAVIGATING)
#   - Frame 582: Processing frame_08730 (State: NAVIGATING)
#   - Frame 583: Processing frame_08745 (State: NAVIGATING)
#   - Frame 584: Processing frame_08760 (State: NAVIGATING)
#   - Frame 585: Processing frame_08775 (State: NAVIGATING)
#   - Frame 586: Processing frame_08790 (State: NAVIGATING)
#   - Frame 587: Processing frame_08805 (State: NAVIGATING)
#   - Frame 588: Processing frame_08820 (State: NAVIGATING)
#   - Frame 589: Processing frame_08835 (State: NAVIGATING)
#   - Frame 590: Processing frame_08850 (State: NAVIGATING)
#   - Frame 591: Processing frame_08865 (State: NAVIGATING)
#   - Frame 592: Processing frame_08880 (State: NAVIGATING)
#   - Frame 593: Processing frame_08895 (State: NAVIGATING)
#   - Frame 594: Processing frame_08910 (State: NAVIGATING)
#   - Frame 595: Processing frame_08925 (State: NAVIGATING)
#   - Frame 596: Processing frame_08940 (State: NAVIGATING)
#
# SUCCESS! Labeled navigation video saved to: output_final_videos\final_navigation_video_with_labels.mp4
